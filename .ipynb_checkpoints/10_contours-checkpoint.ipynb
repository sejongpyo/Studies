# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### contours
# - 등치선
# - 연속되는 점들로 동일한 색 또는 강도를 지님
# - 이미지에서 동일한 색상값이나 강도값을 갖는 연속된 좌표의 리스트
# ##### 형태 분석, 물체 인식 및 인지에 사용
# - apply threshold or canny edge detection before finding it
# #### white object and black background!!!

# %%
img = cv2.imread('/Users/sejongpyo/downloads/yubi.jpg')
imgray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(imgray, 127, 255, 0)
image, _ = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
# (source, contour retrieval mode(추출방식), contour approximation)
# contours : np array of (x, y) coordinates of boundary points
print(image)
# Out:
# [array([[[286, 830]],
#
#        [[286, 831]],
#
#        [[285, 832]],
#
#        [[285, 833]],
#
#        [[284, 834]],
#
#        [[284, 835]],
#
#        [[282, 837]],
#
#        [[282, 838]],
#
#        [[283, 838]],
#
#        [[283, 836]],
#
#        [[284, 835]],
#
#        [[284, 834]],
#
#        [[285, 833]],
#
#        [[285, 832]],
#
#        [[286, 831]]], dtype=int32), array([[[129, 829]],
#
#        [[129, 830]]], dtype=int32), array([[[280, 828]],
#
#        [[278, 830]]], dtype=int32), array([[[131, 825]],
#
#        [[131, 826]],
#
#        [[130, 827]],
#
#        [[131, 826]]], dtype=int32), array([[[281, 824]]], dtype=int32), array([[[146, 824]],
#
#        [[145, 825]]], dtype=int32), array([[[283, 822]]], dtype=int32), array([[[303, 816]]], dtype=int32), array([[[198, 815]]], dtype=int32), array([[[264, 814]]], dtype=int32), array([[[203, 814]]], dtype=int32), array([[[304, 813]],
#
#        [[304, 814]]], dtype=int32), array([[[200, 812]]], dtype=int32), array([[[126, 806]],
#
#        [[126, 807]]], dtype=int32), array([[[127, 803]],
#
#        [[127, 804]]], dtype=int32), array([[[128, 800]]], dtype=int32), array([[[163, 799]]], dtype=int32), array([[[ 44, 798]]], dtype=int32), array([[[297, 797]]], dtype=int32), array([[[129, 797]]], dtype=int32), array([[[184, 796]]], dtype=int32), array([[[130, 795]]], dtype=int32), array([[[167, 793]],
#
#        [[166, 794]],
#
#        [[166, 795]],
#
#        [[167, 794]]], dtype=int32), array([[[308, 792]]], dtype=int32), array([[[193, 791]],
#
#        [[192, 792]],
#
#        [[191, 792]],
#
#        [[190, 793]],
#
#        [[190, 794]],
#
#        [[180, 804]],
#
#        [[180, 811]],
#
#        [[181, 812]],
#
#        [[181, 813]],
#
#        [[180, 814]],
#
#        [[180, 816]],
#
#        [[181, 815]],
#
#        [[182, 815]],
#
#        [[183, 816]],
#
#        [[182, 815]],
#
#        [[183, 814]],
#
#        [[183, 813]],
#
#        [[184, 812]],
#
#        [[185, 812]],
#
#        [[186, 811]],
#
#        [[186, 809]],
#
#        [[189, 806]],
#
#        [[189, 805]],
#
#        [[191, 803]],
#
#        [[190, 802]],
#
#        [[191, 801]],
#
#        [[191, 800]],
#
#        [[192, 799]],
#
#        [[193, 800]],
#
#        [[192, 799]],
#
#        [[192, 798]],
#
#        [[193, 797]],
#
#        [[193, 796]],
#
#        [[194, 795]],
#
#        [[194, 793]],
#
#        [[195, 792]],
#
#        [[193, 794]],
#
#        [[192, 793]],
#
#        [[192, 792]]], dtype=int32), array([[[133, 791]]], dtype=int32), array([[[190, 789]]], dtype=int32), array([[[299, 788]],
#
#        [[299, 792]],
#
#        [[298, 793]],
#
#        [[298, 795]],
#
#        [[298, 794]],
#
#        [[299, 793]],
#
#        [[299, 789]],
#
#        [[300, 788]]], dtype=int32), array([[[202, 788]]], dtype=int32), array([[[175, 787]]], dtype=int32), array([[[134, 787]],
#
#        [[134, 789]]], dtype=int32), array([[[301, 784]],
#
#        [[301, 785]]], dtype=int32), array([[[136, 784]]], dtype=int32), array([[[137, 781]],
#
#        [[137, 782]],
#
#        [[138, 782]],
#
#        [[139, 781]]], dtype=int32), array([[[ 62, 780]]], dtype=int32), array([[[297, 774]],
#
#        [[297, 775]]], dtype=int32), array([[[208, 774]],
#
#        [[208, 775]],
#
#        [[207, 776]],
#
#        [[207, 777]],
#
#        [[206, 778]],
#
#        [[207, 779]],
#
#        [[206, 780]],
#
#        [[206, 781]],
#
#        [[205, 782]],
#
#        [[207, 780]],
#
#        [[207, 778]],
#
#        [[209, 776]],
#
#        [[209, 774]]], dtype=int32), array([[[302, 773]],
#
#        [[302, 776]]], dtype=int32), array([[[211, 772]]], dtype=int32), array([[[ 79, 771]]], dtype=int32), array([[[144, 768]],
#
#        [[141, 771]],
#
#        [[141, 773]],
#
#        [[140, 774]],
#
#        [[140, 775]],
#
#        [[138, 777]],
#
#        [[138, 779]],
#
#        [[139, 778]],
#
#        [[140, 779]],
#
#        [[140, 777]],
#
#        [[141, 776]],
#
#        [[141, 774]],
#
#        [[142, 773]],
#
#        [[142, 772]],
#
#        [[143, 771]],
#
#        [[143, 769]]], dtype=int32), array([[[ 82, 768]]], dtype=int32), array([[[149, 767]]], dtype=int32), array([[[235, 765]]], dtype=int32), array([[[244, 763]],
#
#        [[243, 764]],
#
#        [[243, 766]],
#
#        [[243, 765]],
#
#        [[244, 764]]], dtype=int32), array([[[146, 762]]], dtype=int32), array([[[309, 760]],
#
#        [[309, 761]]], dtype=int32), array([[[146, 756]],
#
#        [[146, 757]]], dtype=int32), array([[[204, 754]],
#
#        [[204, 755]],
#
#        [[203, 756]],
#
#        [[201, 756]],
#
#        [[196, 761]],
#
#        [[196, 762]],
#
#        [[194, 764]],
#
#        [[194, 765]],
#
#        [[191, 768]],
#
#        [[191, 769]],
#
#        [[190, 770]],
#
#        [[190, 771]],
#
#        [[189, 772]],
#
#        [[189, 773]],
#
#        [[187, 775]],
#
#        [[187, 776]],
#
#        [[186, 777]],
#
#        [[186, 778]],
#
#        [[185, 779]],
#
#        [[185, 781]],
#
#        [[184, 782]],
#
#        [[184, 785]],
#
#        [[185, 786]],
#
#        [[182, 789]],
#
#        [[182, 793]],
#
#        [[181, 794]],
#
#        [[181, 797]],
#
#        [[182, 796]],
#
#        [[182, 795]],
#
#        [[184, 793]],
#
#        [[185, 794]],
#
#        [[187, 792]],
#
#        [[186, 791]],
#
#        [[186, 790]],
#
#        [[187, 789]],
#
#        [[186, 788]],
#
#        [[187, 787]],
#
#        [[188, 787]],
#
#        [[188, 786]],
#
#        [[189, 785]],
#
#        [[190, 785]],
#
#        [[190, 783]],
#
#        [[193, 780]],
#
#        [[193, 779]],
#
#        [[194, 778]],
#
#        [[194, 777]],
#
#        [[195, 776]],
#
#        [[194, 777]],
#
#        [[192, 777]],
#
#        [[192, 778]],
#
#        [[191, 779]],
#
#        [[190, 779]],
#
#        [[189, 778]],
#
#        [[189, 777]],
#
#        [[195, 771]],
#
#        [[195, 770]],
#
#        [[196, 769]],
#
#        [[196, 768]],
#
#        [[197, 767]],
#
#        [[198, 767]],
#
#        [[200, 765]],
#
#        [[200, 762]],
#
#        [[201, 761]],
#
#        [[201, 758]],
#
#        [[202, 757]],
#
#        [[203, 758]],
#
#        [[203, 759]],
#
#        [[203, 758]],
#
#        [[204, 757]],
#
#        [[204, 755]],
#
#        [[205, 754]]], dtype=int32), array([[[185, 792]],
#
#        [[186, 791]],
#
#        [[187, 792]],
#
#        [[186, 793]]], dtype=int32), array([[[182, 791]],
#
#        [[183, 790]],
#
#        [[184, 791]],
#
#        [[183, 792]]], dtype=int32), array([[[184, 790]],
#
#        [[185, 789]],
#
#        [[186, 790]],
#
#        [[185, 791]]], dtype=int32), array([[[186, 782]],
#
#        [[188, 782]],
#
#        [[189, 783]],
#
#        [[188, 784]],
#
#        [[187, 784]],
#
#        [[185, 786]],
#
#        [[184, 785]],
#
#        [[184, 784]]], dtype=int32), array([[[191, 779]],
#
#        [[192, 778]],
#
#        [[193, 779]],
#
#        [[192, 780]]], dtype=int32), array([[[188, 778]],
#
#        [[189, 778]],
#
#        [[190, 779]],
#
#        [[187, 782]],
#
#        [[186, 782]],
#
#        [[185, 781]]], dtype=int32), array([[[148, 753]],
#
#        [[148, 755]],
#
#        [[149, 754]]], dtype=int32), array([[[250, 752]],
#
#        [[250, 755]],
#
#        [[249, 756]],
#
#        [[250, 757]],
#
#        [[249, 758]],
#
#        [[249, 761]],
#
#        [[249, 759]],
#
#        [[251, 757]],
#
#        [[251, 756]],
#
#        [[250, 755]],
#
#        [[251, 754]],
#
#        [[250, 753]]], dtype=int32), array([[[191, 748]],
#
#        [[191, 749]],
#
#        [[190, 750]],
#
#        [[190, 751]],
#
#        [[189, 752]],
#
#        [[190, 751]],
#
#        [[190, 750]],
#
#        [[191, 749]]], dtype=int32), array([[[242, 745]]], dtype=int32), array([[[207, 743]]], dtype=int32), array([[[242, 740]],
#
#        [[242, 743]]], dtype=int32), array([[[196, 737]]], dtype=int32), array([[[280, 735]],
#
#        [[279, 736]],
#
#        [[279, 741]],
#
#        [[280, 742]]], dtype=int32), array([[[200, 735]],
#
#        [[200, 736]],
#
#        [[199, 737]],
#
#        [[199, 738]],
#
#        [[197, 740]],
#
#        [[197, 741]],
#
#        [[196, 742]],
#
#        [[196, 745]],
#
#        [[194, 747]],
#
#        [[194, 749]],
#
#        [[192, 751]],
#
#        [[192, 752]],
#
#        [[190, 754]],
#
#        [[190, 756]],
#
#        [[189, 757]],
#
#        [[189, 758]],
#
#        [[188, 759]],
#
#        [[188, 760]],
#
#        [[185, 763]],
#
#        [[185, 765]],
#
#        [[183, 767]],
#
#        [[182, 766]],
#
#        [[182, 765]],
#
#        [[182, 766]],
#
#        [[179, 769]],
#
#        [[179, 771]],
#
#        [[177, 773]],
#
#        [[177, 774]],
#
#        [[176, 775]],
#
#        [[176, 777]],
#
#        [[174, 779]],
#
#        [[174, 780]],
#
#        [[173, 781]],
#
#        [[173, 782]],
#
#        [[172, 783]],
#
#        [[172, 784]],
#
#        [[171, 785]],
#
#        [[171, 786]],
#
#        [[170, 787]],
#
#        [[170, 788]],
#
#        [[169, 789]],
#
#        [[170, 789]],
#
#        [[171, 788]],
#
#        [[171, 787]],
#
#        [[174, 784]],
#
#        [[174, 783]],
#
#        [[177, 780]],
#
#        [[177, 777]],
#
#        [[178, 776]],
#
#        [[178, 775]],
#
#        [[179, 774]],
#
#        [[179, 773]],
#
#        [[180, 772]],
#
#        [[180, 771]],
#
#        [[181, 770]],
#
#        [[181, 768]],
#
#        [[182, 767]],
#
#        [[183, 767]],
#
#        [[187, 763]],
#
#        [[187, 762]],
#
#        [[188, 761]],
#
#        [[188, 760]],
#
#        [[191, 757]],
#
#        [[191, 754]],
#
#        [[194, 751]],
#
#        [[194, 750]],
#
#        [[195, 749]],
#
#        [[195, 748]],
#
#        [[196, 747]],
#
#        [[196, 746]],
#
#        [[197, 745]],
#
#        [[197, 744]],
#
#        [[198, 743]],
#
#        [[198, 742]],
#
#        [[197, 741]],
#
#        [[199, 739]],
#
#        [[199, 737]],
#
#        [[200, 736]]], dtype=int32), array([[[277, 731]],
#
#        [[278, 732]],
#
#        [[278, 734]],
#
#        [[278, 732]]], dtype=int32), array([[[180, 731]],
#
#        [[180, 732]],
#
#        [[179, 733]],
#
#        [[179, 734]],
#
#        [[178, 735]],
#
#        [[178, 737]],
#
#        [[177, 738]],
#
#        [[177, 739]],
#
#        [[177, 738]],
#
#        [[178, 737]],
#
#        [[178, 736]],
#
#        [[179, 735]],
#
#        [[179, 734]],
#
#        [[180, 733]]], dtype=int32), array([[[199, 729]],
#
#        [[199, 730]],
#
#        [[198, 731]],
#
#        [[198, 735]],
#
#        [[198, 734]],
#
#        [[199, 733]],
#
#        [[199, 731]],
#
#        [[200, 730]],
#
#        [[200, 729]]], dtype=int32), array([[[276, 728]],
#
#        [[276, 729]]], dtype=int32), array([[[180, 727]]], dtype=int32), array([[[285, 725]],
#
#        [[286, 725]]], dtype=int32), array([[[209, 723]],
#
#        [[209, 726]]], dtype=int32), array([[[274, 722]],
#
#        [[274, 723]]], dtype=int32), array([[[259, 719]]], dtype=int32), array([[[119, 719]]], dtype=int32), array([[[253, 718]],
#
#        [[253, 720]],
#
#        [[254, 721]],
#
#        [[254, 722]],
#
#        [[254, 720]],
#
#        [[255, 719]],
#
#        [[254, 720]],
#
#        [[253, 719]]], dtype=int32), array([[[202, 718]]], dtype=int32), array([[[257, 717]]], dtype=int32), array([[[285, 714]],
#
#        [[285, 715]],
#
#        [[284, 716]],
#
#        [[286, 718]],
#
#        [[286, 721]],
#
#        [[287, 722]],
#
#        [[287, 723]],
#
#        [[288, 724]],
#
#        [[288, 725]],
#
#        [[289, 726]],
#
#        [[289, 730]],
#
#        [[290, 731]],
#
#        [[290, 735]],
#
#        [[291, 736]],
#
#        [[291, 739]],
#
#        [[292, 740]],
#
#        [[292, 742]],
#
#        [[293, 743]],
#
#        [[293, 749]],
#
#        [[295, 751]],
#
#        [[295, 754]],
#
#        [[294, 755]],
#
#        [[296, 757]],
#
#        [[295, 758]],
#
#        [[295, 759]],
#
#        [[296, 760]],
#
#        [[296, 766]],
#
#        [[297, 767]],
#
#        [[296, 768]],
#
#        [[297, 769]],
#
#        [[297, 772]],
#
#        [[297, 769]],
#
#        [[298, 768]],
#
#        [[298, 765]],
#
#        [[297, 764]],
#
#        [[297, 763]],
#
#        [[298, 762]],
#
#        [[298, 759]],
#
#        [[297, 758]],
#
#        [[297, 749]],
#
#        [[296, 748]],
#
#        [[296, 746]],
#
#        [[295, 745]],
#
#        [[295, 738]],
#
#        [[294, 737]],
#
#        [[294, 736]],
#
#        [[293, 735]],
#
#        [[293, 733]],
#
#        [[292, 732]],
#
#        [[292, 730]],
#
#        [[291, 729]],
#
#        [[291, 727]],
#
#        [[290, 726]],
#
#        [[290, 723]],
#
#        [[289, 723]],
#
#        [[288, 722]],
#
#        [[288, 719]],
#
#        [[287, 719]],
#
#        [[286, 718]],
#
#        [[286, 715]]], dtype=int32), array([[[296, 766]],
#
#        [[297, 765]],
#
#        [[298, 766]],
#
#        [[297, 767]]], dtype=int32), array([[[180, 714]],
#
#        [[180, 718]],
#
#        [[179, 719]],
#
#        [[179, 723]],
#
#        [[179, 719]],
#
#        [[180, 718]],
#
#        [[181, 719]],
#
#        [[181, 714]]], dtype=int32), array([[[280, 713]]], dtype=int32), array([[[281, 711]],
#
#        [[283, 713]],
#
#        [[283, 714]],
#
#        [[283, 712]],
#
#        [[282, 711]]], dtype=int32), array([[[159, 711]],
#
#        [[159, 715]],
#
#        [[158, 716]],
#
#        [[158, 719]],
#
#        [[159, 720]],
#
#        [[159, 723]],
#
#        [[158, 724]],
#
#        [[158, 725]],
#
#        [[157, 726]],
#
#        [[156, 726]],
#
#        [[156, 727]],
#
#        [[157, 728]],
#
#        [[156, 729]],
#
#        [[155, 729]],
#
#        [[155, 732]],
#
#        [[154, 733]],
#
#        [[154, 735]],
#
#        [[153, 736]],
#
#        [[153, 739]],
#
#        [[152, 740]],
#
#        [[152, 741]],
#
#        [[151, 742]],
#
#        [[152, 741]],
#
#        [[153, 742]],
#
#        [[153, 743]],
#
#        [[152, 744]],
#
#        [[152, 745]],
#
#        [[150, 747]],
#
#        [[150, 749]],
#
#        [[148, 751]],
#
#        [[149, 750]],
#
#        [[150, 751]],
#
#        [[150, 752]],
#
#        [[151, 751]],
#
#        [[151, 750]],
#
#        [[154, 747]],
#
#        [[154, 745]],
#
#        [[156, 743]],
#
#        [[155, 742]],
#
#        [[156, 741]],
#
#        [[156, 739]],
#
#        [[158, 737]],
#
#        [[158, 736]],
#
#        [[159, 735]],
#
#        [[159, 733]],
#
#        [[160, 732]],
#
#        [[160, 728]],
#
#        [[161, 727]],
#
#        [[161, 726]],
#
#        [[162, 725]],
#
#        [[161, 724]],
#
#        [[161, 720]],
#
#        [[162, 719]],
#
#        [[162, 718]],
#
#        [[161, 717]],
#
#        [[161, 716]],
#
#        [[162, 715]],
#
#        [[162, 712]],
#
#        [[162, 713]],
#
#        [[161, 714]],
#
#        [[160, 713]],
#
#        [[160, 712]]], dtype=int32), array([[[150, 748]],
#
#        [[151, 747]],
#
#        [[152, 748]],
#
#        [[151, 749]]], dtype=int32), array([[[157, 731]],
#
#        [[158, 730]],
#
#        [[159, 731]],
#
#        [[159, 732]],
#
#        [[158, 733]],
#
#        [[157, 732]]], dtype=int32), array([[[158, 719]],
#
#        [[159, 718]],
#
#        [[160, 719]],
#
#        [[159, 720]]], dtype=int32), array([[[152, 710]],
#
#        [[152, 711]],
#
#        [[151, 712]],
#
#        [[151, 714]],
#
#        [[150, 715]],
#
#        [[150, 718]],
#
#        [[149, 719]],
#
#        [[149, 727]],
#
#        [[149, 722]],
#
#        [[150, 721]],
#
#        [[150, 717]],
#
#        [[151, 716]],
#
#        [[151, 712]],
#
#        [[152, 711]]], dtype=int32), array([[[252, 709]]], dtype=int32), array([[[201, 709]],
#
#        [[202, 710]],
#
#        [[202, 714]],
#
#        [[202, 709]]], dtype=int32), array([[[255, 707]],
#
#        [[255, 708]],
#
#        [[254, 709]],
#
#        [[254, 710]],
#
#        [[253, 711]],
#
#        [[252, 711]],
#
#        [[252, 712]],
#
#        [[254, 710]],
#
#        [[255, 711]],
#
#        [[255, 713]],
#
#        [[256, 714]],
#
#        [[256, 711]],
#
#        [[255, 710]]], dtype=int32), array([[[160, 707]],
#
#        [[160, 709]]], dtype=int32), array([[[253, 705]],
#
#        [[253, 706]]], dtype=int32), array([[[251, 705]],
#
#        [[251, 707]],
#
#        [[250, 708]],
#
#        [[251, 707]]], dtype=int32), array([[[312, 701]],
#
#        [[312, 703]],
#
#        [[313, 704]],
#
#        [[313, 706]],
#
#        [[313, 704]],
#
#        [[312, 703]]], dtype=int32), array([[[311, 698]]], dtype=int32), array([[[246, 696]],
#
#        [[246, 699]],
#
#        [[247, 700]],
#
#        [[247, 701]],
#
#        [[248, 700]],
#
#        [[249, 701]],
#
#        [[249, 704]],
#
#        [[249, 703]],
#
#        [[250, 702]],
#
#        [[250, 701]],
#
#        [[249, 700]],
#
#        [[249, 699]],
#
#        [[248, 698]],
#
#        [[248, 697]],
#
#        [[247, 697]]], dtype=int32), array([[[309, 694]],
#
#        [[309, 695]]], dtype=int32), array([[[244, 692]]], dtype=int32), array([[[307, 688]],
#
#        [[307, 689]]], dtype=int32), array([[[280, 608]],
#
#        [[280, 609]]], dtype=int32), array([[[273, 607]]], dtype=int32), array([[[118, 607]],
#
#        [[119, 608]],
#
#        [[119, 610]],
#
#        [[120, 611]],
#
#        [[119, 610]],
#
#        [[119, 607]]], dtype=int32), array([[[281, 606]]], dtype=int32), array([[[274, 603]],
#
#        [[274, 604]]], dtype=int32), array([[[116, 603]]], dtype=int32), array([[[122, 602]]], dtype=int32), array([[[276, 596]],
#
#        [[276, 598]],
#
#        [[275, 599]],
#
#        [[275, 601]],
#
#        [[275, 599]],
#
#        [[276, 598]]], dtype=int32), array([[[290, 595]],
#
#        [[290, 596]]], dtype=int32), array([[[277, 594]]], dtype=int32), array([[[291, 592]],
#
#        [[291, 593]]], dtype=int32), array([[[295, 589]],
#
#        [[295, 590]],
#
#        [[294, 591]],
#
#        [[294, 592]],
#
#        [[293, 593]],
#
#        [[293, 596]],
#
#        [[290, 599]],
#
#        [[290, 601]],
#
#        [[289, 602]],
#
#        [[289, 603]],
#
#        [[288, 604]],
#
#        [[288, 606]],
#
#        [[287, 607]],
#
#        [[287, 611]],
#
#        [[286, 612]],
#
#        [[286, 617]],
#
#        [[285, 618]],
#
#        [[285, 619]],
#
#        [[284, 620]],
#
#        [[283, 619]],
#
#        [[283, 618]],
#
#        [[283, 620]],
#
#        [[284, 621]],
#
#        [[284, 622]],
#
#        [[285, 623]],
#
#        [[285, 625]],
#
#        [[286, 625]],
#
#        [[287, 626]],
#
#        [[287, 627]],
#
#        [[286, 628]],
#
#        [[287, 627]],
#
#        [[288, 627]],
#
#        [[289, 628]],
#
#        [[289, 629]],
#
#        [[288, 630]],
#
#        [[290, 632]],
#
#        [[290, 633]],
#
#        [[292, 635]],
#
#        [[293, 635]],
#
#        [[296, 638]],
#
#        [[296, 641]],
#
#        [[297, 642]],
#
#        [[297, 643]],
#
#        [[300, 646]],
#
#        [[300, 647]],
#
#        [[301, 648]],
#
#        [[301, 650]],
#
#        [[302, 650]],
#
#        [[303, 651]],
#
#        [[303, 648]],
#
#        [[304, 647]],
#
#        [[304, 636]],
#
#        [[305, 635]],
#
#        [[305, 626]],
#
#        [[304, 625]],
#
#        [[304, 619]],
#
#        [[303, 618]],
#
#        [[303, 613]],
#
#        [[302, 613]],
#
#        [[301, 612]],
#
#        [[301, 609]],
#
#        [[302, 608]],
#
#        [[301, 607]],
#
#        [[301, 605]],
#
#        [[300, 604]],
#
#        [[300, 602]],
#
#        [[298, 600]],
#
#        [[299, 599]],
#
#        [[298, 600]],
#
#        [[297, 599]],
#
#        [[297, 594]],
#
#        [[296, 593]],
#
#        [[295, 594]],
#
#        [[294, 593]],
#
#        [[294, 592]],
#
#        [[295, 591]],
#
#        [[296, 591]],
#
#        [[296, 590]]], dtype=int32), array([[[289, 631]],
#
#        [[290, 630]],
#
#        [[291, 631]],
#
#        [[290, 632]]], dtype=int32), array([[[296, 610]],
#
#        [[297, 609]],
#
#        [[298, 610]],
#
#        [[297, 611]]], dtype=int32), array([[[291, 609]],
#
#        [[292, 608]],
#
#        [[293, 609]],
#
#        [[293, 610]],
#
#        [[292, 611]],
#
#        [[291, 610]]], dtype=int32), array([[[296, 607]],
#
#        [[297, 606]],
#
#        [[298, 607]],
#
#        [[297, 608]]], dtype=int32), array([[[295, 606]],
#
#        [[296, 605]],
#
#        [[297, 606]],
#
#        [[296, 607]]], dtype=int32), array([[[291, 606]],
#
#        [[292, 605]],
#
#        [[293, 606]],
#
#        [[292, 607]]], dtype=int32), array([[[298, 604]],
#
#        [[299, 603]],
#
#        [[300, 604]],
#
#        [[300, 605]],
#
#        [[299, 606]],
#
#        [[298, 605]]], dtype=int32), array([[[296, 604]],
#
#        [[297, 603]],
#
#        [[298, 604]],
#
#        [[298, 605]],
#
#        [[297, 606]],
#
#        [[296, 605]]], dtype=int32), array([[[294, 602]],
#
#        [[295, 601]],
#
#        [[296, 602]],
#
#        [[295, 603]]], dtype=int32), array([[[295, 600]],
#
#        [[296, 599]],
#
#        [[297, 599]],
#
#        [[298, 600]],
#
#        [[298, 602]],
#
#        [[297, 603]],
#
#        [[295, 601]]], dtype=int32), array([[[292, 597]],
#
#        [[293, 596]],
#
#        [[294, 597]],
#
#        [[293, 598]]], dtype=int32), array([[[278, 586]],
#
#        [[278, 589]],
#
#        [[277, 590]],
#
#        [[277, 591]],
#
#        [[278, 591]]], dtype=int32), array([[[294, 585]],
#
#        [[294, 586]]], dtype=int32), array([[[279, 575]],
#
#        [[279, 584]]], dtype=int32), array([[[279, 571]],
#
#        [[279, 573]]], dtype=int32), array([[[253, 562]],
#
#        [[253, 563]]], dtype=int32), array([[[254, 559]]], dtype=int32), array([[[248, 558]]], dtype=int32), array([[[255, 553]],
#
#        [[255, 554]]], dtype=int32), array([[[295, 547]],
#
#        [[295, 548]]], dtype=int32), array([[[267, 546]],
#
#        [[267, 548]],
#
#        [[268, 549]],
#
#        [[268, 551]],
#
#        [[267, 552]],
#
#        [[266, 551]],
#
#        [[267, 552]],
#
#        [[267, 557]],
#
#        [[266, 558]],
#
#        [[265, 557]],
#
#        [[265, 553]],
#
#        [[264, 554]],
#
#        [[264, 561]],
#
#        [[263, 562]],
#
#        [[262, 562]],
#
#        [[262, 563]],
#
#        [[263, 562]],
#
#        [[264, 563]],
#
#        [[264, 565]],
#
#        [[263, 566]],
#
#        [[263, 570]],
#
#        [[262, 571]],
#
#        [[261, 570]],
#
#        [[261, 568]],
#
#        [[260, 567]],
#
#        [[259, 567]],
#
#        [[258, 566]],
#
#        [[257, 566]],
#
#        [[258, 567]],
#
#        [[256, 569]],
#
#        [[256, 571]],
#
#        [[255, 572]],
#
#        [[255, 581]],
#
#        [[256, 582]],
#
#        [[256, 583]],
#
#        [[257, 584]],
#
#        [[257, 585]],
#
#        [[260, 588]],
#
#        [[260, 589]],
#
#        [[261, 590]],
#
#        [[261, 591]],
#
#        [[265, 595]],
#
#        [[265, 596]],
#
#        [[266, 597]],
#
#        [[266, 598]],
#
#        [[268, 600]],
#
#        [[268, 602]],
#
#        [[271, 605]],
#
#        [[271, 602]],
#
#        [[272, 601]],
#
#        [[272, 599]],
#
#        [[273, 598]],
#
#        [[273, 594]],
#
#        [[274, 593]],
#
#        [[274, 592]],
#
#        [[275, 591]],
#
#        [[275, 584]],
#
#        [[276, 583]],
#
#        [[275, 584]],
#
#        [[274, 583]],
#
#        [[274, 581]],
#
#        [[275, 580]],
#
#        [[275, 578]],
#
#        [[276, 577]],
#
#        [[275, 576]],
#
#        [[276, 575]],
#
#        [[275, 574]],
#
#        [[275, 573]],
#
#        [[276, 572]],
#
#        [[276, 569]],
#
#        [[275, 568]],
#
#        [[275, 566]],
#
#        [[276, 565]],
#
#        [[276, 564]],
#
#        [[275, 563]],
#
#        [[275, 568]],
#
#        [[276, 569]],
#
#        [[274, 571]],
#
#        [[274, 573]],
#
#        [[273, 574]],
#
#        [[272, 573]],
#
#        [[272, 570]],
#
#        [[273, 569]],
#
#        [[273, 562]],
#
#        [[274, 561]],
#
#        [[274, 560]],
#
#        [[275, 559]],
#
#        [[274, 558]],
#
#        [[274, 556]],
#
#        [[273, 555]],
#
#        [[273, 554]],
#
#        [[271, 552]],
#
#        [[271, 551]],
#
#        [[268, 548]],
#
#        [[268, 547]]], dtype=int32), array([[[267, 599]],
#
#        [[268, 598]],
#
#        [[269, 599]],
#
#        [[268, 600]]], dtype=int32), array([[[270, 598]],
#
#        [[271, 597]],
#
#        [[272, 598]],
#
#        [[272, 599]],
#
#        [[271, 600]],
#
#        [[270, 599]]], dtype=int32), array([[[268, 597]],
#
#        [[269, 596]],
#
#        [[270, 597]],
#
#        [[270, 598]],
#
#        [[269, 599]],
#
#        [[268, 598]]], dtype=int32), array([[[270, 592]],
#
#        [[271, 591]],
#
#        [[272, 592]],
#
#        [[272, 594]],
#
#        [[271, 595]],
#
#        [[270, 594]]], dtype=int32), array([[[264, 590]],
#
#        [[265, 589]],
#
#        [[266, 590]],
#
#        [[266, 591]],
#
#        [[265, 592]],
#
#        [[264, 591]]], dtype=int32), array([[[273, 587]],
#
#        [[274, 588]],
#
#        [[274, 589]],
#
#        [[273, 590]],
#
#        [[273, 591]],
#
#        [[272, 592]],
#
#        [[271, 591]],
#
#        [[271, 589]]], dtype=int32), array([[[263, 586]],
#
#        [[264, 585]],
#
#        [[265, 586]],
#
#        [[264, 587]]], dtype=int32), array([[[273, 585]],
#
#        [[274, 584]],
#
#        [[275, 585]],
#
#        [[275, 586]],
#
#        [[274, 587]],
#
#        [[273, 586]]], dtype=int32), array([[[259, 584]],
#
#        [[260, 583]],
#
#        [[261, 584]],
#
#        [[260, 585]]], dtype=int32), array([[[271, 580]],
#
#        [[272, 579]],
#
#        [[273, 580]],
#
#        [[273, 583]],
#
#        [[272, 584]],
#
#        [[271, 583]]], dtype=int32), array([[[261, 577]],
#
#        [[262, 576]],
#
#        [[263, 577]],
#
#        [[262, 578]]], dtype=int32), array([[[271, 575]],
#
#        [[272, 574]],
#
#        [[273, 575]],
#
#        [[272, 576]]], dtype=int32), array([[[260, 573]],
#
#        [[261, 572]],
#
#        [[262, 573]],
#
#        [[262, 575]],
#
#        [[261, 576]],
#
#        [[260, 575]]], dtype=int32), array([[[262, 571]],
#
#        [[263, 570]],
#
#        [[264, 571]],
#
#        [[264, 572]],
#
#        [[263, 573]],
#
#        [[262, 572]]], dtype=int32), array([[[256, 570]],
#
#        [[257, 569]],
#
#        [[258, 570]],
#
#        [[257, 571]]], dtype=int32), array([[[259, 568]],
#
#        [[260, 567]],
#
#        [[261, 568]],
#
#        [[261, 569]],
#
#        [[260, 570]],
#
#        [[259, 569]]], dtype=int32), array([[[257, 568]],
#
#        [[258, 567]],
#
#        [[259, 568]],
#
#        [[258, 569]]], dtype=int32), array([[[268, 557]],
#
#        [[269, 556]],
#
#        [[270, 557]],
#
#        [[269, 558]]], dtype=int32), array([[[267, 552]],
#
#        [[268, 551]],
#
#        [[269, 552]],
#
#        [[269, 553]],
#
#        [[268, 554]],
#
#        [[267, 553]]], dtype=int32), array([[[255, 546]],
#
#        [[255, 548]]], dtype=int32), array([[[247, 543]],
#
#        [[247, 545]]], dtype=int32), array([[[102, 541]],
#
#        [[102, 547]],
#
#        [[103, 548]],
#
#        [[103, 545]],
#
#        [[102, 544]],
#
#        [[102, 543]],
#
#        [[103, 542]]], dtype=int32), array([[[294, 535]],
#
#        [[293, 536]],
#
#        [[294, 537]]], dtype=int32), array([[[251, 534]],
#
#        [[251, 540]],
#
#        [[250, 541]],
#
#        [[251, 542]],
#
#        [[251, 543]],
#
#        [[250, 544]],
#
#        [[249, 544]],
#
#        [[249, 552]],
#
#        [[249, 550]],
#
#        [[251, 548]],
#
#        [[252, 549]],
#
#        [[252, 551]],
#
#        [[251, 552]],
#
#        [[251, 553]],
#
#        [[249, 555]],
#
#        [[249, 556]],
#
#        [[250, 557]],
#
#        [[250, 554]],
#
#        [[251, 553]],
#
#        [[251, 552]],
#
#        [[252, 551]],
#
#        [[252, 548]],
#
#        [[251, 547]],
#
#        [[251, 543]],
#
#        [[252, 542]],
#
#        [[253, 543]],
#
#        [[253, 546]],
#
#        [[253, 541]],
#
#        [[254, 540]],
#
#        [[254, 538]],
#
#        [[253, 538]],
#
#        [[252, 537]],
#
#        [[252, 536]],
#
#        [[251, 535]],
#
#        [[252, 534]]], dtype=int32), array([[[103, 533]],
#
#        [[103, 537]]], dtype=int32), array([[[253, 532]]], dtype=int32), array([[[292, 530]],
#
#        [[292, 533]]], dtype=int32), array([[[126, 522]]], dtype=int32), array([[[ 99, 521]],
#
#        [[ 99, 530]],
#
#        [[ 98, 531]],
#
#        [[ 98, 549]],
#
#        [[ 99, 550]],
#
#        [[ 99, 554]],
#
#        [[100, 555]],
#
#        [[100, 562]],
#
#        [[101, 563]],
#
#        [[101, 566]],
#
#        [[101, 562]],
#
#        [[100, 561]],
#
#        [[100, 552]],
#
#        [[ 99, 551]],
#
#        [[ 99, 535]],
#
#        [[100, 534]],
#
#        [[100, 521]]], dtype=int32), array([[[129, 520]]], dtype=int32), array([[[127, 520]]], dtype=int32), array([[[246, 518]]], dtype=int32), array([[[124, 516]]], dtype=int32), array([[[581, 495]]], dtype=int32), array([[[288, 493]]], dtype=int32), array([[[297, 490]],
#
#        [[296, 491]],
#
#        [[297, 491]]], dtype=int32), array([[[296, 485]],
#
#        [[296, 487]],
#
#        [[297, 487]],
#
#        [[298, 488]],
#
#        [[297, 487]],
#
#        [[297, 486]]], dtype=int32), array([[[291, 481]],
#
#        [[291, 482]],
#
#        [[293, 484]],
#
#        [[292, 485]],
#
#        [[292, 486]],
#
#        [[293, 485]],
#
#        [[293, 484]],
#
#        [[292, 483]],
#
#        [[292, 482]]], dtype=int32), array([[[564, 463]]], dtype=int32), array([[[141, 451]],
#
#        [[140, 452]],
#
#        [[140, 453]],
#
#        [[139, 454]],
#
#        [[139, 455]],
#
#        [[137, 457]],
#
#        [[137, 458]],
#
#        [[134, 461]],
#
#        [[133, 460]],
#
#        [[133, 459]],
#
#        [[134, 458]],
#
#        [[133, 458]],
#
#        [[133, 459]],
#
#        [[131, 461]],
#
#        [[131, 463]],
#
#        [[132, 464]],
#
#        [[132, 466]],
#
#        [[131, 467]],
#
#        [[130, 466]],
#
#        [[130, 465]],
#
#        [[130, 467]],
#
#        [[129, 468]],
#
#        [[129, 469]],
#
#        [[127, 471]],
#
#        [[126, 470]],
#
#        [[126, 469]],
#
#        [[127, 468]],
#
#        [[127, 466]],
#
#        [[128, 465]],
#
#        [[128, 463]],
#
#        [[128, 464]],
#
#        [[127, 465]],
#
#        [[127, 467]],
#
#        [[126, 468]],
#
#        [[126, 469]],
#
#        [[124, 471]],
#
#        [[124, 472]],
#
#        [[123, 473]],
#
#        [[123, 475]],
#
#        [[122, 476]],
#
#        [[122, 477]],
#
#        [[121, 478]],
#
#        [[121, 480]],
#
#        [[120, 481]],
#
#        [[120, 484]],
#
#        [[119, 485]],
#
#        [[118, 485]],
#
#        [[117, 484]],
#
#        [[117, 491]],
#
#        [[116, 492]],
#
#        [[115, 492]],
#
#        [[115, 495]],
#
#        [[113, 497]],
#
#        [[113, 499]],
#
#        [[112, 500]],
#
#        [[112, 505]],
#
#        [[111, 506]],
#
#        [[111, 511]],
#
#        [[110, 512]],
#
#        [[110, 515]],
#
#        [[111, 516]],
#
#        [[110, 517]],
#
#        [[110, 518]],
#
#        [[109, 519]],
#
#        [[109, 525]],
#
#        [[108, 526]],
#
#        [[108, 533]],
#
#        [[107, 534]],
#
#        [[107, 546]],
#
#        [[108, 547]],
#
#        [[108, 549]],
#
#        [[107, 550]],
#
#        [[108, 551]],
#
#        [[108, 552]],
#
#        [[110, 554]],
#
#        [[110, 555]],
#
#        [[109, 556]],
#
#        [[108, 556]],
#
#        [[107, 555]],
#
#        [[107, 554]],
#
#        [[106, 555]],
#
#        [[105, 554]],
#
#        [[105, 560]],
#
#        [[106, 561]],
#
#        [[106, 569]],
#
#        [[107, 570]],
#
#        [[107, 574]],
#
#        [[108, 575]],
#
#        [[108, 578]],
#
#        [[109, 579]],
#
#        [[109, 582]],
#
#        [[110, 583]],
#
#        [[110, 584]],
#
#        [[112, 586]],
#
#        [[112, 587]],
#
#        [[113, 587]],
#
#        [[115, 589]],
#
#        [[115, 590]],
#
#        [[116, 591]],
#
#        [[115, 592]],
#
#        [[117, 594]],
#
#        [[117, 595]],
#
#        [[118, 596]],
#
#        [[118, 598]],
#
#        [[119, 599]],
#
#        [[119, 600]],
#
#        [[119, 599]],
#
#        [[118, 598]],
#
#        [[118, 597]],
#
#        [[119, 596]],
#
#        [[120, 597]],
#
#        [[120, 592]],
#
#        [[119, 591]],
#
#        [[120, 590]],
#
#        [[120, 588]],
#
#        [[119, 587]],
#
#        [[120, 586]],
#
#        [[120, 585]],
#
#        [[121, 584]],
#
#        [[120, 583]],
#
#        [[120, 578]],
#
#        [[120, 579]],
#
#        [[119, 580]],
#
#        [[119, 581]],
#
#        [[120, 582]],
#
#        [[119, 583]],
#
#        [[120, 584]],
#
#        [[120, 586]],
#
#        [[119, 587]],
#
#        [[118, 586]],
#
#        [[118, 585]],
#
#        [[117, 585]],
#
#        [[117, 586]],
#
#        [[116, 587]],
#
#        [[115, 586]],
#
#        [[115, 580]],
#
#        [[116, 579]],
#
#        [[116, 576]],
#
#        [[117, 575]],
#
#        [[117, 572]],
#
#        [[118, 571]],
#
#        [[118, 570]],
#
#        [[117, 569]],
#
#        [[118, 568]],
#
#        [[118, 567]],
#
#        [[119, 566]],
#
#        [[119, 565]],
#
#        [[118, 565]],
#
#        [[117, 564]],
#
#        [[117, 563]],
#
#        [[119, 561]],
#
#        [[120, 561]],
#
#        [[120, 560]],
#
#        [[119, 559]],
#
#        [[119, 556]],
#
#        [[120, 555]],
#
#        [[121, 556]],
#
#        [[122, 555]],
#
#        [[121, 555]],
#
#        [[119, 553]],
#
#        [[121, 551]],
#
#        [[121, 549]],
#
#        [[122, 548]],
#
#        [[122, 546]],
#
#        [[123, 545]],
#
#        [[124, 545]],
#
#        [[123, 545]],
#
#        [[122, 544]],
#
#        [[123, 543]],
#
#        [[123, 542]],
#
#        [[124, 541]],
#
#        [[124, 537]],
#
#        [[125, 536]],
#
#        [[125, 535]],
#
#        [[126, 534]],
#
#        [[126, 531]],
#
#        [[127, 530]],
#
#        [[127, 528]],
#
#        [[128, 527]],
#
#        [[128, 525]],
#
#        [[127, 524]],
#
#        [[126, 524]],
#
#        [[124, 526]],
#
#        [[123, 526]],
#
#        [[122, 525]],
#
#        [[123, 524]],
#
#        [[123, 523]],
#
#        [[124, 522]],
#
#        [[124, 520]],
#
#        [[126, 518]],
#
#        [[126, 516]],
#
#        [[127, 515]],
#
#        [[126, 516]],
#
#        [[126, 518]],
#
#        [[125, 519]],
#
#        [[123, 519]],
#
#        [[122, 518]],
#
#        [[122, 517]],
#
#        [[120, 517]],
#
#        [[119, 518]],
#
#        [[118, 517]],
#
#        [[118, 515]],
#
#        [[117, 516]],
#
#        [[116, 515]],
#
#        [[116, 514]],
#
#        [[117, 513]],
#
#        [[118, 513]],
#
#        [[120, 511]],
#
#        [[121, 511]],
#
#        [[122, 510]],
#
#        [[123, 510]],
#
#        [[125, 508]],
#
#        [[125, 507]],
#
#        [[126, 506]],
#
#        [[127, 506]],
#
#        [[128, 505]],
#
#        [[130, 505]],
#
#        [[131, 504]],
#
#        [[133, 504]],
#
#        [[134, 503]],
#
#        [[134, 502]],
#
#        [[136, 500]],
#
#        [[136, 499]],
#
#        [[140, 495]],
#
#        [[139, 494]],
#
#        [[140, 493]],
#
#        [[140, 491]],
#
#        [[144, 487]],
#
#        [[144, 485]],
#
#        [[147, 482]],
#
#        [[147, 480]],
#
#        [[147, 481]],
#
#        [[146, 482]],
#
#        [[145, 482]],
#
#        [[142, 485]],
#
#        [[141, 484]],
#
#        [[141, 483]],
#
#        [[147, 477]],
#
#        [[147, 472]],
#
#        [[148, 471]],
#
#        [[148, 470]],
#
#        [[149, 469]],
#
#        [[150, 470]],
#
#        [[150, 471]],
#
#        [[152, 471]],
#
#        [[152, 468]],
#
#        [[153, 467]],
#
#        [[153, 465]],
#
#        [[152, 464]],
#
#        [[151, 464]],
#
#        [[150, 465]],
#
#        [[149, 464]],
#
#        [[149, 458]],
#
#        [[148, 457]],
#
#        [[148, 455]],
#
#        [[147, 454]],
#
#        [[146, 454]],
#
#        [[145, 453]],
#
#        [[144, 453]],
#
#        [[143, 452]],
#
#        [[143, 454]],
#
#        [[141, 456]],
#
#        [[140, 455]],
#
#        [[140, 453]],
#
#        [[141, 452]]], dtype=int32), array([[[114, 588]],
#
#        [[115, 587]],
#
#        [[116, 588]],
#
#        [[115, 589]]], dtype=int32), array([[[111, 584]],
#
#        [[112, 583]],
#
#        [[113, 584]],
#
#        [[112, 585]]], dtype=int32), array([[[108, 570]],
#
#        [[109, 569]],
#
#        [[110, 570]],
#
#        [[110, 571]],
#
#        [[109, 572]],
#
#        [[108, 571]]], dtype=int32), array([[[116, 568]],
#
#        [[117, 567]],
#
#        [[118, 568]],
#
#        [[117, 569]]], dtype=int32), array([[[111, 567]],
#
#        [[112, 566]],
#
#        [[113, 567]],
#
#        [[112, 568]]], dtype=int32), array([[[113, 566]],
#
#        [[114, 565]],
#
#        [[115, 565]],
#
#        [[116, 566]],
#
#        [[115, 567]],
#
#        [[114, 567]]], dtype=int32), array([[[107, 566]],
#
#        [[108, 565]],
#
#        [[109, 566]],
#
#        [[109, 569]],
#
#        [[108, 570]],
#
#        [[107, 570]],
#
#        [[106, 569]],
#
#        [[106, 568]],
#
#        [[107, 567]]], dtype=int32), array([[[115, 565]],
#
#        [[116, 564]],
#
#        [[117, 565]],
#
#        [[116, 566]]], dtype=int32), array([[[111, 562]],
#
#        [[112, 561]],
#
#        [[113, 562]],
#
#        [[113, 564]],
#
#        [[112, 565]],
#
#        [[111, 564]]], dtype=int32), array([[[106, 562]],
#
#        [[107, 561]],
#
#        [[108, 562]],
#
#        [[108, 563]],
#
#        [[107, 564]],
#
#        [[106, 563]]], dtype=int32), array([[[109, 556]],
#
#        [[110, 555]],
#
#        [[111, 556]],
#
#        [[111, 558]],
#
#        [[113, 560]],
#
#        [[111, 562]],
#
#        [[110, 561]],
#
#        [[110, 560]],
#
#        [[109, 559]]], dtype=int32), array([[[113, 544]],
#
#        [[114, 543]],
#
#        [[115, 544]],
#
#        [[114, 545]]], dtype=int32), array([[[117, 536]],
#
#        [[118, 535]],
#
#        [[119, 536]],
#
#        [[118, 537]]], dtype=int32), array([[[123, 528]],
#
#        [[124, 527]],
#
#        [[125, 528]],
#
#        [[124, 529]]], dtype=int32), array([[[121, 526]],
#
#        [[122, 525]],
#
#        [[123, 526]],
#
#        [[122, 527]]], dtype=int32), array([[[115, 518]],
#
#        [[116, 517]],
#
#        [[117, 517]],
#
#        [[118, 518]],
#
#        [[117, 519]],
#
#        [[116, 519]]], dtype=int32), array([[[113, 512]],
#
#        [[114, 511]],
#
#        [[117, 511]],
#
#        [[118, 512]],
#
#        [[117, 513]],
#
#        [[115, 513]],
#
#        [[115, 514]],
#
#        [[116, 515]],
#
#        [[115, 516]],
#
#        [[114, 516]],
#
#        [[113, 515]],
#
#        [[113, 514]],
#
#        [[113, 517]],
#
#        [[112, 518]],
#
#        [[111, 517]],
#
#        [[111, 514]],
#
#        [[110, 513]],
#
#        [[111, 512]]], dtype=int32), array([[[120, 508]],
#
#        [[121, 507]],
#
#        [[122, 508]],
#
#        [[122, 510]],
#
#        [[121, 511]],
#
#        [[120, 510]]], dtype=int32), array([[[128, 502]],
#
#        [[129, 501]],
#
#        [[130, 502]],
#
#        [[130, 503]],
#
#        [[129, 504]],
#
#        [[128, 503]]], dtype=int32), array([[[129, 498]],
#
#        [[130, 497]],
#
#        [[131, 498]],
#
#        [[130, 499]]], dtype=int32), array([[[135, 492]],
#
#        [[136, 491]],
#
#        [[137, 492]],
#
#        [[136, 493]]], dtype=int32), array([[[137, 489]],
#
#        [[138, 488]],
#
#        [[139, 489]],
#
#        [[139, 490]],
#
#        [[138, 491]],
#
#        [[137, 490]]], dtype=int32), array([[[118, 489]],
#
#        [[119, 488]],
#
#        [[120, 489]],
#
#        [[120, 492]],
#
#        [[119, 493]],
#
#        [[118, 492]]], dtype=int32), array([[[131, 487]],
#
#        [[132, 486]],
#
#        [[133, 487]],
#
#        [[132, 488]]], dtype=int32), array([[[118, 487]],
#
#        [[119, 486]],
#
#        [[120, 487]],
#
#        [[119, 488]]], dtype=int32), array([[[127, 474]],
#
#        [[128, 473]],
#
#        [[129, 474]],
#
#        [[129, 475]],
#
#        [[128, 476]],
#
#        [[127, 475]]], dtype=int32), array([[[124, 474]],
#
#        [[125, 473]],
#
#        [[126, 474]],
#
#        [[126, 475]],
#
#        [[125, 476]],
#
#        [[124, 475]]], dtype=int32), array([[[128, 471]],
#
#        [[129, 470]],
#
#        [[130, 471]],
#
#        [[130, 472]],
#
#        [[129, 473]],
#
#        [[128, 472]]], dtype=int32), array([[[125, 471]],
#
#        [[126, 470]],
#
#        [[127, 471]],
#
#        [[126, 472]]], dtype=int32), array([[[147, 465]],
#
#        [[148, 464]],
#
#        [[149, 464]],
#
#        [[150, 465]],
#
#        [[150, 467]],
#
#        [[149, 468]],
#
#        [[148, 467]],
#
#        [[148, 466]]], dtype=int32), array([[[140, 448]],
#
#        [[137, 451]],
#
#        [[137, 452]],
#
#        [[135, 454]],
#
#        [[135, 456]],
#
#        [[135, 455]],
#
#        [[138, 452]],
#
#        [[138, 451]],
#
#        [[140, 449]]], dtype=int32), array([[[128, 440]],
#
#        [[127, 441]]], dtype=int32), array([[[167, 423]]], dtype=int32), array([[[165, 423]]], dtype=int32), array([[[157, 416]],
#
#        [[157, 417]],
#
#        [[156, 418]],
#
#        [[157, 417]]], dtype=int32), array([[[136, 415]]], dtype=int32), array([[[172, 413]],
#
#        [[172, 416]]], dtype=int32), array([[[163, 408]]], dtype=int32), array([[[166, 407]]], dtype=int32), array([[[128, 407]]], dtype=int32), array([[[126, 404]]], dtype=int32), array([[[135, 403]],
#
#        [[135, 405]],
#
#        [[136, 406]],
#
#        [[136, 407]],
#
#        [[137, 408]],
#
#        [[137, 409]],
#
#        [[138, 410]],
#
#        [[138, 411]],
#
#        [[139, 412]],
#
#        [[139, 413]],
#
#        [[140, 414]],
#
#        [[140, 415]],
#
#        [[140, 414]],
#
#        [[139, 413]],
#
#        [[139, 411]],
#
#        [[137, 409]],
#
#        [[137, 407]],
#
#        [[135, 405]]], dtype=int32), array([[[170, 402]],
#
#        [[170, 403]]], dtype=int32), array([[[127, 401]]], dtype=int32), array([[[171, 400]],
#
#        [[172, 401]],
#
#        [[172, 406]],
#
#        [[172, 401]]], dtype=int32), array([[[177, 392]],
#
#        [[177, 394]],
#
#        [[176, 395]],
#
#        [[176, 396]],
#
#        [[175, 397]],
#
#        [[174, 396]],
#
#        [[174, 395]],
#
#        [[174, 417]],
#
#        [[175, 418]],
#
#        [[175, 422]],
#
#        [[176, 423]],
#
#        [[176, 425]],
#
#        [[176, 421]],
#
#        [[177, 420]],
#
#        [[177, 414]],
#
#        [[178, 413]],
#
#        [[179, 413]],
#
#        [[179, 407]],
#
#        [[180, 406]],
#
#        [[180, 405]],
#
#        [[179, 404]],
#
#        [[179, 403]],
#
#        [[178, 402]],
#
#        [[178, 400]],
#
#        [[179, 399]],
#
#        [[178, 398]],
#
#        [[178, 392]]], dtype=int32), array([[[164, 389]],
#
#        [[164, 391]]], dtype=int32), array([[[359, 385]]], dtype=int32), array([[[178, 384]],
#
#        [[178, 385]]], dtype=int32), array([[[163, 384]],
#
#        [[163, 385]]], dtype=int32), array([[[177, 380]]], dtype=int32), array([[[176, 368]]], dtype=int32), array([[[137, 367]]], dtype=int32), array([[[520, 365]]], dtype=int32), array([[[154, 363]],
#
#        [[154, 364]]], dtype=int32), array([[[124, 362]],
#
#        [[124, 364]],
#
#        [[123, 365]],
#
#        [[123, 368]],
#
#        [[122, 369]],
#
#        [[121, 368]],
#
#        [[121, 370]],
#
#        [[120, 371]],
#
#        [[120, 374]],
#
#        [[119, 375]],
#
#        [[119, 385]],
#
#        [[120, 386]],
#
#        [[120, 389]],
#
#        [[121, 390]],
#
#        [[121, 393]],
#
#        [[122, 394]],
#
#        [[122, 395]],
#
#        [[123, 396]],
#
#        [[123, 397]],
#
#        [[124, 398]],
#
#        [[124, 400]],
#
#        [[125, 399]],
#
#        [[125, 398]],
#
#        [[124, 397]],
#
#        [[125, 396]],
#
#        [[126, 396]],
#
#        [[126, 394]],
#
#        [[125, 393]],
#
#        [[125, 390]],
#
#        [[124, 389]],
#
#        [[124, 385]],
#
#        [[125, 384]],
#
#        [[124, 383]],
#
#        [[124, 378]],
#
#        [[126, 376]],
#
#        [[126, 375]],
#
#        [[125, 374]],
#
#        [[125, 369]],
#
#        [[124, 368]],
#
#        [[124, 367]],
#
#        [[125, 366]],
#
#        [[125, 365]],
#
#        [[124, 364]]], dtype=int32), array([[[123, 375]],
#
#        [[124, 374]],
#
#        [[125, 375]],
#
#        [[125, 376]],
#
#        [[124, 377]],
#
#        [[123, 376]]], dtype=int32), array([[[122, 372]],
#
#        [[123, 371]],
#
#        [[124, 371]],
#
#        [[125, 372]],
#
#        [[123, 374]],
#
#        [[122, 373]]], dtype=int32), array([[[123, 370]],
#
#        [[124, 369]],
#
#        [[125, 370]],
#
#        [[124, 371]]], dtype=int32), array([[[162, 360]],
#
#        [[162, 362]]], dtype=int32), array([[[175, 359]],
#
#        [[175, 363]]], dtype=int32), array([[[152, 358]],
#
#        [[153, 359]],
#
#        [[152, 360]],
#
#        [[152, 363]],
#
#        [[150, 365]],
#
#        [[150, 367]],
#
#        [[149, 368]],
#
#        [[149, 371]],
#
#        [[148, 372]],
#
#        [[148, 374]],
#
#        [[147, 375]],
#
#        [[147, 380]],
#
#        [[146, 381]],
#
#        [[146, 383]],
#
#        [[147, 384]],
#
#        [[146, 385]],
#
#        [[146, 386]],
#
#        [[146, 385]],
#
#        [[148, 383]],
#
#        [[149, 384]],
#
#        [[149, 386]],
#
#        [[148, 387]],
#
#        [[148, 391]],
#
#        [[149, 392]],
#
#        [[149, 395]],
#
#        [[148, 396]],
#
#        [[149, 395]],
#
#        [[150, 396]],
#
#        [[150, 400]],
#
#        [[149, 401]],
#
#        [[148, 400]],
#
#        [[149, 401]],
#
#        [[149, 403]],
#
#        [[150, 404]],
#
#        [[150, 405]],
#
#        [[151, 406]],
#
#        [[151, 407]],
#
#        [[152, 408]],
#
#        [[152, 411]],
#
#        [[154, 413]],
#
#        [[154, 414]],
#
#        [[155, 415]],
#
#        [[155, 413]],
#
#        [[156, 412]],
#
#        [[158, 412]],
#
#        [[160, 414]],
#
#        [[160, 415]],
#
#        [[159, 416]],
#
#        [[159, 418]],
#
#        [[158, 419]],
#
#        [[158, 420]],
#
#        [[157, 421]],
#
#        [[157, 422]],
#
#        [[161, 426]],
#
#        [[161, 427]],
#
#        [[162, 428]],
#
#        [[162, 429]],
#
#        [[163, 430]],
#
#        [[163, 428]],
#
#        [[161, 426]],
#
#        [[161, 425]],
#
#        [[162, 424]],
#
#        [[165, 427]],
#
#        [[165, 428]],
#
#        [[166, 429]],
#
#        [[166, 427]],
#
#        [[165, 426]],
#
#        [[165, 425]],
#
#        [[164, 425]],
#
#        [[163, 424]],
#
#        [[163, 422]],
#
#        [[164, 421]],
#
#        [[164, 417]],
#
#        [[165, 416]],
#
#        [[165, 414]],
#
#        [[165, 415]],
#
#        [[163, 417]],
#
#        [[162, 416]],
#
#        [[162, 415]],
#
#        [[163, 414]],
#
#        [[163, 413]],
#
#        [[164, 412]],
#
#        [[164, 411]],
#
#        [[164, 412]],
#
#        [[163, 413]],
#
#        [[162, 412]],
#
#        [[161, 412]],
#
#        [[160, 411]],
#
#        [[160, 409]],
#
#        [[161, 408]],
#
#        [[161, 405]],
#
#        [[160, 404]],
#
#        [[160, 403]],
#
#        [[161, 402]],
#
#        [[162, 403]],
#
#        [[162, 402]],
#
#        [[161, 402]],
#
#        [[160, 401]],
#
#        [[160, 400]],
#
#        [[161, 399]],
#
#        [[161, 394]],
#
#        [[160, 393]],
#
#        [[160, 391]],
#
#        [[159, 391]],
#
#        [[158, 390]],
#
#        [[158, 387]],
#
#        [[157, 386]],
#
#        [[157, 378]],
#
#        [[158, 377]],
#
#        [[158, 376]],
#
#        [[157, 375]],
#
#        [[157, 370]],
#
#        [[156, 369]],
#
#        [[156, 365]],
#
#        [[156, 370]],
#
#        [[155, 371]],
#
#        [[155, 372]],
#
#        [[154, 373]],
#
#        [[153, 372]],
#
#        [[153, 369]],
#
#        [[152, 368]],
#
#        [[153, 367]],
#
#        [[153, 366]],
#
#        [[152, 365]],
#
#        [[152, 361]],
#
#        [[153, 360]],
#
#        [[153, 358]]], dtype=int32), array([[[160, 423]],
#
#        [[161, 422]],
#
#        [[162, 423]],
#
#        [[162, 424]],
#
#        [[161, 425]],
#
#        [[160, 424]]], dtype=int32), array([[[159, 421]],
#
#        [[160, 420]],
#
#        [[161, 421]],
#
#        [[161, 422]],
#
#        [[160, 423]],
#
#        [[159, 422]]], dtype=int32), array([[[158, 419]],
#
#        [[159, 418]],
#
#        [[160, 419]],
#
#        [[160, 420]],
#
#        [[159, 421]],
#
#        [[158, 420]]], dtype=int32), array([[[159, 412]],
#
#        [[160, 411]],
#
#        [[161, 412]],
#
#        [[161, 413]],
#
#        [[160, 414]],
#
#        [[159, 413]]], dtype=int32), array([[[154, 411]],
#
#        [[155, 410]],
#
#        [[156, 411]],
#
#        [[155, 412]]], dtype=int32), array([[[153, 409]],
#
#        [[154, 408]],
#
#        [[155, 409]],
#
#        [[155, 410]],
#
#        [[154, 411]],
#
#        [[153, 410]]], dtype=int32), array([[[158, 408]],
#
#        [[159, 407]],
#
#        [[160, 408]],
#
#        [[159, 409]]], dtype=int32), array([[[152, 408]],
#
#        [[153, 407]],
#
#        [[154, 408]],
#
#        [[153, 409]]], dtype=int32), array([[[151, 405]],
#
#        [[152, 404]],
#
#        [[153, 405]],
#
#        [[153, 406]],
#
#        [[152, 407]],
#
#        [[151, 406]]], dtype=int32), array([[[155, 404]],
#
#        [[156, 403]],
#
#        [[157, 404]],
#
#        [[156, 405]]], dtype=int32), array([[[152, 404]],
#
#        [[153, 403]],
#
#        [[154, 404]],
#
#        [[153, 405]]], dtype=int32), array([[[150, 404]],
#
#        [[151, 403]],
#
#        [[152, 404]],
#
#        [[151, 405]]], dtype=int32), array([[[149, 401]],
#
#        [[150, 400]],
#
#        [[151, 401]],
#
#        [[151, 402]],
#
#        [[150, 403]],
#
#        [[149, 402]]], dtype=int32), array([[[159, 395]],
#
#        [[160, 394]],
#
#        [[161, 395]],
#
#        [[161, 399]],
#
#        [[160, 400]],
#
#        [[159, 399]]], dtype=int32), array([[[153, 394]],
#
#        [[154, 393]],
#
#        [[155, 394]],
#
#        [[155, 395]],
#
#        [[154, 396]],
#
#        [[153, 395]]], dtype=int32), array([[[158, 392]],
#
#        [[159, 391]],
#
#        [[160, 392]],
#
#        [[160, 393]],
#
#        [[159, 394]],
#
#        [[158, 393]]], dtype=int32), array([[[148, 389]],
#
#        [[149, 388]],
#
#        [[150, 389]],
#
#        [[150, 390]],
#
#        [[149, 391]],
#
#        [[148, 390]]], dtype=int32), array([[[150, 383]],
#
#        [[151, 382]],
#
#        [[152, 383]],
#
#        [[151, 384]]], dtype=int32), array([[[154, 376]],
#
#        [[155, 375]],
#
#        [[156, 376]],
#
#        [[155, 377]]], dtype=int32), array([[[151, 369]],
#
#        [[152, 368]],
#
#        [[153, 369]],
#
#        [[153, 374]],
#
#        [[154, 375]],
#
#        [[153, 376]],
#
#        [[153, 380]],
#
#        [[152, 381]],
#
#        [[151, 380]],
#
#        [[151, 376]],
#
#        [[150, 375]],
#
#        [[150, 373]],
#
#        [[151, 372]]], dtype=int32), array([[[151, 367]],
#
#        [[152, 366]],
#
#        [[153, 367]],
#
#        [[152, 368]]], dtype=int32), array([[[143, 358]],
#
#        [[143, 360]],
#
#        [[142, 361]],
#
#        [[142, 363]],
#
#        [[142, 361]],
#
#        [[143, 360]]], dtype=int32), array([[[156, 357]],
#
#        [[156, 359]]], dtype=int32), array([[[128, 355]],
#
#        [[128, 363]],
#
#        [[128, 358]],
#
#        [[129, 357]],
#
#        [[130, 357]],
#
#        [[129, 357]],
#
#        [[128, 356]]], dtype=int32), array([[[130, 354]],
#
#        [[130, 355]]], dtype=int32), array([[[175, 353]],
#
#        [[175, 356]]], dtype=int32), array([[[154, 352]],
#
#        [[154, 353]]], dtype=int32), array([[[125, 352]],
#
#        [[125, 353]]], dtype=int32), array([[[157, 351]],
#
#        [[157, 354]]], dtype=int32), array([[[130, 351]]], dtype=int32), array([[[144, 350]],
#
#        [[144, 352]],
#
#        [[145, 351]],
#
#        [[145, 350]]], dtype=int32), array([[[142, 350]],
#
#        [[142, 351]]], dtype=int32), array([[[173, 349]]], dtype=int32), array([[[129, 346]],
#
#        [[129, 347]]], dtype=int32), array([[[130, 344]]], dtype=int32), array([[[127, 342]],
#
#        [[127, 343]],
#
#        [[126, 344]],
#
#        [[126, 347]],
#
#        [[126, 346]],
#
#        [[127, 345]]], dtype=int32), array([[[132, 341]]], dtype=int32), array([[[128, 340]]], dtype=int32), array([[[132, 335]],
#
#        [[132, 337]]], dtype=int32), array([[[129, 335]],
#
#        [[127, 337]],
#
#        [[127, 338]],
#
#        [[128, 337]],
#
#        [[128, 336]]], dtype=int32), array([[[133, 332]],
#
#        [[133, 333]]], dtype=int32), array([[[152, 329]],
#
#        [[152, 331]],
#
#        [[151, 332]],
#
#        [[151, 333]],
#
#        [[150, 334]],
#
#        [[150, 335]],
#
#        [[149, 336]],
#
#        [[149, 337]],
#
#        [[148, 338]],
#
#        [[148, 339]],
#
#        [[147, 340]],
#
#        [[147, 341]],
#
#        [[146, 342]],
#
#        [[146, 344]],
#
#        [[145, 345]],
#
#        [[145, 346]],
#
# ...
#
#        [[336, 330]],
#
#        [[337, 329]]], dtype=int32), array([[[327, 324]]], dtype=int32), array([[[315, 320]],
#
#        [[314, 321]],
#
#        [[312, 321]],
#
#        [[310, 323]],
#
#        [[305, 323]],
#
#        [[304, 324]],
#
#        [[302, 324]],
#
#        [[300, 326]],
#
#        [[300, 327]],
#
#        [[299, 328]],
#
#        [[298, 328]],
#
#        [[297, 329]],
#
#        [[309, 329]],
#
#        [[310, 328]],
#
#        [[311, 328]],
#
#        [[312, 327]],
#
#        [[317, 327]],
#
#        [[318, 326]],
#
#        [[319, 326]],
#
#        [[320, 325]],
#
#        [[321, 325]],
#
#        [[322, 324]],
#
#        [[323, 324]],
#
#        [[323, 322]],
#
#        [[322, 322]],
#
#        [[321, 321]],
#
#        [[318, 321]],
#
#        [[317, 320]]], dtype=int32), array([[[283, 288]],
#
#        [[284, 287]],
#
#        [[285, 287]],
#
#        [[286, 288]],
#
#        [[287, 288]],
#
#        [[288, 289]],
#
#        [[290, 289]],
#
#        [[291, 290]],
#
#        [[291, 291]],
#
#        [[290, 292]],
#
#        [[289, 292]],
#
#        [[288, 291]],
#
#        [[285, 291]],
#
#        [[283, 289]]], dtype=int32), array([[[307, 282]],
#
#        [[311, 282]],
#
#        [[312, 283]],
#
#        [[313, 283]],
#
#        [[314, 284]],
#
#        [[313, 285]],
#
#        [[306, 285]],
#
#        [[305, 284]]], dtype=int32), array([[[148, 277]],
#
#        [[149, 276]],
#
#        [[150, 276]],
#
#        [[151, 277]],
#
#        [[151, 279]],
#
#        [[149, 281]],
#
#        [[148, 280]]], dtype=int32), array([[[150, 275]],
#
#        [[151, 274]],
#
#        [[152, 275]],
#
#        [[152, 276]],
#
#        [[151, 277]],
#
#        [[150, 276]]], dtype=int32), array([[[151, 272]],
#
#        [[152, 271]],
#
#        [[153, 272]],
#
#        [[153, 273]],
#
#        [[152, 274]],
#
#        [[151, 273]]], dtype=int32), array([[[424, 251]],
#
#        [[425, 250]],
#
#        [[426, 251]],
#
#        [[425, 252]]], dtype=int32), array([[[423, 248]],
#
#        [[424, 247]],
#
#        [[425, 248]],
#
#        [[424, 249]]], dtype=int32), array([[[430, 247]],
#
#        [[431, 246]],
#
#        [[432, 247]],
#
#        [[431, 248]]], dtype=int32), array([[[439, 242]],
#
#        [[440, 241]],
#
#        [[441, 242]],
#
#        [[440, 243]]], dtype=int32), array([[[435, 240]],
#
#        [[436, 239]],
#
#        [[437, 239]],
#
#        [[438, 240]],
#
#        [[439, 240]],
#
#        [[440, 241]],
#
#        [[439, 242]],
#
#        [[439, 243]],
#
#        [[440, 244]],
#
#        [[438, 246]],
#
#        [[438, 247]],
#
#        [[437, 248]],
#
#        [[436, 248]],
#
#        [[436, 249]],
#
#        [[435, 250]],
#
#        [[434, 249]],
#
#        [[434, 244]],
#
#        [[435, 243]]], dtype=int32), array([[[453, 239]],
#
#        [[454, 238]],
#
#        [[456, 238]],
#
#        [[457, 239]],
#
#        [[457, 241]],
#
#        [[458, 242]],
#
#        [[458, 243]],
#
#        [[457, 244]],
#
#        [[453, 240]]], dtype=int32), array([[[447, 239]],
#
#        [[448, 238]],
#
#        [[449, 239]],
#
#        [[448, 240]]], dtype=int32), array([[[428, 239]],
#
#        [[429, 238]],
#
#        [[430, 239]],
#
#        [[429, 240]]], dtype=int32), array([[[452, 238]],
#
#        [[453, 237]],
#
#        [[454, 238]],
#
#        [[453, 239]]], dtype=int32), array([[[450, 237]],
#
#        [[451, 236]],
#
#        [[452, 237]],
#
#        [[451, 238]]], dtype=int32), array([[[448, 235]],
#
#        [[450, 235]],
#
#        [[451, 236]],
#
#        [[450, 237]],
#
#        [[449, 237]],
#
#        [[448, 238]],
#
#        [[447, 238]],
#
#        [[446, 237]]], dtype=int32), array([[[435, 236]],
#
#        [[436, 235]],
#
#        [[439, 238]],
#
#        [[439, 239]],
#
#        [[438, 240]],
#
#        [[435, 237]]], dtype=int32), array([[[446, 235]],
#
#        [[447, 234]],
#
#        [[448, 235]],
#
#        [[447, 236]]], dtype=int32), array([[[434, 235]],
#
#        [[435, 234]],
#
#        [[436, 235]],
#
#        [[435, 236]]], dtype=int32), array([[[443, 234]],
#
#        [[444, 233]],
#
#        [[445, 233]],
#
#        [[446, 234]],
#
#        [[445, 235]],
#
#        [[444, 235]]], dtype=int32), array([[[433, 234]],
#
#        [[434, 233]],
#
#        [[435, 234]],
#
#        [[434, 235]]], dtype=int32), array([[[445, 233]],
#
#        [[446, 232]],
#
#        [[450, 232]],
#
#        [[451, 233]],
#
#        [[453, 233]],
#
#        [[454, 232]],
#
#        [[455, 232]],
#
#        [[457, 234]],
#
#        [[457, 235]],
#
#        [[458, 235]],
#
#        [[459, 236]],
#
#        [[459, 238]],
#
#        [[458, 239]],
#
#        [[457, 239]],
#
#        [[455, 237]],
#
#        [[455, 236]],
#
#        [[454, 236]],
#
#        [[453, 235]],
#
#        [[450, 235]],
#
#        [[449, 234]],
#
#        [[446, 234]]], dtype=int32), array([[[451, 232]],
#
#        [[452, 231]],
#
#        [[453, 232]],
#
#        [[452, 233]]], dtype=int32), array([[[266, 232]],
#
#        [[267, 231]],
#
#        [[269, 233]],
#
#        [[269, 235]],
#
#        [[268, 236]],
#
#        [[267, 236]],
#
#        [[266, 235]]], dtype=int32), array([[[455, 231]],
#
#        [[456, 230]],
#
#        [[458, 232]],
#
#        [[457, 233]],
#
#        [[456, 233]],
#
#        [[455, 232]]], dtype=int32), array([[[447, 231]],
#
#        [[448, 230]],
#
#        [[450, 230]],
#
#        [[451, 231]],
#
#        [[450, 232]],
#
#        [[448, 232]]], dtype=int32), array([[[264, 229]],
#
#        [[265, 228]],
#
#        [[266, 229]],
#
#        [[265, 230]]], dtype=int32), array([[[263, 228]],
#
#        [[264, 227]],
#
#        [[265, 228]],
#
#        [[264, 229]]], dtype=int32), array([[[233, 223]],
#
#        [[234, 222]],
#
#        [[235, 222]],
#
#        [[236, 223]],
#
#        [[235, 224]],
#
#        [[234, 224]]], dtype=int32), array([[[268, 220]],
#
#        [[269, 219]],
#
#        [[270, 219]],
#
#        [[271, 220]],
#
#        [[270, 221]],
#
#        [[269, 221]]], dtype=int32), array([[[358, 216]],
#
#        [[359, 215]],
#
#        [[360, 216]],
#
#        [[359, 217]]], dtype=int32), array([[[269, 216]],
#
#        [[270, 215]],
#
#        [[271, 216]],
#
#        [[270, 217]]], dtype=int32), array([[[272, 215]],
#
#        [[273, 214]],
#
#        [[274, 215]],
#
#        [[273, 216]]], dtype=int32), array([[[270, 214]],
#
#        [[271, 213]],
#
#        [[272, 214]],
#
#        [[271, 215]]], dtype=int32), array([[[271, 212]],
#
#        [[272, 211]],
#
#        [[273, 212]],
#
#        [[273, 213]],
#
#        [[272, 214]],
#
#        [[271, 213]]], dtype=int32), array([[[266, 212]],
#
#        [[267, 211]],
#
#        [[268, 212]],
#
#        [[267, 213]]], dtype=int32), array([[[265, 211]],
#
#        [[266, 210]],
#
#        [[267, 211]],
#
#        [[266, 212]]], dtype=int32), array([[[263, 209]],
#
#        [[264, 208]],
#
#        [[265, 209]],
#
#        [[265, 210]],
#
#        [[264, 211]],
#
#        [[263, 210]]], dtype=int32), array([[[270, 208]],
#
#        [[271, 207]],
#
#        [[272, 208]],
#
#        [[272, 210]],
#
#        [[271, 211]],
#
#        [[270, 210]]], dtype=int32), array([[[326, 207]],
#
#        [[327, 206]],
#
#        [[328, 207]],
#
#        [[327, 208]]], dtype=int32), array([[[247, 207]],
#
#        [[248, 206]],
#
#        [[249, 207]],
#
#        [[248, 208]]], dtype=int32), array([[[402, 204]],
#
#        [[403, 203]],
#
#        [[404, 204]],
#
#        [[403, 205]]], dtype=int32), array([[[269, 203]],
#
#        [[270, 202]],
#
#        [[271, 203]],
#
#        [[271, 207]],
#
#        [[270, 208]],
#
#        [[269, 207]]], dtype=int32), array([[[403, 201]],
#
#        [[404, 200]],
#
#        [[405, 201]],
#
#        [[405, 202]],
#
#        [[404, 203]],
#
#        [[403, 202]]], dtype=int32), array([[[359, 201]],
#
#        [[360, 200]],
#
#        [[361, 200]],
#
#        [[362, 201]],
#
#        [[361, 202]],
#
#        [[360, 202]]], dtype=int32), array([[[455, 200]],
#
#        [[456, 199]],
#
#        [[459, 202]],
#
#        [[459, 203]],
#
#        [[460, 204]],
#
#        [[460, 205]],
#
#        [[459, 206]],
#
#        [[458, 206]],
#
#        [[456, 204]],
#
#        [[456, 203]],
#
#        [[455, 202]]], dtype=int32), array([[[356, 200]],
#
#        [[357, 199]],
#
#        [[359, 199]],
#
#        [[360, 200]],
#
#        [[359, 201]],
#
#        [[357, 201]]], dtype=int32), array([[[268, 200]],
#
#        [[269, 199]],
#
#        [[270, 200]],
#
#        [[270, 202]],
#
#        [[269, 203]],
#
#        [[268, 202]]], dtype=int32), array([[[268, 197]],
#
#        [[269, 196]],
#
#        [[270, 197]],
#
#        [[270, 198]],
#
#        [[269, 199]],
#
#        [[268, 198]]], dtype=int32), array([[[446, 195]],
#
#        [[447, 194]],
#
#        [[450, 194]],
#
#        [[451, 195]],
#
#        [[453, 195]],
#
#        [[454, 196]],
#
#        [[454, 197]],
#
#        [[453, 198]],
#
#        [[452, 197]],
#
#        [[445, 197]],
#
#        [[444, 198]],
#
#        [[443, 197]],
#
#        [[443, 196]],
#
#        [[444, 195]]], dtype=int32), array([[[403, 192]],
#
#        [[404, 191]],
#
#        [[405, 192]],
#
#        [[404, 193]]], dtype=int32), array([[[402, 191]],
#
#        [[403, 190]],
#
#        [[404, 191]],
#
#        [[403, 192]]], dtype=int32), array([[[396, 188]],
#
#        [[397, 187]],
#
#        [[398, 188]],
#
#        [[398, 189]],
#
#        [[397, 190]],
#
#        [[396, 189]]], dtype=int32), array([[[395, 187]],
#
#        [[396, 186]],
#
#        [[397, 187]],
#
#        [[396, 188]]], dtype=int32), array([[[393, 185]],
#
#        [[394, 184]],
#
#        [[395, 184]],
#
#        [[396, 185]],
#
#        [[396, 186]],
#
#        [[395, 187]],
#
#        [[394, 187]],
#
#        [[393, 186]]], dtype=int32), array([[[392, 184]],
#
#        [[393, 183]],
#
#        [[394, 184]],
#
#        [[393, 185]]], dtype=int32), array([[[155, 184]],
#
#        [[156, 183]],
#
#        [[157, 184]],
#
#        [[156, 185]]], dtype=int32), array([[[391, 183]],
#
#        [[392, 182]],
#
#        [[393, 183]],
#
#        [[392, 184]]], dtype=int32), array([[[336, 182]],
#
#        [[337, 181]],
#
#        [[338, 181]],
#
#        [[339, 182]],
#
#        [[338, 183]],
#
#        [[337, 183]]], dtype=int32), array([[[322, 182]],
#
#        [[323, 181]],
#
#        [[324, 182]],
#
#        [[323, 183]]], dtype=int32), array([[[319, 182]],
#
#        [[320, 181]],
#
#        [[321, 182]],
#
#        [[320, 183]]], dtype=int32), array([[[348, 181]],
#
#        [[349, 180]],
#
#        [[351, 180]],
#
#        [[352, 181]],
#
#        [[351, 182]],
#
#        [[349, 182]]], dtype=int32), array([[[341, 181]],
#
#        [[342, 180]],
#
#        [[343, 180]],
#
#        [[344, 181]],
#
#        [[343, 182]],
#
#        [[342, 182]]], dtype=int32), array([[[323, 181]],
#
#        [[324, 180]],
#
#        [[325, 181]],
#
#        [[324, 182]]], dtype=int32), array([[[319, 179]],
#
#        [[320, 178]],
#
#        [[321, 179]],
#
#        [[320, 180]]], dtype=int32), array([[[320, 178]],
#
#        [[321, 177]],
#
#        [[322, 178]],
#
#        [[321, 179]]], dtype=int32), array([[[270, 174]],
#
#        [[271, 175]],
#
#        [[271, 177]],
#
#        [[270, 178]],
#
#        [[270, 183]],
#
#        [[269, 184]],
#
#        [[268, 183]],
#
#        [[268, 176]]], dtype=int32), array([[[251, 164]],
#
#        [[252, 163]],
#
#        [[253, 164]],
#
#        [[253, 167]],
#
#        [[252, 168]],
#
#        [[251, 167]]], dtype=int32), array([[[251, 161]],
#
#        [[252, 160]],
#
#        [[253, 161]],
#
#        [[253, 162]],
#
#        [[252, 163]],
#
#        [[251, 162]]], dtype=int32), array([[[366, 149]],
#
#        [[367, 148]],
#
#        [[368, 149]],
#
#        [[368, 151]],
#
#        [[367, 152]],
#
#        [[366, 151]]], dtype=int32), array([[[252, 148]],
#
#        [[253, 147]],
#
#        [[254, 148]],
#
#        [[254, 151]],
#
#        [[253, 152]],
#
#        [[252, 151]]], dtype=int32), array([[[363, 146]],
#
#        [[364, 145]],
#
#        [[365, 146]],
#
#        [[364, 147]]], dtype=int32), array([[[268, 144]],
#
#        [[269, 143]],
#
#        [[270, 144]],
#
#        [[270, 145]],
#
#        [[269, 146]],
#
#        [[268, 145]]], dtype=int32), array([[[161, 134]],
#
#        [[162, 133]],
#
#        [[163, 134]],
#
#        [[163, 136]],
#
#        [[162, 137]],
#
#        [[161, 136]]], dtype=int32), array([[[162, 132]],
#
#        [[163, 131]],
#
#        [[164, 132]],
#
#        [[164, 133]],
#
#        [[163, 134]],
#
#        [[162, 133]]], dtype=int32), array([[[174, 131]],
#
#        [[175, 130]],
#
#        [[176, 130]],
#
#        [[177, 131]],
#
#        [[177, 132]],
#
#        [[176, 133]],
#
#        [[176, 135]],
#
#        [[175, 136]],
#
#        [[175, 139]],
#
#        [[174, 140]],
#
#        [[174, 145]],
#
#        [[173, 146]],
#
#        [[173, 151]],
#
#        [[172, 152]],
#
#        [[172, 157]],
#
#        [[171, 158]],
#
#        [[171, 166]],
#
#        [[169, 168]],
#
#        [[168, 167]],
#
#        [[168, 165]],
#
#        [[169, 164]],
#
#        [[169, 156]],
#
#        [[170, 155]],
#
#        [[170, 151]],
#
#        [[171, 150]],
#
#        [[171, 142]],
#
#        [[172, 141]],
#
#        [[172, 138]],
#
#        [[173, 137]],
#
#        [[173, 135]],
#
#        [[174, 134]]], dtype=int32), array([[[257, 128]],
#
#        [[258, 127]],
#
#        [[259, 128]],
#
#        [[258, 129]]], dtype=int32), array([[[170, 114]],
#
#        [[171, 113]],
#
#        [[172, 114]],
#
#        [[171, 115]]], dtype=int32), array([[[284, 112]],
#
#        [[285, 111]],
#
#        [[286, 112]],
#
#        [[285, 113]]], dtype=int32), array([[[182, 110]],
#
#        [[183, 109]],
#
#        [[184, 110]],
#
#        [[184, 112]],
#
#        [[183, 113]],
#
#        [[183, 114]],
#
#        [[182, 115]],
#
#        [[182, 117]],
#
#        [[181, 118]],
#
#        [[181, 121]],
#
#        [[180, 122]],
#
#        [[180, 123]],
#
#        [[179, 124]],
#
#        [[179, 126]],
#
#        [[178, 127]],
#
#        [[178, 129]],
#
#        [[177, 130]],
#
#        [[175, 128]],
#
#        [[176, 127]],
#
#        [[176, 124]],
#
#        [[177, 123]],
#
#        [[177, 121]],
#
#        [[178, 120]],
#
#        [[178, 118]],
#
#        [[179, 117]],
#
#        [[179, 116]],
#
#        [[180, 115]],
#
#        [[180, 114]],
#
#        [[181, 113]],
#
#        [[181, 112]],
#
#        [[182, 111]]], dtype=int32), array([[[173, 109]],
#
#        [[174, 108]],
#
#        [[175, 109]],
#
#        [[174, 110]]], dtype=int32), array([[[174, 108]],
#
#        [[175, 107]],
#
#        [[176, 108]],
#
#        [[175, 109]]], dtype=int32), array([[[183, 107]],
#
#        [[184, 106]],
#
#        [[185, 107]],
#
#        [[185, 109]],
#
#        [[184, 110]],
#
#        [[183, 109]]], dtype=int32), array([[[175, 106]],
#
#        [[176, 105]],
#
#        [[177, 106]],
#
#        [[176, 107]]], dtype=int32), array([[[188,  97]],
#
#        [[189,  98]],
#
#        [[189,  99]],
#
#        [[188, 100]],
#
#        [[188, 102]],
#
#        [[187, 103]],
#
#        [[187, 104]],
#
#        [[186, 105]],
#
#        [[186, 106]],
#
#        [[185, 107]],
#
#        [[184, 106]],
#
#        [[184, 104]],
#
#        [[185, 103]],
#
#        [[185, 101]],
#
#        [[186, 100]],
#
#        [[186,  99]]], dtype=int32), array([[[193,  88]],
#
#        [[194,  89]],
#
#        [[194,  90]],
#
#        [[193,  91]],
#
#        [[193,  92]],
#
#        [[192,  93]],
#
#        [[192,  94]],
#
#        [[191,  95]],
#
#        [[191,  96]],
#
#        [[189,  98]],
#
#        [[188,  97]],
#
#        [[188,  95]],
#
#        [[189,  94]],
#
#        [[189,  93]],
#
#        [[191,  91]],
#
#        [[191,  90]]], dtype=int32), array([[[204,  83]],
#
#        [[205,  82]],
#
#        [[206,  83]],
#
#        [[205,  84]]], dtype=int32), array([[[205,  82]],
#
#        [[206,  81]],
#
#        [[207,  82]],
#
#        [[206,  83]]], dtype=int32), array([[[206,  80]],
#
#        [[207,  79]],
#
#        [[208,  80]],
#
#        [[207,  81]]], dtype=int32), array([[[207,  79]],
#
#        [[208,  78]],
#
#        [[209,  79]],
#
#        [[208,  80]]], dtype=int32), array([[[212,  73]],
#
#        [[213,  74]],
#
#        [[213,  75]],
#
#        [[209,  79]],
#
#        [[208,  78]],
#
#        [[208,  77]]], dtype=int32), array([[[213,  70]],
#
#        [[214,  69]],
#
#        [[216,  69]],
#
#        [[217,  70]],
#
#        [[213,  74]],
#
#        [[212,  73]],
#
#        [[212,  72]],
#
#        [[213,  71]]], dtype=int32), array([[[216,  68]],
#
#        [[217,  67]],
#
#        [[218,  68]],
#
#        [[217,  69]]], dtype=int32), array([[[217,  66]],
#
#        [[218,  65]],
#
#        [[220,  67]],
#
#        [[219,  68]],
#
#        [[218,  68]],
#
#        [[217,  67]]], dtype=int32), array([[[221,  62]],
#
#        [[222,  63]],
#
#        [[222,  64]],
#
#        [[220,  66]],
#
#        [[219,  66]],
#
#        [[218,  65]]], dtype=int32), array([[[223,  60]],
#
#        [[224,  59]],
#
#        [[225,  60]],
#
#        [[224,  61]]], dtype=int32), array([[[278,  29]],
#
#        [[279,  28]],
#
#        [[280,  29]],
#
#        [[279,  30]]], dtype=int32), array([[[318,  26]],
#
#        [[319,  25]],
#
#        [[320,  25]],
#
#        [[321,  26]],
#
#        [[320,  27]],
#
#        [[319,  27]]], dtype=int32), array([[[323,  24]],
#
#        [[324,  23]],
#
#        [[325,  24]],
#
#        [[324,  25]]], dtype=int32)]

# %% [markdown]
# ### contour approximation method
# - to save memory use cv.CHAIN_APPROX_SIMPLE
# - the difference between NONE vs SIMPLE -> NONE saves whole points of image

# %% [markdown]
# ### 등치선 그릴때

# %%
# cv.drawContours(image, contours, contourIdx, color, thick)
# contourIdx : 몇 번째 contours line을 그릴 것인지(-1 : 전체)

img = cv2.imread('/Users/sejongpyo/downloads/con.jpg')
imgray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# binary image transform
ret, thresh = cv2.threshold(imgray, 127, 255, 0)
                            
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
con = cv2.drawContours(img, contours, -1, (0, 255, 0), 50)
plt.imshow(con)
plt.show()
print(len(contours))
# Out:
# 13

# %% [markdown]
# - contours는 리스트 형태로 이어진 하나의 선이 각각 하나로 위의 예제에서는 총 13개가 있음
