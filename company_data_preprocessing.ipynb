# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
from terminaltables import AsciiTable
import pandas as pd
import pymysql
import pyquery

warnings.filterwarnings('ignore')
# %matplotlib inline

def db_connection(host_name = "ds"):
    host_url = "db.ds.mycelebs.com"
    user_nm = 'dbteam'
    passwd = ''
    port_num = 3306
    db_name = 'book_kyobo'
    conn = pymysql.connect(host=host_url, user = user_nm, passwd=passwd, port=port_num,
                           charset='utf8', db=db_name, cursorclass=pymysql.cursors.DictCursor)
    book_sql = '''SELECT series_id, title, isbn13, listprice, form_size, page, weight, category_name
                  FROM book_kyobo_humanities_data
                  UNION ALL
                  SELECT series_id, title, isbn13, listprice, form_size, page, weight, category_name
                  FROM book_kyobo_learning_data
                  UNION ALL
                  SELECT series_id, title, isbn13, listprice, form_size, page, weight, category_name
                  FROM book_kyobo_lifestyle_data
                  UNION ALL
                  SELECT series_id, title, isbn13, listprice, form_size, page, weight, category_name
                  FROM book_kyobo_literature_data
                  UNION ALL
                  SELECT series_id, title, isbn13, listprice, form_size, page, weight, category_name
                  FROM book_kyobo_science_data
                  UNION ALL
                  SELECT series_id, title, isbn13, listprice, form_size, page, weight, category_name
                  FROM book_kyobo_biz_econo_self_improve_data
                '''
    
    cursor = conn.cursor()
    cursor.execute(book_sql)
    crawl_list = pd.DataFrame(cursor.fetchall()).reset_index()

    return crawl_list

df = db_connection()

# from csv due to db error
# df = pd.read_csv("kyobo_data.csv")
# df = df.drop(['Unnamed: 0', 'index'], axis = 1)
# df['isbn13'].fillna(0, inplace = True)
# df['isbn13'] = df['isbn13'].astype(int)
df.head()
# Out:
#    index  series_id             title         isbn13  listprice  form_size  \
# 0      0    9000428       역사를 바꾼 이인자들  1400000010648      11800  153*225mm
# 1      1    9000483     삼국유사(세계의사상 1)  1400000212776      17600  148*210mm
# 2      2    9000484  세계를 움직인 12인의 천재들  1400000212783      13800  153*225mm
# 3      3    9000495          미국역사의 순환  1400000212967      20500  148*210mm
# 4      4    9000596        한국의 멋을 찾아서  1400000215036      19600  188*254mm
#
#    page  weight category_name
# 0   316       0        한국역사인물
# 1   508       0        삼국시대일반
# 2   356       0        세계역사인물
# 3   580       0           미국사
# 4   437       0          역사기행

# %% [markdown]
# # 결측치 확인

# %%
# 결측치 확인
for i in df.columns:
    print(f"{i} : {df[i].isnull().sum()}")
# Out:
# index : 0
# series_id : 0
# title : 0
# isbn13 : 0
# listprice : 0
# form_size : 1137140
# page : 334625
# weight : 1798410
# category_name : 0

# %% [markdown]
# # form size, weight, page_num --> 0

# %%
# form size 스페이스값을 0으로 변환
df['form_size'].replace(' ', np.nan, inplace = True)

# %%
# 무게가 50그람 미만일 경우, 0으로 변환
df.loc[df['weight'] < 50, 'weight'] = np.nan

# %%
# 페이지가 10페이지 미만일 경우, 0으로 변환
df.loc[df['page'] < 10, 'page'] = np.nan

# %% [markdown]
# # 데이터프레임 복사하기

# %%
df_copy = df.copy()

# %% [markdown]
# # 무게 당 가격

# %%
# 무게 당 가격
df_copy['price_per_100g'] = df_copy['listprice'] / df_copy['weight'] * 100

# %% [markdown]
# # 책 넓이

# %%
import math

def get_area(x):
    if type(x) == str:
        x = x.split('mm')[0]
        x = x.split('*')
        x = list(map(int, x))
        x = round(math.prod(x))
    else:
        return np.nan
    return x

df['size'] = df['form_size'].apply(get_area)

# %% [markdown]
# # 넓이 당 가격 (넓이 : 10mm ^ 2)

# %%
# 넓이 당 가격 (넓이 100 mm ^ 2)
df_copy['price_per_100mm^2'] = df_copy['listprice'] / df_copy['size'] * 100

# %% [markdown]
# # 페이지 당 가격

# %%
# 페이지 당 가격
df_copy['price_per_page'] = df_copy['listprice'] / df_copy['page']

# %% [markdown]
# # 그림이 많을 것 같은 책 구분자 표시

# %%
for i in df_copy['category_name'].unique():
    print(i)
# Out:
# 한국역사인물
# 삼국시대일반
# 세계역사인물
# 미국사
# 역사기행
# 문화일반
# 한국사
# 신화
# 세계사
# 역사일반
# 동양사
# 역사/문화
# 역사인물
# 문화사
# 해방전후사/한국전쟁
# 독도문제
# 가정의례
# 풍속/민속학일반
# 교양세계사
# 민족운동/민족주의
# 한국통사
# 일본사일반
# 한국고대사
# 동양사일반
# 한국문화사
# 일제시대
# 중국사일반
# 한국근현대사
# 성풍속사
# 고고학
# 일본문화사
# 문화사일반
# 세계문화사
# 민속학
# 조선시대일반
# 무속/민간신앙
# 역사이론
# 러시아사
# 중국근대사
# 조선정치사
# 한국현대사
# 동남아시아사
# 서양문화사
# 한국지리
# 북한사
# 고려시대
# 신라
# 지리학의 이해
# 조선후기
# 고구려
# 한일관계와역사
# 문명/문명사
# 삼국사기
# 중국역사인물
# 전설/설화
# 지리학사/사전
# 신화의이해
# 삼국유사
# 한국역사기행
# 조선전기
# 지방/향토
# 민족학
# 인류학
# 서양사일반
# 발해
# 성씨/족보
# 한국근대사
# 그리스로마신화
# 조선중기
# 독일사
# 로마사
# 그리스
# 통일신라
# 유럽사일반
# 미국역사인물
# 청소년 역사
# 유럽역사인물
# 중국신화
# 한국신화
# 지리이야기
# 탐험사
# 민속놀이
# 조선왕조사
# 아프리카사
# 일본근현대사
# 백제
# 박물관학
# 문화재/유산
# 근대개화기
# 생활사
# 음식문화
# 문화유적답사
# 이스라엘/유대인
# 가정윤리/효
# 영국사
# 프랑스사
# 의복문화
# 역사이야기
# 기타나라사
# 역사철학
# 유적/유물
# 몽골/티벳
# 이탈리아사
# 인도사
# 조선시대생활/문화
# 중국문화사
# 중국근세사
# 세계사이야기
# 이슬람사
# 일본역사인물
# 세계지리
# 라틴아메리카사
# 동양신화
# 유럽신화
# 중국고대사
# 역사기행일반
# 동양문화사
# 기타아시아역사인물
# 중국근현대사
# 중국중세사
# 주거문화
# 대만/마카오/홍콩사
# 일본고대사
# 군사정권과민주화운동
# 유럽문화사
# 중앙아시아사
# 캐나다/호주사
#
# 미국문화사
# 일본신화
# 이집트사
# 중국역사기행
# 기타국가역사인물
# 이집트역사기행
# 서양신화
# 중동/기타
# 유럽역사기행
# 조선이야기
# 기타역사기행
# 대학교재
# 건국사/멸망사
# 일본중세사
# 일본역사기행
# 지식/상식
# 친일파
# 인문교양
# 지중해/그리스여행
# 인문
# 인문교양총서일반
# 국어이야기
# 공자
# 중국철학
# 고사성어
# 문학이론일반
# 문법론
# 사기열전
# 한국문학이론일반
# 기타사상가
# 장폴사르트르
# 인문학일반
# 한국고전문학
# 한문학
# 주역
# 철학
# 영미문학론
# 국어문법론
# 심리학
# 언어학
# 역학/사주
# 인문교양총서
# 독서/글쓰기
# 유아교육
# 중국문학론
# 인문고전총서
# 성격심리
# 교육학
# 한국문학론
# 한자능력시험
# 특수교육
# 교수/지도법
# 초등교육
# 사회윤리
# 국어학이론
# 한자펜글씨
# 문예사조
# 영재아
# 건강/생활지도
# 방언학
# 과학교육
# 국어교육
# 도덕교육
# 수학교육
# 청소년교육
# 평생교육
# 한국철학일반
# 일본철학
# 한국교육사
# 학습법
# 서양철학사
# 속담
# 백과사전
# 교육일반
# 고문진보
# 실용한자
# 명심보감
# 문장작법/수사학
# 철학사전
# 윤리학일반
# 만세력
# 궁합
# 사주학
# 육효
# 교과교육론
# 교육과정
# 교육역사
# 교육심리학
# 교육방법론
# 교육학개론
# 교육평가
# 글쓰기일반
# 사회교육
# 생활지도
# 교육경영
# 영미수필론
# 교육철학
# 한국작가연구
# 독일문학이론
# 언어학이론
# 인간론
# 중국문학이론일반
# 영미작가론
# 한국고전문학론
# 한국현대문학론
# 심리학개론
# 역술이야기
# 문학비평/평론
# 인도철학
# 국어의미론
# 한시(인문)
# 교육정책
# 수필론
# 아동심리
# 언어교육
# 영국문학
# 영미문학이론일반
# 영어교육
# 국어음운론
# 교사론
# 교육행정
# 변증론
# 교양철학
# 대학/대학원교육
# 철학사
# 철학개론
# 고대/그리스철학
# 서양문학이론
# 채근담
# 프로이트
# 교육사회학
# 논문작성법
# 우리말의기원
# 프랑스문학이론
# 구비문학/설화
# 속기/속독
# 유아/취학전교육
# 미학
# 현상학
# 아리스토텔레스
# 해석학
# 정보학/정보검색론
# 시간론
# 헤겔
# 고문서
# 시조(인문)
# 국어어휘론
# 융
# 중국시론
# 심리상담이론/진단
# 한국현대시론
# 특수교육이론
# 문학의이해
# 시론
# 고대언어
# 도서관사
# 도교
# 문헌정보학이론
# 분류/목록
# 도서관경영/운영
# 독서지도일반
# 사서
# 서지학
# 예기
# 한국근대소설론
# 천자문/사자소학
# 기타고전일반
# 지식과학문
# 시가(인문)
# 한문학사
# 고전산문
# 한국문학비평
# 동양철학의이해
# 대학/중용
# 임용고시
# 가정/부모교육
# 한글펜글씨
# 예언
# 고등교육
# 공공도서관
# 교육론
# 한국근대시론
# 비교문학
# 사회교육론
# 가요(인문)
# 한국고전작가
# 영미시론
# 프랑스철학
# 유아교육과정
# 기타도서관
# 지역사회
# 한문학의이해
# 인식과사고
# 향가(인문)
# 독일/오스트리아
# 가사(인문)
# 일본문학이론
# 한국현대소설론
# 문학사전
# 음양오행
# 점성술/별자리
# 한국근현대시인
# 한국근대문학론
# 도가
# 한국어교육
# 한자학
# 한국근현대작가
# 가치론/윤리론
# 러시아문학이론
# 마르크스
# 조선시대사상
# 교육사상
# 칼포퍼
# 논리학
# 동양철학이야기
# 북한문학론
# 장자
# 시쓰기
# 인식론
# 전공과목별임용고시
# 교육공학
# 풍수지리
# 관상
# 사주팔자
# 명리학
# 영유아심리
# 노자
# 유아교육기관운영
# 놀이교육
# 몬테소리
# 창의성
# 지능과감각
# 심리치료일반
# 유아연구방법
# 언어교육론/번역
# 유아교육이론
# 유아교육활동
# 현장학습
# 들뢰즈/가타리/데리다
# 자유론
# 자녀교육
# 도덕철학
# 수업방법
# IQ/EQ
# 장애치료
# 교육재정/장학
# 교육제도/법
# 교육조직
# 장애인
# 교육연구
# 인권시민교육
# 발달심리학
# 정신분석학
# 윤리교육
# 진로지도
# 임상심리학
# 인간/인성교육
# 서양교육사
# 성인교육
# 학습평가
# 시청각교육
# 자율학습
# 열린교육/대안교육
# 아동상담
# 차이심리학
# 청소년심리
# 유아교수법
# 행동심리학
# 학습지도방법
# 인지심리학
# 정신지체
# 기타과목
# 특별학습
# 학교교육
# 성교육(교사용)
# 행동지도/수정
# 심리학사
# 학습과기억
# 교육학사전
# 심리검사
# 중학교육
# 수필쓰기
# 문인/작가론
# 대학도서관
# 독서일반
# 장서개발
# 교육방법/학습법
# 꿈풀이
# 꿈
# 아시아문학이론
# 문학교육
# 문학연감/총람
# 한시의이해
# 운명학
# 논어
# 니체
# 서양철학의이해
# 에리히프롬
# 교양심리
# 청소년철학
# 하이데거/아도르노
# 유가/유교
# 주자학/소학
# 미셀푸코
# 감정과정서
# 노장철학
# 작명
# 실존철학
# 토정비결
# 기타나라철학
# 국가/정치윤리
# 역점
# 세계문학이론
# 이상심리학
# 소설론
# 맹자
# 교과교구제작
# 시각장애
# 수화
# 페미니즘문학론
# 언어장애
# 서경
# 시경
# 춘추류
# 수상
# 그외철학자들
# 칸트
# 미국철학
# 중국작가론
# 직업윤리
# 유아교육프로그램
# 존재론
# 아동독서지도
# 유아창작공예
# 세계유아교육
# 영유아보육/육아
# 아동문학론
# 창작/구연동화
# 유아교육실습
# 문자학
# 미국문학론
# 미술치료
# 자폐아
# 역학
# 소설쓰기
# 덴마크철학
# 소크라테스
# 조직심리
# 쇼펜하우어
# 문학사
# 철학에세이
# 교육에세이
# 발달장애
# 한비자
# 경학
# 부적/운명
# 근사록/전국책
# 효경
# 순자
# 플라톤
# 기타나라문학이론
# 하버마스/프랑크푸르트학파
# 형이상학
# 데카르트
# 영국철학
# 인문학의이해
# 포스트모더니즘문학론
# 기호학
# 방과후지도
# 프뢰벨
# 영미문학사
# 중세철학
# 미스테리
# 임용논술
# 초등임용고시
# 독서법
# 에밀/딥스
# 러셀/라이프니치
# 홉스/로크/흄
# 교육사상가일반
# 마키아벨리
# 철학가이야기
# 기록학
# 가족치료
# 한국철학이론
# 스페인문학이론
# 참고봉사
# 양명학
# 화이트헤드
# 중국소설론
# 움베르트에코
# 유아교육신서
# 영미문학비평
# 심리학자일반
# 성교육(청소년용)
# 유학
# 실과교육
# 음악치료
# 영미소설론
# 한국수필론
# 친일문학론
# 게오르크루카치
# 문학
# 한글맞춤법
# 비트겐슈타인
# 현대철학
# 역사교육
# 역술인
# 청소년 인문교양
# 청각장애
# 책세상문고 고전의 세계
# 분석철학
# 놀이치료
# 라캉
# 유치원임용고시
# 학교도서관
# 한길그레이트북스
# 문헌정보학
# 살림지식총서
# 부부치료
# 한국어능력시험
# 타로카드
# 인문고전총서일반
# 한국사능력검정시험
# 독서치료
# 기타종교
# 독서에세이
# 기타언어학자
# 키에르케고르
# 성리학
# 무용치료
# 퇴계사상
# 색채심리
# 실학사상
# 언어/기호학자
# 근대한국사상
# 율곡사상
# 장보드리야르
# 포스트모더니즘
# 크로노스
# 촘스키
# 지식인마을
# 동양철학사
# 월드북
# 인문/사회
# 주자학파
# 유아체육교육
# 러시아시
# 책세상문고 우리시대
# 클라시커
# 시와 이야기
# 현대신서
# 일기/편지
# 감성에세이
# 삼국/고려시대
# 정치/사회
# 정부간행물
# 인간과사회
# 지역사회학
# 북한정치
# 첨단무기
# 정치이론/개론
# 일본정치
# 정치사상사
# 언론/신문/방송
# 정치/외교
# 사회철학
# 사회과학일반
# 법학
# 사회학
# 정치/사회문고
# 사회복지
# 민법
# 국방/군사
# 행정/정책
# 통일관련
# 노사관계
# 노인복지/노년학
# 정치가
# 러시아정치
# 한국정치일반
# 방송론
# PD/기자/아나운서
# 정치일반서
# 고대병법
# 국방/군사일반
# 사회일반서
# 행정학이론
# 전쟁사
# 물권법:부동산
# 경매
# 민법일반
# 물권법:재산법
# 노동문제일반
# 한국외교일반
# 르뽀/시사/비평
# 사회사상일반
# 국제관계
# 수사
# 노동조합
# 민법총칙
# 형법일반
# 사법제도
# 대학보충교재
# 행정법강의
# 형사법
# 형사소송
# 헌법일반
# 한국관련
# 범죄학
# 한국사회/문화
# 사회학이론일반
# 사회사상사
# 기타나라정치
# 언론의자유
# 노동운동
# 정치철학
# 정치사상
# 정치투쟁
# 지방자치일반
# 각국사회/문화
# 전체주의/국가주의
# 민주주의
# 남북관계
# 동북아국제관계
# 법학이론/개론
# 외교정책
# 장애인복지
# 사회복지일반
# 정치비평에세이
# 교정학
# 국제법일반
# 북한사회/문화
# 정당론/정당정치
# 중국정치
# 한미외교
# 한국전쟁
# 외교학
# 보험법
# 선거일반
# 국제사법
# 민사소송
# 비교행정
# 사회심리/여론
# 특허/상표법/의장법
# 언론사/언론학
# 여성학/페미니즘
# 회사법
# 채권법
# 현대사회이론
# 사회문제일반
# 시민운동
# 정치혁명/테러
# 민법판례
# 법학일반서
# 상법총론
# 한국행정
# 형법총론
# 호적법
# 출판제작/인쇄
# 출판학
# 잡지론
# 형사정책
# 생활법률
# 상법일반
# 형사소송법
# 국제거래/조약
# 사회사업
# 행정관리
# 국제기관
# 인사행정론
# 지방자치이해
# 청소년정치사회
# 국제분쟁
# 전쟁
# 아시아정치
# 매스커뮤니케이션론
# 커뮤니케이션론
# 각국행정
# 사회주의/신사회주의
# 법제사
# 경찰학개론
# 마르크스주의
# 인권
# 여성정책/제도
# 조직론
# 한국헌법
# 선거운동
# 강제집행/압류/가처분
# 각종계약/서식
# 노동법
# 영미법
# 각국법/예규
# 판례
# 부속법령집
# 각국헌법
# 비송사건
# 지방행정
# 행정학일반
# 국가보안법
# 한국정치사
# 미래예측
# 군사교육/시설
# 저널리즘
# 정책학일반
# 사회복지법
# 미디어론
# 청소년문제
# 법전/사전/법령집
# 형사소송법연습
# 기업법
# 민법강의
# 자유주의
# 법사회/문학
# 인권문제
# 법철학
# 아동복지
# 행형학
# 근로기준법
# 상법강의
# TV
# 입법
# 노동관계/문제
# 이민일반
# 서양법
# 해상법
# 가족법
# 임금문제
# 방송정책
# 라디오방송
# 미국정치
# 신문기사작성/편집
# 사회통계학
# 신문론
# 정보화사회
# 디지털선거
# 사회과학방법론
# 인터넷방송/케이블TV
# 방송산업론
# 사회정책
# 한국안보
# 국제정치이론
# 정부관련
# 정치사
# 노동정책
# 이데올로기
# 전자정부
# 지역개발
# 국제분쟁/조정
# 사회계층
# 재무행정
# 행정학
# 빈곤/불평등문제
# 행정구제법
# 행정학개론
# 행정기획
# 정책분석론
# 사회보장론
# 민족주의
# 공기업론
# 행정역사/철학
# 관료제도
# 군사전략
# 법학입문서
# 세계외교사
# 경찰제도
# 기타헌법/법률
# 어음법/수표법
# 부실채권/회수
# 파산법
# 저작권법
# 한국근현대정치
# 여성사
# 형법판례
# 민사특별법
# 신문취재/보도
# 사회운동가
# 언론이야기
# 성폭력/성문제
# 중국사회/문화
# 국가와개인
# 사회/문화에세이
# 지방자치행정
# 헌법판례
# 상행위
# 범죄문제
# 사회비평에세이
# 비교정치론
# 사회조사방법론
# 교통사고
# 공정거래법
# 발전행정,행정통제
# 사회복지행정론
# 방송저널리즘
# 소유권:지적재산권
# 행정조사
# 각국형법
# 경찰행정론
# 정책평가론
# 각국민법
# 상속법
# 헌법기출문제
# 이민체험기
# 시민사회/NGO
# 디지털사회
# 방송제작이론/실습
# 사회과학연감/총람
# 언론일반서
# 미국사회/문화
# 남성학/남성문제
# 법조인
# 자원봉사
# 여성학에세이
# 일본사회/문화
# 인구학
# 복지역사
# 혁명사
# 공무원관리론,공무원법
# 각국상법
# 언론인
# 정치학
# 동성애
# 담보물권
# 출판편집
# 전자출판
# 지방정부
# 이민절차
# 가족복지
# 인터넷법률
# 소비자보호법
# 행정법교수사례문제
# 제조물책임법
# 미-이라크전쟁
# 민사집행법
# 대중문화
# 농학/원예
# 사회복지실천론
# 세계복지
# 환경문제
# 다문화사회
# 세계질서
# 국토개발
# 행정/정치/법
# 경제/경영
# 해운
# 경호실무
# 디지털미디어
# 교육문제
# 국방학
# 디지털방송론
# 고용관계법
# 정부규제개혁
# 거버넌스
# 아시아법
# 국제경제법
# 객관식민법
# 행정쟁송법
# 객관식행정법
# 행정조직법
# 사회복지조사방법론
# 객관식헌법
# 행정작용법
# 경찰인사행정
# 행정경영
# 유엔/APEC
# 문화산업
# 국제계약
# 재가복지
# 경호학
# 뉴스
# 환경운동
# 지역연구
# 실버산업
# 대중문화이론
# 멀티미디어
# 문화경제론
# 성/몸
# 여성복지
# 사회복지프로그램
# 방송언어론
# 산업복지
# 국민연금
# 파시즘
# 여성운동
# 형벌/고문
# 사회조직/제도
# 형법기출문제
# 민법기출문제
# 일본대중문화
# 한국언론재단총서
# 비송사건절차법
# 가압류
# 상법기출문제
# 노동해설
# 기계공학이론
# 신학일반
# 기독교일반
# 불교인물
# 신앙생활/영성
# 기독교교육일반
# 설교학
# 강해
# 구약성서
# 종교일반
# 기독교(개신교)
# 불교
# 그외종교
# 가톨릭
# 종교
# 종교이야기
# 불교이야기
# 성경인물
# 종교학이론
# 신앙인물
# 불교경전
# 한글성경
# 복음성가/CCM 음반
# 외국어성경
# 설법CD/TAPE
# 신약성서
# 복음서
# 어린이가톨릭
# 예배
# 불교일반
# 불교철학/사상
# 불교수행
# 사찰/사찰기행
# 법어집
# 기독교성가집
# 기독교음악
# 가톨릭교리
# 가톨릭일반
# 가톨릭신앙생활
# 교회
# 가톨릭인물
# 가톨릭성서
# 미사/성사
# 가톨릭기도/묵상
# 천도교
# 목회/목회자
# 교회론/교회사
# 성서해석
# 설교집
# 비교종교학
# 선교일반
# 칼빈사상
# 설법/법회/의식
# 신비주의
# 불교입문
# 불교사
# 세계불교
# 종교사
# 원불교
# 어린이기독교일반
# 종교사전
# 기독교윤리
# 한국기독교역사
# 성경일반
# 데이트/결혼/가정
# CCM악보
# 어린이불교
# 종교철학
# 기독교상담
# 기독교치유
# 찬송가
# 어린이그림성경
# 주일학교/교사
# 어린이설교
# 레크레이션
# 직분론
# 전도
# 교회행정
# 한영성경
# 성경공부/QT교재
# 기독교문학(소설/수필/시)
# 기독교자녀교육
# 설교CD/TAPE
# 기도/묵상
# 성경문법
# 성지순례
# 기독교역사
# 기독교고전
# 기독교교리
# 다이어리
# 해외선교
# 종교문화
# 성공/리더십
# 제자훈련/사역
# 기독교대인관계
# 가톨릭성가
# 증산도
# 이슬람교
# 의식/성극
# 이스라엘역사
# 한국불교
# 어린이성경책
# 악세사리/기타
# 교회성장
# 불교음반
# 힌두교
# 한국종교학
# 종말/이단론
# 불교선/깨달음
# 조직신학
# 새신자양육
# 여호와의증인
# 신학사
# 기독교이론
# 기독교사회복지
# 티벳불교
# 사모학
# 한국역사
# 행정법
# 재정/예산/결산
# 보험이론/보험법
# 국제정치/국제관계
# 시사/사회비평
# 방송/신문일반
# 상법이론
# 특허/상표/지식재산/저작권
# 민사소송(법)
# 금융시장/정책
# 지방자치
# 이민
# 사회복지행정/실천론
# 형법이론
# 노동법/근로기준법
# 정치비평
# 노동시장/고용/노사관련
# 한국외교
# 여성학/여성문제
# 물권법
# 출판학/실무
# 회사법/기업법
# 선거
# 젠더
# 민법이론
# 시민운동/사회운동
# 헌법이론
# 사회복지론
# 법학이론
# 노동조합/협동조합
# 경찰학/경찰행정
# 형사소송(법)
# 국제법이론
# 채권/파산법
# 사회문제/복지
# 정치/행정
# 사회/문화
# 인문/역사
# 인문교재
# 디지털/정보화사회
# 소송/판례
# 서양철학일반
# 소송판례
# 사회과학이론
# 강제집행/압류/가처분/경매
# 컴퓨터
# 외국어
# 자연과학
# 과학/동식물/환경
# 어린이(초등)
# 속담/고사성어/명언
# 논술/독후감/일기쓰기
# 외국작가
# 한국작가
# 고전/명작
# 세계사/인물/문화/지리
# 한국인물
# 수학
# 문학일반
# 게임/컬러링/만들기
# 과학
# 취미/실용
# 환경/생태
# 영어
# 고전/전래동화/명작동화
# 게임/도감
# 지구/해양/우주
# 철학/사고/심리
# 한국사/문화/지리
# 과학/컴퓨터
# 퀴즈/수수께끼
# 동물/곤충/공룡
# 예술/체육
# 세계사/문화/지리
# 경제/상식/교양
# 건강/인체
# 여행/답사/체험/캠핑
# 자기계발/공부방법/진로
# 한자
# 한글공부/맞춤법
# 세계인물
# 컴퓨터/코딩
# 동시/동요
# 사회문화/사회교육
# 한국사/인물/문화/지리
# 교양/경제/상식
# 식물/꽃
# 국어/한자
# 만화일반
# 종교/신화
# 성교육
# 어린이작가
# 동식물/환경
# TV/애니메이션/영화
# 판타지/모험/SF
# 만화/애니메이션
# 학습만화
# 예술/취미
# 역사/문화/인물
# 동화책
# 그림책
# 책읽기/글쓰기
# 어린이기독교
# 초등학교 입학준비
# 어린이컴퓨터/코딩
# 교과참고/통합교과
# 그래픽노블
# 현대시
# 외국그림책
# 한국그림책
# 알파벳
# 동화/그림책/리더스북
# 영역별영어학습
# 어린이영어
# VIDEO
# CD
# PELT
# 영어만화
# 어린이중국어
# Course Book
# 교과서영어문제집
# 쓰기/작문
# 단어
# 영어노래/챈트
# 듣기/말하기/회화
# 명작동화
# 퍼즐/게임/놀이북
# 파닉스/발음
# 기타영어학습교재
# Flash Card
# 기타교재
# 영어사전
# 리더스북(Readers Books)
# 읽기
# Flap Book/Popup Book
# 창작동화
# 기타시험대비서
# 단계별시리즈
# Math
# 문법
# 읽기/쓰기
# DVD
# EBS영어교재
# 단어/숙어
# Science
# 주니어토익/토플
# 어린이일본어
# 영어성경
# TOSEL
# 홈스쿨링
# 미국교과서일반
# 베오영
# 복합상품
# 노부영
# Social Study
# 교사용지도서
# JET
# NEAT(국가영어능력평가)
# 아동
# 유아
# 자연관찰
# 역사
# 사회/백과/예능
# 자연/과학
# 인물
# 세계명작
# 전래동화
# 백과/예능
# 위인
# 문학/논술
# 한글/영어/수학
# 외서전집
# 어린이전집
# 번역
# 기타외국어
# 영어일반
# 영어문법/독해/작문
# 일본어일반
# 영어학습법
# 수험영어
# 비즈니스영어
# 독일어
# 비즈니스회화
# 중국어일반
# 일본어능력시험/JPT
# HSK/중국어시험
# 영어문고
# 영어회화/청취
# 프랑스어
# 영어독해
# 스페인어
# OPIc
# GMAT
# 영어독해일반
# Vocabulary
# 비즈니스일본어
# 일본어첫걸음
# 국어사전
# 일어작문
# 종합
# 프랑스단어/어휘
# 일상회화
# 기타
# Speaking
# 방송영어(CNN/AFKN)
# 영영사전
# 일반문법
# 생활영어
# 일반회화
# 일본어학
# 방송영어교재
# 여행회화
# 영화/드라마영어
# 한자사전
# 영어학이론
# Idiom
# 독해법
# 단어/어휘
# L/C
# 모의고사/테스트
# 기초문법
# G-Telp
# 기초회화
# 명문/사설
# 영한사전
# R/C
# 중국어첫걸음
# 중/고급문법
# 독일어문법
# 중국어학
# 비즈니스영작
# 독일어학
# 통역
# 프랑스어학
# 프랑스독해
# 초급회화
# 유학안내서
# 관광영어
# 중급일본어
# 유학일반
# 중국어학습서
# 중고급독해
# 기타영어문고
# 일한사전
# 일본어단어
# 독일어독해
# 중한사전
# 스페인어단어/문법/회화
# 중국어문법
# 중국어청취/발음
# 일본유학시험/기타시험
# 러시아어단어/문법/회화
# 독일어단어/어휘
# 기타수험서
# 일본어한자
# 기타서양어
# 영어발음
# 프랑스문법/작문
# 독일어첫걸음
# 일본어펜글씨
# 중고급회화
# SAT
# 불어사전
# 독어사전
# GRE
# 기타외국어사전
# 러시아사전
# 영어듣기
# LSAT
# 스페인어사전
# Business
# Resource Book
# 한중사전
# 영어작문일반
# Reading
# Listening
# 영어첫걸음
# Writing
# Course Book Tape
# 영어일기
# 스페인어첫걸음
# AP
# 한영사전
# 일본어청취/발음(스크린일본어)
# 호텔영어
# 프랑스작문
# 일본어능력시험1급
# 영어팝송
# 전화영어
# 중국어작문
# 상황별회화
# 초급독해
# 대역문고
# 프랑스회화
# 다락원문고
# 일본어능력시험3급/4급
# 일본어능력시험2급
# 독일어회화
# HSK모의고사/테스트
# HSK독해/문법
# HSK
# 만화
# 기타동양어
# 한일사전
# 기타나라어학
# 초등영어사전
# 이탈리아어
# 프랑스어첫걸음
# 기타일본어사전
# 포르투칼어
# 영어편지/펜팔
# 러시아어첫걸음
# 중국어단어
# Grammar
# IELTS
# 펭귄시리즈
# 영어회화사전
# 시사영어사명작문고
# HSK듣기
# HSK종합
# 영어슬랭
# 국제회의
# oxford문고
# 유학성공기
# 한자읽기사전
# 스페인어학
# 교실영어
# 인문/사회일반
# 독일어작문
# 일본어어휘
# JPT 종합
# 성경
# JPT 모의고사/테스트
# 신아사영어문고
# 영한/한영합본사전
# 영어속담
# 러시아어학
# SSAT
# 청취/어휘
# 문법/독해
# 한어교정
# 영어논문
# 외국소설
# JPT 단어/어휘
# 어학/교육
# 수입영어사전
# Work Book
# 소설
# 어린이
# 사전
# 경제
# 예술/실용
# 중국어어휘
# 과학/기술
# JPT 독해/문법
# JPT 청해
# E-MAIL
# 시험대비문법
# TSC
# HSK어휘/단어
# 외래어사전
# 월드컴문고
# 시험대비독해
# 유아그림책
# 유아학습
# 유아(0~7세)
# 유아완구/교구/블록
# 세계명작그림책
# 한글/국어학습
# 숫자/수학학습
# 사물익히기
# 식물/자연
# 동물/공룡/곤충
# 스티커북/색칠하기
# 몸/인체
# 퍼즐
# 학습지일반
# 종이접기/만들기
# 올바른생활습관
# 벽보
# 과학/발명/기계
# 토이북
# 논리/창의력
# 역사/지리
# 지구/우주
# 한자배우기
# 그림찾기/미로/게임북
# 감정/감각/인지능력계발
# 인물동화
# 플래시카드
# 동요/동시
# 성교육그림책
# 생각/철학
# 사회성키우기
# 팝업북/플랩북
# 음악/미술
# 헝겊책
# 목욕책
# 그림이있는에세이
# 그림책일반
# 영어영역
# 수학영역
# 영어/수학일반/한자
# 고등학교 과목별
# 논술/면접대비
# 대입진학자료
# 공부방법/진학
# 중학교 학년별
# 수학관련
# 예비중학
# 중/고등참고서
# 중고등경시/올림피아드
# 중고학습문학
# 국어
# 예체능/기타과목
# 영문법
# 총정리
# 독해
# 청소년 고전
# 청소년 소설
# 한국사/동아시아사/세계사/지리
# 기초영어/영어
# 청소년 에세이
# 사회탐구영역
# 국어영역
# 과학탐구영역
# 수능종합모의고사
# 논술교재
# 제2외국어/한문
# 공부방법
# 고입검정고시
# 대입검정고시
# 생활과윤리/윤리와사상
# 사회/법과정치/경제
# 직업탐구영역
# 사회탐구영역:사회/법과정치/경제
# 기초수학/수학
# 융합과학/생명과학/화학
# 과학탐구영역:지구과학
# 한국사영역
# 과학탐구영역:물리
# 과학탐구영역:생명과학
# 사회탐구영역:한국지리/세계지리
# 사회탐구영역:생활과윤리/윤리와사상
# 국어③/④
# 과학탐구영역:화학
# 특목고대비교재
# 학습다이어리
# 국어①/②
# 듣기/듣기TAPE
# 체육/음악/미술/기타
# 기술가정
# 지구과학/물리
# 사회/정치/경제/윤리
# 사회/역사/도덕①②
# 기술가정①②
# 사회탐구영역:동아시아사/세계사
# 국어⑤/⑥
# 사회/역사/도덕
# 진로
# 논술단행본
# 청소년 문학기타
# 제2외국어영역/한문
# 청소년 시
# 시험성공수기
# 수시/적성검사
# 미적분
# 실용영어/심화영어
# 구술/면접
# 중간고사(중등)
# 확률과통계/기하와벡터
# 명문대진학
# EBS 만점마무리
# EBS 수능특강
# EBS 기타고등과정
# EBS FINAL 실전모의고사
# 개념원리
# 쎈수학
# EBS 예비과정
# EBS 뉴탐스런
# 잡지
# 입시안내
# 수능문제집
# 입학사정관제
# 고급수학
# 특목고진학
# 핵심
# 자습서
# 기말고사(중등)
# 셀파
# 교과서 평가문제
# 우공비
# 일품
# 1등급 만들기(일등급 만들기)
# 강남구청 인터넷교재
# 평가문제집
# 완자
# 텍스트
# 자이스토리(XISTORY)
# 알짬
# 숨마쿰라우데
# 꿈틀
# 청소년 정치사회
# 청소년 자기계발
# 청소년 철학
# 청소년
# 청소년 예술
# 진로/직업소개
# 청소년 교양과학
# 초등참고서
# 학습교구
# 논술
# 전과목
# 수학/연산
# 사회
# 초등1학년
# 초등3학년
# 초등4학년
# 통합교과(바슬즐)
# 예체능
# 동아전과
# 초등2학년
# 초등5학년
# 초등6학년
# 경시대회/올림피아드
# 수학경시대회
# 국어/논술/글쓰기
# 영재학습지
# 단계별 학습지
# 한문/한자
# 산수/연산학습
# EBS 만점왕
# 백점맞는시리즈
# 열공기출
# 기출예상
# 글쓰기/논술학습
# 베스트해법
# 자산관리사/재무위험관리사
# 인적성/직무능력
# 취업
# 취업/수험서
# 공무원 행정학
# 고시
# 국가자격증
# 전문직자격증
# 공무원 과목별
# 편입/독학사
# 공무원 직군별
# 공인노무사
# 경제/금융/회계자격증
# 공인중개사2차
# 그외기술직
# 일반상식
# 공무원 종합본
# 변호사시험
# 외무/행정고시
# 공무원 국어
# 관세직
# 공무원 경제학
# 공무원 한국사
# 공무원 헌법
# 공무원 행정법
# 편입영어
# 공인중개사1차
# 세트/모의고사
# 주택관리사1차
# 주택관리사2차
# 법원직/검찰사무직
# 공기업/공사/공무원
# 보험설계/판매관리사
# 면접일반
# 영어면접
# 건축/토목/응용역학
# 일반
# 물류관리사
# 편입일반
# 공무원 영어
# 공인회계사
# 감정평가사
# 컴퓨터공학
# 경비지도사/경호원
# 경찰형법
# 경찰기타과목
# 경찰실무
# 공무원 일반
# 소방국어/국사
# 공무원 형법
# 공무원 형사소송법
# 공무원 사회
# 법무사:상법/형법/공탁법
# 기타자격증 및 자격증안내
# 경찰국어/국사
# 법무사:민법/호적법
# 소방종합본
# 경찰영어
# 손해사정사
# 법무사:기출문제/모의고사
# 변리사
# 공무원 교정학
# 공무원 회계학
# 보건/간호학
# 롯데
# 삼성
# 기계공학
# 화학/환경공학
# 자동차구조/교통법규
# 소방영어
# 군무원/부사관
# 경찰형사소송법
# 세무사
# 직업가이드/유망직업
# 관광/호텔수험서
# 품질경영기사
# 취업전략
# 자기소개서/이력서
# 경찰행정/행정법
# 소방승진
# 경찰수사
# 매경TEST
# 전기/전자/무선통신
# 공무원 교육학
# 조경/농업/임업학
# 식품위생
# 직업상담사
# 사회복지학
# 부동산/임대수험서
# 법무사:부동산등기
# 법무사:헌법
# 독학사
# 공무원면접
# 경찰종합본
# 증권투자상담사/분석사
# 소방학개론/법규
# 우편금융상식/컴퓨터일반
# 관세사
# 농협
# 취업논술
# 국제법/국제정치학
# 유통관리사
# 국제무역사/무역영어
# 사회복지사
# 소비자전문상담사/CS리더
# 공직적성검사(PSAT)
# CJ
# 회계관리사
# 취업일반
# 계리직
# 공인중개사
# 공무원 수학
# 법학적성시험(LEET)
# TESAT경제이해력검증시험
# 사회조사분석사
# 행정직
# 텔레마케팅관리사
# 사회복지직
# 공무원 과학
# 행정사
# ERP정보관리사
# 경영지도사
# 귀화시험
# LG
# 민법/민사소송법
# 기술/공학
# 현대
# 새마을금고
# 두산
# SK
# 조리직/식품위생직
# 관세법
# 해양경찰
# 교육행정직
# 교정직
# 자료조직/정보봉사
# 축산/수산학
# 전산직
# 보건직/간호직
# 세무직
# 공무원 세법
# 조경직/농업직/임업직
# 세법이론
# 기계직
# 웹사이트기획
# 플래시
# 엑셀일반
# 프로그래밍일반
# AUTOCAD
# 3DSMAX
# 디지털기기
# 프로그래밍 언어
# 네트워크
# 게임
# 컴퓨터입문/활용
# CAD
# 웹사이트
# 컴퓨터/IT
# 그래픽
# 데이터베이스
# OA/사무자동화
# OS
# 웹프로그래밍
# 개발방법론
# 자격증/수험서
# 건축CAD/CAM
# 컴퓨터공학/과학개론
# C
# 마이크로프로세서일반
# 네트워크일반
# 마이크로로봇
# 멀티미디어일반
# 8051/80196/Z-80
# 보안/해킹
# 한글
# Mac OS
# 컴퓨터자격증일반
# Visual Basic
# 워드프로세서
# 컴퓨터그래픽스
# 그래픽일반
# PC조립/튜닝
# 컴퓨터구조
# 컴퓨터교육
# OA관련서
# C++
# PADS/PCB
# 워드
# 인터넷입문/활용
# 전산통계/수치해석
# 정보처리기사
# 자료구조/알고리즘
# 게임일반
# 정보시스템
# 전산수학/이산수학/전산영어
# SPSS/SAS
# 정보기기운용기능사
# 사무자동화산업기사
# WindowsXP/Vista/7
# 컴퓨터활용능력
# 컴퓨터그래픽스운용기능사
# 데이터베이스일반
# 유닉스
# C#
# 파워포인트일반
# SQL
# 개발방법론일반
# 컴퓨터음악/음향
# 소프트웨어공학
# 인공지능일반
# 게임기획
# Java
# 오피스종합
# 엑셀매크로/VBA
# 게임공략집/가이드북
# AVR
# 엑셀통계
# 컴퓨터애니메이션
# 포토샵일반
# 설계프로그램일반
# ITQ
# TCP/IP
# 지리정보(GIS)
# 자료분석/빅데이터
# 운영체제론
# 엑세스2000/2002/2003
# PIC
# 일러스트레이터
# 디자인패턴
# 엑셀2000/2002/2003
# CATIA
# 전산회계운용사
# IT일반서
# 프로젝트관리
# SNS/블로그/검색
# Server
# 기타3D그래픽툴
# 전자상거래관리사
# PHP
# HTML/CSS3
# WindowsServer2000/20
# ORCAD
# Visual C++
# 웹디자인
# CAD자격증일반
# Oracle
# 유비쿼터스/RFID
# 리눅스
# 드림위버
# 엑셀2007/2010/2013
# VisualC++.NET/Visual
# MATLAB
# 윈도우프로그래밍일반
# 쇼핑몰/전자상거래
# 나모웹에디터
# 프리미어
# 웹프로그래밍일반
# UCC/영상처리
# 캐릭터디자인
# JSP
# 전산세무회계사
# 포토샵CS
# 파워포인트2000/2002/2003
# Windows일반
# DIAT
# 정보보안기사
# LABVIEW
# 유니그래픽스
# Python(파이썬)
# 안드로이드
# JavaScript
# 프리젠테이션
# SNS/트위터/페이스북
# 웹서비스
# MOS
# 파워포인트2007/2010/2013
# 블로그/홈페이지
# GTQ/웹디자인기능사
# 애프터이펙트/아크
# 엑세스2007/2010
# ASP.NET
# 라이트룸
# 베가스
# 모바일프로그래밍일반
# 스마트폰/태블릿
# 동영상/인터넷방송
# 게임개발일반
# ASP
# 라이노3D
# 인디자인
# jQuery
# e-test
# IT교양서/IT에세이
# 임베디드
# PMP/CAPM
# 인벤터
# 솔리드웍스
# 유니티
# MAYA
# 가상현실/증강현실
# XML
# .NET일반
# Flex
# AJAX
# 아이폰/아이패드
# UX/UI
# 언리얼
# 아두이노
# 코딩
# 딥러닝/머신러닝
# 블록체인
# 사물인터넷
# 프로엔지니어링
# 모바일게임
# 소나/큐베이스
# ARM
# 케라스/텐서플로
# 청소년컴퓨터
# 정보통신공학
# 예술/대중문화
# 기타언어 사용자 대상
# 어린이문학
# 일본어 사용자 대상
# 명언/지혜
# 한국어학습 일반
# 영어권 사용자 대상
# 어린이교양
# 공직윤리/공무원
# 형사정책/교정
# 방통대교재
# 초등1-6학년
# IT일반
# 기술공학
# 논리/창의력학습
# 정치/사회/법
# 영어단어/어휘
# 국어/한문/언어
# 일본어
# 중국어
# 정치/행정교재
# 농학교재
# 영화교재
# 교육교재
# 법학교재
# 간호교재
# 사회/문화교재
# 관광교재
# 농학
# EBS 고등
# 0세부터100세그림책
# 토플(Toefl)
# 영어문법
# 영상편집
# 초등1-2학년
# 학년별 개념/문제
# 중국어회화
# 공인중개사/주택관리사
# 어학사전
# SAT/GRE/GMAT/IELTS
# 토익(Toeic)
# 결혼/가정
# 가정/육아
# 임신
# 자녀교육일반서
# 육아일반
# 태교
# 부부이야기
# 지능개발
# 독서교육
# 출산
# 학습교육
# 행복한 가정
# 부모교육
# 결혼
# 이혼
# 육아일기
# 조기영어교육
# 수교육
# 태교동화
# 홈인테리어일반
# 유태인교육법
# 가베
# 임산부건강
# 모유수유
# 경제교육
# 기공체조
# 건강일반
# 한방치료
# 뇌건강
# 질병치료/예방
# 건강이야기
# 건강
# 다이어트
# 건강문고
# 다이어트일반
# 피부관리방법
# 마사지
# 단학
# 암
# 다이어트비디오
# 수맥
# 식품과건강
# 명상
# 자연치유
# 자연식건강
# 민간요법
# 손/발건강
# 장수
# 건강상식
# 한방건강
# 성생활
# 금연/금주
# 스트레스
# 성인병
# 기건강
# 헬스/웨이트트레이닝
# 동의보감
# 단전호흡
# 경락/경혈
# 응급처치
# 대체의학
# 물건강
# 자연요법일반
# 한방약초
# 국선도
# 뇌혁명
# 수험생건강법
# 수면
# 요가
# 건강음식
# 사상체질
# 피부미용일반
# 치질/변비
# 단식
# 스트레칭
# 여성건강
# 최면치료
# 허브/아로마요법
# 자연식품/생식
# 뇌호흡
# 약물중독
# 디스크/척추
# 노후건강관리
# 요통
# 아토피/여드름(피부질환)
# 눈건강
# 식생활과건강
# 정신건강
# 남성건강
# 치매
# 코/귀/치아건강
# 탈모
# 잘 먹고 잘사는 법
# 새집증후군
# FAMILY DOCTOR
# 건강문고기타
# 로맨스만화
# 웹툰/카툰에세이
# 기타만화
# 액션/무협만화
# 역사만화
# 명랑/코믹만화
# 탐정/추리
# 직업만화
# 성인만화
# SF/판타지
# 일상생활/드라마/가족만화
# 스포츠만화
# 고전/문학작품만화
# 요리만화
# 동물등장만화
# 공포/스릴러
# 학원만화
# 웹툰일반
# BL만화
# 도박만화
# 시사/비평
# 그래픽노블일반
# 교양
# 일상생활/드라마
# 액션/무협
# 캐릭터퍼즐
# 캐릭터일반
# 로맨스
# 명랑/코믹
# 실용/취미
# 세계여행
# 국내여행
# 국내여행일반
# 해외여행
# 여행에세이
# 테마여행
# 여행
# 도로지도
# 전국지도
# 유럽여행일반
# 중국여행
# 세계지도
# 답사여행
# 호주/뉴질랜드
# 아프리카여행
# 아시아여행일반
# 미국여행
# 동남아여행
# 유럽지도
# 아프리카지도
# 서울/수도권
# 캠핑/드라이브/기차여행
# 경상도
# 홍콩/마카오/대만여행
# 일본여행
# 충청도
# 배낭여행
# 제주도
# 괌/사이판/하와이
# 강원도
# 전라도
# 오지탐험/산여행
# 인도/티베트여행
# 맛집여행
# 지구본
# 아시아지도
# 북남미지도
# 주말여행
# 터키여행
# 프랑스여행
# 이탈리아여행
# 체험/미술관/박물관여행
# 바다/섬여행
# 워킹홀리데이
# 실크로드여행
# 영국여행
# 사찰여행
# 스페인여행
# 카페여행
# 중남미여행
# 지도
# 해외지도
# 국내지도
# 북남미여행
# 유럽여행
# 러시아여행
# 독일여행
# 캐나다여행
# 뉴욕
# 걷기/자전거여행
# 체코여행
# 북유럽여행
# 시/에세이
# 한국에세이
# 예술기행
# 음악사
# 예술가이야기
# 음악
# 예술일반
# 디자인/색채
# 사진/영상
# 영화이야기
# 연극
# 예술문고
# 국내희곡작품
# 영화
# 미술
# 패션/의류
# 타악기
# 록/팝송
# 예술론
# 국내가곡
# 예술이야기
# 산업디자인
# 분장/무대예술
# 소나티네
# 성악/합창이론
# 미술가이야기
# 체르니
# 사진촬영기법
# 패션디자인
# 아시아영화
# 미술작품집
# 미술사
# 동양회화
# 국외사진집
# 색채이론
# 국악실기/교육
# 국악이론
# 영화사
# 드라마작품
# 판소리
# 국내사진집
# 보석디자인
# 국외화집
# 동요
# 시각디자인
# 영상학/영상편집
# 디자인이론
# 국내화집
# 종교화/불교미술
# 드로잉
# 수채화
# 인물화
# 예술사전
# 미술교육
# 심볼/마크
# 음악이론/원리
# 조형/조각
# 서예일반
# 패션이론
# 연극이론
# 미술사전
# 도안
# 장식
# 타이포그래피
# 삽화/일러스트기법
# 유럽희곡
# 연기론
# 국내연극
# 동요/반주집
# 세계문양
# 공예
# 도자/유리공예
# 전통예술/문화재도록
# 예술연감/총람
# 영미희곡작품
# 현대패션이론
# 패션이야기
# 양재/봉제
# 피복재료/소재
# 한국복식사
# 패턴메이킹/의복제작
# 서양복식사
# 의류학
# 패션사전/배색사전
# 섬유학
# 패션마케팅
# 패션일러스트
# 한복
# 대위법
# 음악가이야기
# 화성/화성학
# 희곡론
# 국외연극론
# 데생
# 한국회화
# 희곡작법
# 민요
# 사진이론
# 직물학
# 염색
# 염직물공예
# 음악철학
# 미술이야기
# 음악교육
# 어린이미술교재
# 한글서예
# 패션연출방법
# 풍경화/풍물화
# 정물화
# 한국문양
# 회화재료/기법
# 유화
# 드라마이론
# 한국영화론
# 재즈피아노
# 대중가요
# Guitar 일반
# 기타건반악기
# 포크/통기타
# 클라비어/하모니카
# 러시아희곡
# 연주/지휘
# 일본 대중음악
# 만화작품집
# 음악이야기
# 합창곡
# 음악사전/잡지
# 재봉수험서
# 학년별 음악공부
# 어린이음악교본
# 피아노이론
# 전통문양
# 대중음악비평/감상
# 연예인이야기
# 사진이야기
# 서양회화
# 아시아희곡
# 반주법
# 그외 관현악기
# 록/베이스기타
# 플룻
# 색소폰
# 소곡집/명곡집
# 영화/드라마악보
# 영화음악
# 클래식기타
# 트럼펫
# 작곡/편곡
# 바이올린
# 애니메이션일반/만화영화
# 시나리오작법
# 연극이야기
# 영화이론
# 영화제작
# 레터링
# 광고/간판
# 연극사
# 빛깔있는 책들
# 인형극/아동극
# 미술론
# 클라리넷
# 셰익스피어 희곡론
# 부르크밀러
# 바이엘
# 한국희곡론
# 국외가곡
# 패션디스플레이/텍스타일
# 패션도식/드레이핑
# 패션토탈코디네이션
# 영화인
# 사진실기
# 편화
# 바하/베토벤
# 판화
# 입시구성
# 수묵
# 공연예술기타
# 회화이론
# 발성
# 합창/지휘
# 포장디자인
# 예술사일반
# 풍속화
# 현악기
# 취주악기
# 그외악기
# 리스트
# 가극/기타극음악
# 기타작곡가
# 사진가
# 고고미술/미술사학
# 시나리오집
# 예술경영/투자
# 교향곡
# 가요/팝악보
# 첼로
# 리코더/오카리나
# 스즈키 바이올린
# 음악형식
# 오페라/아리아
# 재즈
# 하아프
# 호만 바이올린
# 어린이 피아노교본
# 서체자전/천자문
# 알프레드
# 공연제작/ 연출
# 동양희곡론
# 만화작법
# 금속공예
# 일러스트집
# 멘델스존/브람스
# 슈만/쇼팽
# 모짜르트
# 슈베르트
# 국악이야기
# 연탄곡집
# 합주곡
# 하농
# 기타작곡집
# 시창/청음
# 시공디스커버리
# 영미희곡론
# 열화당 미술책방
# 영화연감/총람
# 연극/영화
# 영화감독론
# 작가론
# 기타나라희곡
# 뮤지컬
# 청소년예술
# 우쿨렐레
# 어드벤쳐교재
# 라흐마니노프
# 캘리그래피
# 방송작가작품
# 한국현대미술
# 예술교육
# 헐리웃영화론
# 연극인
# 북아트
# 컬러리스트
# 독립영화
# 연극교육
# 컬러링북
# 환경구성
# 예술문고기타
# 드라마/시나리오
# 패션/유행
# 미술실기/기법
# 회화
# 공예/장식
# 서예
# 예술사
# 미술이론
# 교양미술
# 대중예술
# 디지털카메라
# 발라드
# 한국 대중음악
# 영화마케팅
# 카툰 캐릭터
# 예술심리/시각
# 열화당 사진문고
# 사진역사
# 망가/아니메
# 사진편집
# 시공아트
# 서예이론/교본
# 베이식 아트
# 퍼포먼스/마임
# 즐거운지식여행
# 조주/술
# 요리
# 전문요리
# 테마별요리
# 한국요리
# 재료별요리
# 서양요리
# 일본요리
# 조리사
# 한국음식
# 도시락,샌드위치
# 다도/차
# 서양음식
# 베이킹/간식
# 칵테일
# 요리일반
# 건강요리
# 전통음식,김치
# 사찰음식
# 식탁예절
# 제과제빵기사
# 와인
# 반찬/밑반찬
# 신세대스피드요리
# 계절요리
# 국/찌개/탕
# 채식,샐러드
# 과일,초대요리
# 이유식
# 분식
# 밥/죽
# 한권이면OK
# 명절음식
# 전문가요리비법
# 다이어트식
# 어린이요리
# 중국요리
# 일본음식
# 조주기능사
# 아침,점심,저녁
# 커피
# 요리에세이
# 연예인
# 푸드코디네이트
# 주스
# 퓨전요리
# 중국음식
# 식당/음식점
# 문학/교양
# 외국잡지
# 의학/건강
# 컴퓨터/웹
# 레저/스포츠
# 시사/사회
# 여성/리빙
# 교육
# 예술/문화일반
# 자동차
# 건축/인테리어
# 영화/연극
# 연예
# 육아/어린이
# 인문/역사/종교
# 골프/바둑/낚시/등산
# 기계/기술/공학
# 역사/철학
# 시사/정치/경제/경영
# 그래픽/디자인
# 예술/문화
# 취미일반
# 사진
# 여성/리빙/남성/육아
# 남성
# 비즈니스소양
# 주간/격주간지
# 한국일반
# 한국소개도서
# 건축품셈/적산/일위대가
# 교양/문학
# 시조
# 골프
# 무술
# 스포츠
# 바둑
# 퀴즈/퍼즐/스도쿠
# 취미/실용/스포츠
# 체육
# 애완동물
# 레크레이션/게임
# 등산/낚시
# 걷기
# 체육교육학
# 스포츠의학
# 무용이론
# 기타지상스포츠
# 운동과건강/생활체육
# 수영
# 체육위생/영양학
# 에어로빅
# 무술일반
# 체육이론
# 체육측정/체육능력
# 스포츠마케팅/스포츠경영
# 취미기타
# 스키/스케이팅
# 낚시일반
# 꽃/화초/화췌
# 마술
# 책갈피
# 농구
# 바둑일반
# 애견기르기
# 볼링
# 댄스스포츠
# 공예/기타
# 채소재배
# 자동차/카레이싱
# 대학체육
# 태권도
# 배구
# 체육사회학/사회체육
# 윈드서핑
# 옷만들기
# 가계부
# 낚시터/낚시지도
# 손뜨개
# 골프일반
# 축구
# 열대어기르기
# 발레
# 체육수험서
# 마라톤/달리기
# 코칭/트레이닝
# 한국무용
# 등산지도
# 엽서
# 무용교육
# 무용사
# 야구
# 체육심리학
# 운동처방학
# 살림의지혜
# 테니스/스쿼시
# 탈춤/가면극
# 퀴즈
# 프로실전바둑
# 중국무술
# 클레이/지점토
# 무용일반/무용평론
# 캘린더
# 우표/주화수집
# 항공스포츠
# 배드민턴
# 탁구
# 핸드볼
# 국내등산
# 소품/DIY
# 퀼트
# 인형만들기
# 허브
# 꽃꽂이
# 유도
# 프로골퍼레슨
# 당구
# 인라인스케이팅
# 카드게임
# 해외등반
# 검도
# 보드게임
# 등산일반
# 수석
# 로또/복권/경마
# 기타수상스포츠
# 스텐실/톨페인팅
# 현대무용
# 네모네모로직
# 종이접기
# 기타구기종목
# 호신술
# 선물포장/리본
# 스노클링/스쿠버다이빙
# 승마
# 풍선아트
# 자수/바느질
# 스도쿠
# 피규어/프라모델
# 고양이기르기
# 홈인테리어/수납
# 자전거하이킹
# 텃밭가꾸기
# 정리/수납
# 목공예
# 비즈
# 기타동물기르기
# 운동선수/무도인
# 카약/카누/조정/요트
# 세계전통무용
# 무용
# 일본에세이
# 한국문화예술
# 리빙/라이프
# 수영/수상스포츠
# 퍼즐/퀴즈
# 전통무용
# 스키/빙상스포츠
# 보드게임/카드
# 카레이싱/자전거
# 스포츠일반
# 댄스스포츠/에어로빅
# 마라톤/달리기/걷기
# 무술/호신술
# 고양이
# 체육/스포츠이론
# 가정원예
# 등산
# 강아지/개
# 체육/스포츠일반
# 테니스/배드민턴
# 꽃꽂이/화초
# 가정
# 미디어
# 간호/건강
# 가정교재
# 사진에세이
# 여행/패션
# 반려동물일반
# 육아
# 반려동물
# 생활공예/DIY
# 텃밭가꾸기/채소재배
# 주간/월간/계간지
# 인기지역
# 한국소설일반
# 역사/대하소설
# 한국소설
# 영미소설일반
# 프랑스소설
# 고전소설/문학선
# 북유럽소설
# 영미소설
# 기타나라소설
# 중국소설
# 청소년소설
# 북유럽소설일반
# SF/과학소설
# 독일소설
# 독일소설일반
# 러시아소설일반
# 일본소설일반
# 미스터리/스릴러소설
# 중남미소설
# 프랑스소설일반
# 로맨스소설
# 무협소설
# 이탈리아소설
# 역사소설
# 드라마/영화소설
# 공포/호러소설
# 스페인소설
# 여러나라소설
# 판타지소설
# 라이트노벨
# 아프리카소설
# 범우문고
# 중국소설일반
# 그외유럽소설
# 일본라이트노벨
# 자전적에세이
# 틱낫한
# 기타나라시
# 탈무드
# 한국시
# 장르시
# 시/에세이문고
# 지혜/상식
# 나라별 시
# 테마에세이
# 인물/자전적에세이
# 나라별 에세이
# 문인/작가
# 프랑스시
# 프랑스에세이
# 명시모음
# 크리슈나무르티
# 기타국가에세이
# 영미에세이
# 독일에세이
# 독일시
# 러시아에세이
# 중국시
# 영미시
# 중국에세이
# 라즈니쉬
# 교훈/지혜
# 명언
# 명상에세이
# 그림이 있는 시
# 일본시
# 시/에세이문고 일반
# 문학기행
# 사랑에세이
# 사랑시
# 인생이야기
# 한시
# 포토에세이
# 연하도서/카드도서
# 여러인물/인터뷰
# 국내기업가
# 종교인
# 시가
# 에버그린문고
# 사진이 있는 시
# 청소년자기계발
# 자녀훈
# 유머
# 한국문학
# 동물등장에세이
# 사랑/연애에세이
# 캐릭터에세이
# 그림에세이
# 명상/치유에세이
# 시조/한시(고전)
# 기타나라/여러나라시
# 노년에세이
# 장르소설
# 문학/소설/시
# 문학/소설/시교재
# 청소년 시/에세이
# 지구과학이론
# 과학이야기
# 물리학
# 생물학
# 교양과학
# 과학이론
# 선형대수학
# 수학일반
# 공업수학/대학수학
# 물리학이론
# 미분적분학
# 동물/곤충/어류도감
# 화학사전
# 화학이론
# 수학이론/수학철학
# 확률
# 달/태양/별
# 과학이론일반
# 교양천문학
# 이론천문학
# 과학의역사
# 역/달력
# 우주/UFO
# 고분자화학
# 물리이야기
# 미생물학
# 생물학이론
# 과학사전
# 교양생명과학
# 생물과학
# 지구
# 과학자
# 기초물리학
# 광학
# 교양자연
# 과학기술사전
# 해양학
# 물리화학
# 화학공학
# 수리물리학
# 통계이론
# 통계학일반
# 기하학
# 집합/함수론
# 수학사
# 현대대수학
# 식물학
# 진화론/종의기원
# 교양식물
# 교양곤충
# 식물도감
# 생물이야기
# 유기화학
# 무기화학
# 유전학
# 일반물리학
# 심령과학
# 분자생물학
# 미생물학실험
# 원자력/핵/방사선
# 생화학
# 일반화학실험
# 동물학
# 동물이야기
# 발견/발명
# 교양수학/수학이야기
# 대학물리학
# 대학화학
# 분석화학
# 기상학/기후학
# 생태학
# 일반화학
# 기초수학
# 양자역학
# 지구물리학
# 수학사전
# 현대물리학
# 지형학
# 과학철학
# 암석학
# 첨단물리학
# 교양화학
# 생물철학
# 성과학
# 유기화학실험
# 생물학사전
# 기기분석
# 구조지질학
# 순수과학연감/총람
# 정수론
# 초과학/초능력
# 뇌과학
# 자연생태기행
# 고생물학
# 유전이야기
# 음향학/진동학
# 발생생물학
# 생활물리
# 교양지구과학
# 물리학사전
# 옥스퍼드 위대한 과학자
# 선생님도 놀란 과학뒤집기
# 과학자들이들려주는과학이야기
# 인체이야기
# 카오스/빛/양자
# 교양과학문고
# 인간복제
# 별자리
# 면역,세포
# 화학
# 과학공화국 법정
# 동물에세이
# 바칼로레아
# 주니언스
# 사이언스 마스터스
# 천문학
# 내연기관
# 건축문화
# 교양건축/건축이야기
# 도시학
# 국외건축가
# 식량문제
# 건설중장비운전기능사
# 농수산/축산
# 전기/전자
# 자동차/운전
# 환경/소방/도시/조경
# 토목/건설
# 의학
# 기계/역학/항공
# 생활과학
# 건축론/비평
# 전기공학
# 토목구조이론
# 교통공학
# 산림학
# 운전면허1종
# 전기기계/기구일반
# 전기공사/설비일반
# 발전
# 방약합편
# 농업교육/연구
# 환경일반서
# 자동차일반
# 첨단과학/과학기술
# 헤어/퍼머
# 인체생리학/해부학
# 치과의학
# 안테나/위성통신
# 전자공학이론
# 데이타통신
# 디지털공학
# 전자회로
# 제어시스템
# 무선공학
# 무선설비기사/통기기기기능사
# 통신공학/이론
# 전기/전자자격증일반
# 항공/우주공학
# 전자기학/전기자기학
# 정보통신기사
# 전자계산기
# 전자기사/전자기기기능사
# 신호처리
# 회로이론
# 전기회로
# 요업/복합재료
# 텔레비젼공학
# 기계설계/제도
# 전력
# 기계공작
# 디지털논리회로
# 반도체공학
# 자동차정비자격증
# 전기기사/전기공사기사
# 전자계산기사
# 전파공학/레이더공학
# 비뇨생식기
# 당뇨/혈압/성인병
# 미용학/피부관리
# 산과/부인과
# 메이크업
# 각과한의학
# 한의약학이론
# 가축사육
# 침구/경락/경혈
# 제조업
# 인테리어/가구/조명
# 작품집일반
# 서양건축사
# 소화기
# 산업안전
# 용접
# 기술공학이론
# 환경과인간
# 농업일반
# 도시계획/재생/건축
# 수질/토양오염
# 환경공학
# 식품기사
# 식품학이론
# 식품화학/미생물학
# 식품위생학
# 유체역학
# 금속/주조공학
# 측량학
# 정원/조경
# 수의학
# 원예기능사/화훼장식기사
# 교량공학
# 건설안전/감리
# 건축설비
# 하천공학
# 조경학
# 건설법
# 토목설계
# 도로공학
# 철도공학
# 수리학/수문학
# 건설일반서
# 콘크리트
# 건설경영/계약
# 토목시공
# 폐기물/재활용
# 건설품셈/적산/일위대가
# 건축법규
# 토목품셈/적산/일위대가
# 토목공학
# 자동차공학
# 건축설계/제도
# 건설기계설비/정비기사
# 건설안전기사
# 건축시공/작업
# 건축구조
# 건축시공기술사
# 건축재료
# 토질역학
# 상하수도공학
# 토목시공기술사/토목구조기술사
# 건축사전/용어집
# 공기조화
# 건축기사
# 건축계획
# 토목기사
# 지적학
# 공업구조역학
# 건축공학개론
# 환경이야기
# 건설재료시험기사
# 토목사전
# 토지이용계획
# 항만공학
# 주거학/주택관리
# 기계연감/총람/편람
# 전기품셈/적산/일위대가
# 콘크리트기사
# 주택/전원주택
# 학교/도서관/연구기관
# 기타건축
# 동양건축사
# 아파트/호텔/관광시설
# 병원/교회/복지시설
# 국내건축가
# 계측
# 전기전자공학이론
# 시퀀스
# 보일러/증기기관
# 송전/배전
# 모터/PLC
# 공업규격/표준화
# 기계재료
# 열역학/열전달
# 전등/조명/전열
# 프레스금형
# 가스기사
# 석유/가스
# 승강기기사
# 폐기물처리기사
# 환경자격증일반
# 가정학/가족학
# 공업영어/유한요소
# 안경학
# 면역학
# 임상의학/진단학
# 재배/보호
# 조직학/세포학
# 농기계/토양
# 농업정책
# 대기환경기사/대기관리기술사
# 대우자동차
# 자동차정비/수리
# 자동차전기
# 자동차섀시
# 뇌
# 의학철학/의학이론
# 한국건축사
# 중국의학
# 기아자동차
# 현대자동차
# 냉동공학
# 간호학개론/이론
# 건축디자인일반
# 임학
# 자원/에너지
# 가정의학
# 성형외과
# 낙농
# 신장병
# 화학공학/공업화학
# 한의학의경
# 공중보건학
# 한의학이론
# 의학용어/사전
# 약리학/약물학
# 보건의료법규
# 보건학일반
# 예방의학
# 약품화학/미생물학
# 약학일반
# 의학사
# 외과일반
# 본초학
# 한의학사전
# 임상한의학
# 병원경영
# 건강관리학
# 법의학
# 농업경제
# 건축사일반
# 정신신경계
# 철강/비철금속
# 한국전통건축/한옥
# 수산업
# 내과일반
# 한국의사국가고시
# 소아과
# 간장병(간염)
# 건강사정/신체검진
# 정형외과
# 구강학/구강진단학
# 임상병리사
# 병리학
# 한의학일반
# 초음파/방사선
# 노인의학
# 신경계통
# 심장병
# 응급의학과
# 미생물/세균/기생충학
# 가정간호
# 내분비
# 재활의학
# 순환기계통
# 통증의학
# 혈액/혈관
# 호흡기
# 환경행정/환경법
# 피부과
# 성인간호학
# 간호사/보건교사
# 고급/지역사회영양학
# 치과기공사/치과위생사
# 보건의료통계
# 보철학
# 의료행정/정책
# 대한약전
# 약학이론
# 의료보험
# 간호기록/영어
# 의무기록사/병원행정사
# 방사선사
# 노인간호
# 마취학
# 영양학이론
# 산업안전/위생관리기사
# 소방설비기사
# MEET/DEET/PEET
# 에너지관리기사
# 비파괴검사
# 건축사
# 비파괴검사기사
# 금형작업술
# 선박공학
# 센서
# 도로교통사고감정사/분석사/교통기사
# 대기오염
# 유통/마케팅
# 로봇/메카트로닉스
# 소방안전
# 동역학
# 재료공학/재료과학
# 전자통신
# 디지털통신
# 광통신
# 이동통신
# 기구학
# 식품가공학
# 과수
# 근육/근골격계질환
# 조리과학
# 농학이론
# 기타공학
# 학교보건/급식
# 작물학
# 양봉/양잠
# 기계자격증일반
# 플라스틱
# 폐수/하수처리
# 위험물산업기사
# 수자원공학
# 토목재료
# 측량및지형공간정보기사
# 안과
# 건축자격증일반
# 실내디자인일반
# 의학윤리
# 자동차기관/엔진
# 전산응용기계제도기능사
# 기계품셈/적산/일위대가
# 건축설비기사
# CAD/CAM/BIM
# 소방이론
# 유공압공학
# 수질환경기사/수질관리기술사
# 식품구매/HACCP
# 용접기능사
# 기계설계기사
# 토목/건설자격증일반
# 소음/진동
# 안경사
# 식품학연감/총람/편람
# 축산학
# 세라믹
# 화공기사/화학분석기사
# 의학이야기
# 환경기능사
# 생약학
# 유기농
# 기술과학연감/총람/편람
# 조경기사
# 코/귀(이비인후과)
# 금형/열처리기능사
# 시계/전자파
# 디지털시스템
# 정역학
# 실내건축기사
# 물리치료학
# 물리치료사/작업치료사
# 전기/수/광선치료학
# 치아형태학/치과재료학
# 여성건강간호학
# 정신간호학
# 지역사회간호
# 전기전자연감/총람/편람
# 건축공학
# 전염병/기생충
# 미용사(피부)
# 미용사(일반)
# 발효
# 원예/화훼
# 식품재료
# 기술역사
# 농촌지도사
# 영양과건강
# 농수산/축산자격증일반
# 산림기사
# 유기농기사
# 발송배전기술사
# 컴퓨터응용가공산업기사/선반/밀링기능사
# 전산응용건축제도기능사
# 항공기사/항공정비기능사
# 소방기술사
# 열유체공학
# 보건학개론
# 치의학용어/사전
# 간호관리
# 아동간호학
# 호스피스
# 기능성식품학
# 기본간호학
# 치과위생
# 위생사
# 의료공학
# 공조냉동기사
# 화장품학
# 약업경영학
# 알레르기/전신병
# 전지/레이저
# 작업치료학/치료요법
# 모발과학/관리
# 응급구조사
# 네일
# 도배기능사
# 상하수도기술사
# 식육가공기사/식육처리기능사
# 기타제조사
# 영양사
# 미용사(네일)
# 운전면허2종
# 국내경영이야기
# 미용사(메이크업)
# 식물보호기사
# 생산자동화산업기사
# 문화재수리기술자
# 온실가스관리기사
# 신재생에너지발전설비기사
# 의공기사/의료전자기능사
# 보건행정/의료경영자격증일반
# 메카트로닉스기사
# 항공자격증일반
# 항해사/해기사/기관사
# 청소년 교양공학
# 건축술
# 축산기사
# 금속재료기사/압연기능사
# 주조/제강/제선기능사
# 농산물/수산물품질관리사
# 의료인
# 공학일반
# 의학논문
# 전기/전자공학
# 과학/공학
# 정책이론/실무
# 환경
# 과학교재
# 컴퓨터교재
# MBA
# 재테크성공이야기
# 경제학일반
# 산업경제일반
# 금융정책
# 지식경영
# 벤처
# 조직관리일반
# 한국경제
# 경영관리일반
# 아시아경제
# 기업합병,M&A
# 한국기업
# 창업일반
# 브랜드
# 기업경영일반
# 디지털경제
# 창업실무
# 기업윤리/문화
# 인구
# 재무관리
# 거시경제학
# 경영일반
# 재테크/금융
# 경제이론
# 마케팅/세일즈
# 기업실무관리
# 경제일반
# 경제/경영문고
# 경영관리
# 관광/호텔
# 유통/창업
# 경영전략
# 각국경제
# 경영이론
# e-비즈니스
# 기업경제
# 중국경제
# 부자되는법
# 회계관리
# 광고/홍보일반
# 무역/운송
# 경제상식/경제이야기
# 고객/CS
# 비즈니스무역영어
# 법인세
# 무역이론
# 마케팅전략일반
# 경영전략일반
# 예산/결산
# 원가회계
# 간부관리(CEO)
# 지방세
# 재정관리일반
# 무역일반
# 회계학이론
# 인사/노무
# ISO
# 경영분석
# 다국적기업
# 생산관리
# 사무관리
# 상업/유통학개론
# 임금/급여
# 인적자원관리
# 투자가이드/자산관리
# 해외경영이야기
# 벤처창업
# 일본경제
# R&D경영/CFO
# 우편/통신
# 세계경제/국제경제
# 재무적기업관리
# 공장경영
# 물류관리/SCM
# 부동산실무
# 비서학
# 아웃소싱
# 중소기업
# 증권시장
# 공업경제/산업공학
# 교통일반
# 정치경제학
# 세일즈기법
# 미국경제
# 교통안전/사고
# 자동화작업
# 신뢰성공학/작업관리
# 북한경제
# 보험론
# 부동산일반
# 계량경영/OR이론
# 경영사
# 경영학이론
# 경제사/각국경제일반
# 경제수학/경제통계
# 경제원론/개론
# 관리회계
# 광고/홍보이론
# 국제경영
# 기업경제일반
# 노동경제학
# 마케팅이론일반
# 미시경제학
# 자본론
# 재무회계
# 조직행동
# 중급회계
# 회계감사
# 회계원리
# 소비자행동
# 경영혁신
# 기업형태구조
# 보험일반
# 금융기관
# 선물/옵션
# 기술경제
# 환경경제/관리경제
# 인터넷마케팅
# 경영사전/연감/총람
# 경제법
# 경제학연습
# 통화정책
# 세금일반/조세정책
# 경제사전/연감/총람
# 관광이론일반
# 부동산토지세
# 부동산이론
# 부동산중개론
# 관광자원론
# 근무관리
# 금융시장/실무
# 경영과학
# 채권/자산
# 증권투자
# 호텔경영
# 관광학일반
# 한국경제사
# 연말정산
# 경제정책일반
# 세일즈매너
# 물가
# 기업회계
# 세무회계
# 관세
# 재벌
# 부동산경제/개발
# 상속세
# 경영정보시스템
# 외환
# 주식투자기법
# 국제무역/세계무역
# 독일경제
# 해상보험
# 마르크스경제학
# 세테크(세금절약법)
# 양도세/소득세
# 은행운영
# 금융리스크
# 국제금융
# 금융이론
# 무역실무일반
# 해외투자
# 네트웍마케팅
# 품질관리/경영
# 관광마케팅/상품기획
# 관광사업론
# 여행업
# 외식사업경영
# 호텔마케팅/회계
# 호텔식음료학
# 관광서비스론
# 점포창업
# CF/카피
# 상품학
# 부동산투자일반
# 남아메리카경제
# 크리에이티브
# PR
# 세계기업
# 고용보험
# 교통정책/행정
# 육로운송
# 경제전망
# 계량경제학
# 고급회계
# 투자금융
# 무역정책
# 국제무역법규
# 경영수학/경영통계
# 전산회계
# 경제발전
# 무역계약론/중재론
# 차트/기술적분석
# 초보주식투자가이드
# 서비스경영
# 신용장론
# 지역경제
# 이벤트
# 여가/레저산업
# 경리
# 부가가치세
# 소비자경제
# 국제운송/운송일반
# 통상
# 생활경제
# 러시아경제
# 유럽경제
# 무역결제론
# 광고/홍보이야기
# 텔레마케팅
# 화폐/전자결제
# 국제마케팅
# 마케팅조사
# 마케팅관리
# WTO/EU/FTA
# 내집마련
# 경제협력(OECD)
# 외국기업가
# 공기업
# 공공경제
# 산업심리
# 재무제표
# 관광가이드
# 서비스마케팅
# 프랜차이즈
# 관광이벤트/법규
# 부동산법률
# 정부/비영리회계
# 수입/수출
# 전자상거래
# 부동산컨설팅
# 세일즈성공스토리
# 창업성공이야기
# 의사결정
# 원천징수
# 현금흐름/가치평가
# 기업이미지
# 시장
# 신용
# 국제조세
# 소비자보호
# 재산세
# 광고제작론
# 디지털경영
# 경제통합
# 영업/판매
# 컨설팅
# 원가절감
# 컨벤션경영
# 총무
# 부동산경매
# 경제비평
# 6시그마
# 유통관리/매장관리
# 항공운송
# 소자본창업
# 팀워크
# 인터넷창업
# 계정과목
# 경제기사
# 사업계획/주식회사
# 소비자학이론
# 항공예약실무
# 코칭/멘토링/BSC
# IT경영
# 컨텐츠비즈니스
# 회계학일반
# 재개발/재건축
# 펀드
# 코스닥
# 땅투자
# 청소년경제
# 세금상식
# 한국무역
# 무역실무연습
# 도시경제
# 부동산금융
# 마케팅사례
# 가격결정
# 회계학연습
# CRM
# 국제비즈니스/투자
# 사회적기업
# 전시학
# 인도경제
# 트레이딩
# 인터넷광고
# 유비쿼터스
# 반도체경제
# 제3시장
# 리츠
# 다단타매매
# 상권분석
# 호텔객실관리
# 프로모션
# 철도운송
# 소매경영
# 오퍼상무역
# 간접투자
# 자기계발
# 대리/과장/팀장
# 자기능력계발
# 성공/처세
# 인간관계
# 비즈니스능력계발
# 자기혁신/자기관리
# 리더십향상
# 설득/협상
# 여성처세
# 시간관리
# 직장처세술
# 기획력
# 회의방법/토론
# 대화와화술
# 연설/스피치
# 프리젠테이션스킬
# 인간관계일반
# 메모/문서서식
# 카네기시리즈
# 아이디어
# 인생처세술/삶의지혜
# 남녀심리
# 커뮤니케이션향상
# 국제화마인드
# 남녀관계
# 창의적문제해결
# 인간관계심리
# 직장내인간관계
# 신입사원
# 여성을위한조언
# 청년훈
# 다이어리/플래너
# 성공스토리
# 전자책단말기/전자기기
# 브레인스토밍
# 고전에서배우는리더십
# 고전처세
# 중년/퇴직/은퇴
# 마인드콘트롤
# 오디오북
# 발상
# 노후생활/귀농/귀촌
# 가족관계
# 혈액형심리
# 산업경제
# 경제정책/협력
# 기업일반
# 경제학이론
# 경영분석/경영정보
# 광고/홍보/브랜드
# 매너/이미지메이킹
# 마케팅전략
# 유통/상품
# 네트워크/텔레마케팅
# 마케팅이론
# 소비자/고객/CS
# 상속/가족/호적법
# 중급/고급/재무회계
# 회계이론/회계원리
# 원가/관리회계
# 부동산투자
# 마케팅/광고/고객
# 국세/지방세
# 무역법규
# 양도/소득/재산세
# 상속/증여세
# 관광마케팅/사업
# 항공서비스
# 운송
# 컨벤션/국제회의
# 여행업/관광가이드
# 삶의지혜/조언
# 직장처세
# 세금상식/세테크
# 학습/공부법
# 자기관리/처세
# 아이디어/창의성
# 주식투자
# 경영관리/기업경영
# 외식/식음료
# 대화/화술
# 가상화폐
# 부동산이론/실무
# 마인드콘트롤/감정
# 무역이론/실무
# 관광이론
# 조직관리
# 관광
# 카페/음식점
# 무역
# 진로/직업/적성
# 인사/노무/총무
# 합병/M&A
# 품질관리/산업경영
# 경영
# 경영교재
# 경제교재
# 부동산중개
# IT/디지털경영
# 회계일반
# 선물/옵션/펀드
# 세계경제사
# 미국/유럽경제

# %%
# 문자 수 10%
child_list = ['다이어리/플래너', '메모/문서서식', '토이북', '유아학습', '유아그림책,유아(0~7세)', '스티커북/색칠하기',
              '고전/전래동화/명작동화', '동시/동요', '어린이작가', '그림책', '동화책', '어린이기독교', '동화/그림책/리더스북',
              '영어만화', '어린이중국어', '명작동화', '명작동화', '전래동화', '어린이전집', '어린이', '유아완구/교구/블록',
              '세계명작그림책', '그림찾기/미로/게임북', '동요/동시']

# 문자 수 20%
ele_list = ['그림에세이', '초등2학년', '초등5학년', '예체능', '초등1학년', '초등3학년', '초등4학년', '아이디어', '유머',
            '시조/한시(고전)', '기타나라/여러나라시', '사진이 있는 시', '시가', '포토에세이', '한시', '사랑시', '일본시',
            '그림이 있는 시', '영미시', '중국시', '독일시', '명시모음','프랑스시', '나라별 시', '시/에세이문고', '기타나라시']

df_copy['check_drawing_10'] = 0
df_copy['check_drawing_20'] = 0

def drawing_10(x):
    if x in child_list:
        return True
    else:
        return False
    
def drawing_20(x):
    if x in ele_list:
        return True
    else:
        return False
    
df_copy['check_drawing_10'] = df_copy['category_name'].apply(drawing_10)
df_copy['check_drawing_20'] = df_copy['category_name'].apply(drawing_20)

# %% [markdown]
# # 글자수 데이터가 있는 테이블 가져오기

# %%
# 글자수 데이터 추출

def db_connection(host_name = "ds"):
    host_url = "db.ds.mycelebs.com"
    user_nm = 'dbteam'
    passwd = 'celebdbteam2@#'
    port_num = 3306
    db_name = 'book_kyobo'
    conn = pymysql.connect(host=host_url, user = user_nm, passwd=passwd, port=port_num,
                           charset='utf8', db=db_name, cursorclass=pymysql.cursors.DictCursor)
    book_sql = '''SELECT isbn, text_len
                  FROM book_kyobo_matched_data
                '''
    
    cursor = conn.cursor()
    cursor.execute(book_sql)
    crawl_list = pd.DataFrame(cursor.fetchall()).reset_index()

    return crawl_list

df_2 = db_connection()
df_2.rename(columns = {'isbn':'isbn13'}, inplace = True)
df_2.head()
# Out:
#    index         isbn13   text_len
# 0      0  9788901150598    약 34만 자
# 1      1  9788901152295  약 10.3만 자
# 2      2  9788901166285  약 11.7만 자
# 3      3  9788901217666  약 10.8만 자
# 4      4  9788925556826  약 49.1만 자

# %% [markdown]
# # 글자수 데이터가 있는 행의 숫자 추출

# %%
import re
def extract(x):
    num = float(''.join(ele for ele in x if ele.isdigit() or ele == '.'))
    return num * 10000

df_2['text_len'] = df_2['text_len'].apply(extract)

# %% [markdown]
# # 글자수 데이터 있는 테이블과 원본 데이터프레임 Merge

# %%
df_copy['isbn13'] = df_copy['isbn13'].astype(int)

# %%
df_2['isbn13'] = df_2['isbn13'].astype(int)

# %%
df_big = df_copy.merge(df_2, how = 'left', on = 'isbn13')

# %%
df_big.drop(columns = ['index_x', 'index_y'], inplace = True)

# %% [markdown]
# # 글자수 결측값 채워주기
# - 100mm^2 당 평균 2글자
# - size 컬럼 / 100 * 2

# %%
df_big.loc[df_big['text_len'].isnull(), 'text_len'] = round(df_big['size'] / 100 * 2 * df_big['page'], 2)

# %%
df_big.loc[df_big['check_drawing_10'] == True, 'text_len'] = df_big['text_len'] * 0.1
df_big.loc[df_big['check_drawing_20'] == True, 'text_len'] = df_big['text_len'] * 0.2

# %% [markdown]
# # 사이즈 대비 무게
# - 사이즈에 비해 무게가 가벼울수록 들고 다니기 편안함.
# - 해당 컬럼 값이 작을수록 좋다는 뜻.

# %%
df_big['size_per_weight'] = round(df_big['weight'] / df_big['size'], 2)

# %% [markdown]
# # 가격 대비 글자수
# - 가격에 비해 글자수가 많다면 더 많은 내용이 담겨있는것이고, 가성비가 좋다고 할 수 있음.

# %%
df_big['price_per_text_len'] = round(df_big['text_len'] / df_big['listprice'], 2)

# %% [markdown]
# # inf 값 수정

# %%
li_inf = ['price_per_100g', 'price_per_100mm^2', 'price_per_page', 'size_per_weight', 'price_per_text_len']

for i in li_inf:
    df_big[i] = df_big[i].replace(np.inf, np.nan)

# %% [markdown]
# # 0인 값 nan으로 전환

# %%
li_nan = ['price_per_100g', 'price_per_100mm^2', 'price_per_page', 'size_per_weight', 'price_per_text_len']

for i in li_nan:
    df_big.loc[df_big[i] == 0, i] = np.nan

# %%
df_big.head()
# Out:
#    series_id             title         isbn13  listprice  form_size   page  \
# 0    9000428       역사를 바꾼 이인자들  1400000010648      11800  153*225mm  316.0
# 1    9000483     삼국유사(세계의사상 1)  1400000212776      17600  148*210mm  508.0
# 2    9000484  세계를 움직인 12인의 천재들  1400000212783      13800  153*225mm  356.0
# 3    9000495          미국역사의 순환  1400000212967      20500  148*210mm  580.0
# 4    9000596        한국의 멋을 찾아서  1400000215036      19600  188*254mm  437.0
#
#    weight category_name     size  price_per_100mm^2  price_per_page  \
# 0     NaN        한국역사인물  34425.0          34.277415       37.341772
# 1     NaN        삼국시대일반  31080.0          56.628057       34.645669
# 2     NaN        세계역사인물  34425.0          40.087146       38.764045
# 3     NaN           미국사  31080.0          65.958816       35.344828
# 4     NaN          역사기행  47752.0          41.045401       44.851259
#
#    check_drawing_10  check_drawing_20  price_per_100g   text_len  \
# 0             False             False             NaN  217566.00
# 1             False             False             NaN  315772.80
# 2             False             False             NaN  245106.00
# 3             False             False             NaN  360528.00
# 4             False             False             NaN  417352.48
#
#    size_per_weight  price_per_text_len
# 0              NaN               18.44
# 1              NaN               17.94
# 2              NaN               17.76
# 3              NaN               17.59
# 4              NaN               21.29

# %%
li_qcut = ['price_per_100g', 'price_per_100mm^2', 'price_per_page', 'size_per_weight', 'price_per_text_len']


for i in li_qcut:
    sample_df = df_big.copy()
    print(f"{i} : {pd.qcut(sample_df[i], 5, duplicates = 'drop')}")
# Out:
# price_per_100g : 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 2262886    NaN
# 2262887    NaN
# 2262888    NaN
# 2262889    NaN
# 2262890    NaN
# Name: price_per_100g, Length: 2262891, dtype: category
# Categories (5, interval[float64]): [(1.8900000000000001, 2222.222] < (2222.222, 2710.414] < (2710.414, 3157.895] < (3157.895, 3867.403] < (3867.403, 1440000.0]]
# price_per_100mm^2 : 0               (32.069, 40.85]
# 1          (54.873, 51200000.0]
# 2               (32.069, 40.85]
# 3          (54.873, 51200000.0]
# 4               (40.85, 54.873]
#                    ...
# 2262886         (40.85, 54.873]
# 2262887         (40.85, 54.873]
# 2262888     (-0.000429, 20.914]
# 2262889         (40.85, 54.873]
# 2262890         (40.85, 54.873]
# Name: price_per_100mm^2, Length: 2262891, dtype: category
# Categories (5, interval[float64]): [(-0.000429, 20.914] < (20.914, 32.069] < (32.069, 40.85] < (40.85, 54.873] < (54.873, 51200000.0]]
# price_per_page : 0              (26.882, 40.625]
# 1              (26.882, 40.625]
# 2              (26.882, 40.625]
# 3              (26.882, 40.625]
# 4              (40.625, 53.398]
#                    ...
# 2262886    (79.365, 281936.667]
# 2262887        (40.625, 53.398]
# 2262888        (53.398, 79.365]
# 2262889        (53.398, 79.365]
# 2262890        (53.398, 79.365]
# Name: price_per_page, Length: 2262891, dtype: category
# Categories (5, interval[float64]): [(0.004, 26.882] < (26.882, 40.625] < (40.625, 53.398] < (53.398, 79.365] < (79.365, 281936.667]]
# size_per_weight : 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 2262886    NaN
# 2262887    NaN
# 2262888    NaN
# 2262889    NaN
# 2262890    NaN
# Name: size_per_weight, Length: 2262891, dtype: category
# Categories (2, interval[float64]): [(0.009000000000000001, 0.02] < (0.02, 334.8]]
# price_per_text_len : 0                        (16.51, 20.8]
# 1                        (16.51, 20.8]
# 2                        (16.51, 20.8]
# 3                        (16.51, 20.8]
# 4                   (20.8, 1401973.76]
#                       ...
# 2262886    (0.009000000000000001, 8.6]
# 2262887                 (12.72, 16.51]
# 2262888             (20.8, 1401973.76]
# 2262889                   (8.6, 12.72]
# 2262890                   (8.6, 12.72]
# Name: price_per_text_len, Length: 2262891, dtype: category
# Categories (5, interval[float64]): [(0.009000000000000001, 8.6] < (8.6, 12.72] < (12.72, 16.51] < (16.51, 20.8] < (20.8, 1401973.76]]

# %%
li_cat = ['cat_price_per_100g', 'cat_price_per_100mm^2', 'cat_price_per_page', 'cat_size_per_weight', 'cat_price_per_text_len']

for i in li_cat:
    df_big[i] = 0

df_big.loc[(df_big['price_per_100g'] <= 2222.222) & (df_big['price_per_100g'] > 1.8900000000000001), 'cat_price_per_100g'] = 1
df_big.loc[(df_big['price_per_100g'] <= 2710.414) & (df_big['price_per_100g'] > 2222.222), 'cat_price_per_100g'] = 2
df_big.loc[(df_big['price_per_100g'] <= 3157.895) & (df_big['price_per_100g'] > 2710.414), 'cat_price_per_100g'] = 3
df_big.loc[(df_big['price_per_100g'] <= 3867.403) & (df_big['price_per_100g'] > 3157.895), 'cat_price_per_100g'] = 4
df_big.loc[(df_big['price_per_100g'] <= 1440000.0) & (df_big['price_per_100g'] > 3867.403), 'cat_price_per_100g'] = 5

df_big.loc[(df_big['price_per_100mm^2'] <= 20.914) & (df_big['price_per_100mm^2'] > -0.000429), 'cat_price_per_100mm^2'] = 1
df_big.loc[(df_big['price_per_100mm^2'] <= 32.069) & (df_big['price_per_100mm^2'] > 20.914), 'cat_price_per_100mm^2'] = 2
df_big.loc[(df_big['price_per_100mm^2'] <= 40.85) & (df_big['price_per_100mm^2'] > 32.069), 'cat_price_per_100mm^2'] = 3
df_big.loc[(df_big['price_per_100mm^2'] <= 54.873) & (df_big['price_per_100mm^2'] > 40.85), 'cat_price_per_100mm^2'] = 4
df_big.loc[(df_big['price_per_100mm^2'] <= 51200000.0) & (df_big['price_per_100mm^2'] > 54.873), 'cat_price_per_100mm^2'] = 5

df_big.loc[(df_big['price_per_page'] <= 26.882) & (df_big['price_per_page'] > 0.004), 'cat_price_per_page'] = 1
df_big.loc[(df_big['price_per_page'] <= 40.625) & (df_big['price_per_page'] > 26.882), 'cat_price_per_page'] = 2
df_big.loc[(df_big['price_per_page'] <= 53.398) & (df_big['price_per_page'] > 40.625), 'cat_price_per_page'] = 3
df_big.loc[(df_big['price_per_page'] <= 79.365) & (df_big['price_per_page'] > 53.398), 'cat_price_per_page'] = 4
df_big.loc[(df_big['price_per_page'] <= 281936.667) & (df_big['price_per_page'] > 79.365), 'cat_price_per_page'] = 5

df_big.loc[(df_big['size_per_weight'] <= 0.02) & (df_big['size_per_weight'] > 0.009000000000000001), 'cat_size_per_weight'] = 1
df_big.loc[(df_big['size_per_weight'] <= 334.8) & (df_big['size_per_weight'] > 0.02), 'cat_size_per_weight'] = 5

df_big.loc[(df_big['price_per_text_len'] <= 8.6) & (df_big['price_per_text_len'] > 0.009000000000000001), 'cat_price_per_text_len'] = 1
df_big.loc[(df_big['price_per_text_len'] <= 12.72) & (df_big['price_per_text_len'] > 8.6), 'cat_price_per_text_len'] = 2
df_big.loc[(df_big['price_per_text_len'] <= 16.51) & (df_big['price_per_text_len'] > 12.72), 'cat_price_per_text_len'] = 3
df_big.loc[(df_big['price_per_text_len'] <= 20.8) & (df_big['price_per_text_len'] > 16.51), 'cat_price_per_text_len'] = 4
df_big.loc[(df_big['price_per_text_len'] <= 1401973.76) & (df_big['price_per_text_len'] > 20.8), 'cat_price_per_text_len'] = 5

# %%
li_cat = ['cat_price_per_100g', 'cat_price_per_100mm^2', 'cat_price_per_page', 'cat_size_per_weight', 'cat_price_per_text_len']

for i in li_cat:
    df_big.loc[df_big[i] == 0, i] = np.nan

# %% [markdown]
# # 중간 실행 위치!!!!!

# %%
df_3 = df_big.copy()

# %% [markdown]
# # carriage_ord

# %%
df_3['carriage_ord'] = 0

df_3.loc[((df_3['size'] >= 124740.0) | (df_3['weight'] > 980.0)), 'carriage_ord'] = 1
# Out:
# 0    2208569
# 1      54322
# Name: carriage_ord, dtype: int64

# %%
pd.qcut(df_3.loc[df_3['carriage_ord'] == 0]['size_per_weight'], 5, duplicates = 'drop')
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 2262885    NaN
# 2262886    NaN
# 2262887    NaN
# 2262889    NaN
# 2262890    NaN
# Name: size_per_weight, Length: 2208569, dtype: category
# Categories (2, interval[float64]): [(0.009000000000000001, 0.02] < (0.02, 250.0]]

# %%
df_3.loc[(df_3['size_per_weight'] <= 0.02) & (df_3['size_per_weight'] > 0.009000000000000001), 'carriage_ord'] = 3
df_3.loc[(df_3['size_per_weight'] <= 250.0) & (df_3['size_per_weight'] > 0.02), 'carriage_ord'] = 2

# %%
df_3.tail(5)
# Out:
#          series_id                          title         isbn13  listprice  \
# 2262886   46195621  17년째 버티고 있는 중입니다(셀프헬프 시리즈 16)  9788965292647      12800
# 2262887   46195665                 코로나 시대 자영업의 미래  9791197076817      17800
# 2262888   46195669   주식 공부 5일 완성(마흔 살에 시작하는)(개정판)  9791162541869      18000
# 2262889   46195670                        파워링커 혁명  9791129019646      16000
# 2262890   46195672                   더 위험한 미국이 온다  9791162541883      16000
#
#           form_size   page  weight category_name      size  price_per_100mm^2  \
# 2262886   128*188mm 152.00     nan          자기계발  24064.00              53.19
# 2262887   147*225mm 384.00     nan         경제/경영  33075.00              53.82
# 2262888  152*2250mm 336.00     nan         경제/경영 342000.00               5.26
# 2262889   152*225mm 257.00     nan          자기계발  34200.00              46.78
# 2262890   152*225mm 276.00     nan         경제/경영  34200.00              46.78
#
#          ...  price_per_100g   text_len  size_per_weight  price_per_text_len  \
# 2262886  ...             nan   73154.56              nan                5.72
# 2262887  ...             nan  254016.00              nan               14.27
# 2262888  ...             nan 2298240.00              nan              127.68
# 2262889  ...             nan  175788.00              nan               10.99
# 2262890  ...             nan  188784.00              nan               11.80
#
#          cat_price_per_100g  cat_price_per_100mm^2  cat_price_per_page  \
# 2262886                 nan                   4.00                5.00
# 2262887                 nan                   4.00                3.00
# 2262888                 nan                   1.00                4.00
# 2262889                 nan                   4.00                4.00
# 2262890                 nan                   4.00                4.00
#
#          cat_size_per_weight  cat_price_per_text_len  carriage_ord
# 2262886                  nan                    1.00             0
# 2262887                  nan                    3.00             0
# 2262888                  nan                    5.00             1
# 2262889                  nan                    2.00             0
# 2262890                  nan                    2.00             0
#
# [5 rows x 23 columns]

# %%
div_1 = df_big.iloc[:1000000]
div_2 = df_big.iloc[1000000:2000000]
div_3 = df_big.iloc[2000000:]

div_1.to_csv("output_div_1.csv", encoding = 'utf-8-sig')
div_2.to_csv("output_div_2.csv", encoding = 'utf-8-sig')
div_3.to_csv("output_div_3.csv", encoding = 'utf-8-sig')

# %%
df_big.columns
# Out:
# Index(['series_id', 'title', 'isbn13', 'listprice', 'form_size', 'page',
#        'weight', 'category_name', 'size', 'price_per_100mm^2',
#        'price_per_page', 'check_drawing_10', 'check_drawing_20',
#        'price_per_100g', 'text_len', 'size_per_weight', 'price_per_text_len',
#        'cat_price_per_100g', 'cat_price_per_100mm^2', 'cat_price_per_page',
#        'cat_size_per_weight', 'cat_price_per_text_len'],
#       dtype='object')

# %%
# df_big.to_csv('output.csv', encoding = 'utf-8-sig')
