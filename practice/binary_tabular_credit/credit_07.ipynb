# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from math import sqrt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc

# %%
NFOLDS = 3
SEED = 0
NROWS = None

# %%
data = pd.read_csv('application_train.csv')
test = pd.read_csv("application_test.csv")
prev = pd.read_csv('previous_application.csv')

# %%
categorical_feats = [f for f in data.columns if data[f].dtype == 'object']

for f_ in categorical_feats:
    data[f_], indexer = pd.factorize(data[f_])
    test[f_] = indexer.get_indexer(test[f_])
    
gc.enable()

y_train = data['TARGET']
del data['TARGET']

prev_cat_features = [f_ for f_ in prev.columns if prev[f_].dtype == 'object']

for f_ in prev_cat_features:
    prev[f_], _ = pd.factorize(prev[f_])

# %%
avg_prev = prev.groupby('SK_ID_CURR').mean()
cnt_prev = prev[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
avg_prev['np_app'] = cnt_prev['SK_ID_PREV']
del avg_prev['SK_ID_PREV']

# %%
x_train = data.merge(right = avg_prev.reset_index(), how = 'left', on = 'SK_ID_CURR')
x_test = test.merge(right = avg_prev.reset_index(), how = 'left', on = 'SK_ID_CURR')

x_train = x_train.fillna(0)
x_test = x_test.fillna(0)

ntrain = x_train.shape[0]
ntest = x_test.shape[0]

excluded_feats = ['SK_ID_CURR']
features = [i for i in x_train.columns if i not in excluded_feats]

x_train = x_train[features]
x_test = x_test[features]

kf = KFold(n_splits = NFOLDS, shuffle = True, random_state = SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed = 0, params = None):
        params['random_state'] = seed
        self.clf = clf(**params)
        
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
        
    def predict(self, x):
        return self.clf.predict_proba(x)[:, 1]
    
class CatboostWrapper(object):
    def __init__(self, clf, seed = 0, params = None):
        params['random_state'] = seed
        self.clf = clf(**params)
        
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
        
    def predict(self, x):
        return self.clf.predict_proba(x)[:, 1]

class LightGBMWrapper(object):
    def __init__(self, clf, seed = 0, params = None):
        params['feature_fraction'] = seed
        params['bagging_seed'] = seed
        self.clf = clf(**params)
        
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
        
    def predict(self, x):
        return self.clf.predict_proba(x)[:, 1]
    
class XgbWrapper(object):
    def __init__(self, seed = 0, params = None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)
        
    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label = y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)
        
    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))
    
def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))
    
    for i, (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train.loc[train_index]
        y_tr = y_train.loc[train_index]
        x_te = x_train.loc[test_index]
        
        clf.train(x_tr, y_tr)
        
        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)
        
    oof_test[:] = oof_test_skf.mean(axis = 0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

et_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

rf_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.2,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.7,
    'silent': 1,
    'subsample': 0.7,
    'learning_rate': 0.075,
    'objective': 'binary:logistic',
    'max_depth': 4,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds': 200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False
}

lightgbm_params = {
    'n_estimators':200,
    'learning_rate':0.1,
    'num_leaves':123,
    'colsample_bytree':0.8,
    'subsample':0.9,
    'max_depth':15,
    'reg_alpha':0.1,
    'reg_lambda':0.1,
    'min_split_gain':0.01,
    'min_child_weight':2    
}

# %%
xg = XgbWrapper(seed=SEED, params=xgb_params)
et = SklearnWrapper(clf=ExtraTreesClassifier, seed=SEED, params=et_params)
rf = SklearnWrapper(clf=RandomForestClassifier, seed=SEED, params=rf_params)
cb = CatboostWrapper(clf= CatBoostClassifier, seed = SEED, params=catboost_params)
lg = LightGBMWrapper(clf = LGBMClassifier, seed = SEED, params = lightgbm_params)

xg_oof_train, xg_oof_test = get_oof(xg)
et_oof_train, et_oof_test = get_oof(et)
rf_oof_train, rf_oof_test = get_oof(rf)
cb_oof_train, cb_oof_test = get_oof(cb)

print("XG-CV: {}".format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print("ET-CV: {}".format(sqrt(mean_squared_error(y_train, et_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, cb_oof_train))))

x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train), axis=1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test), axis=1)

print("{},{}".format(x_train.shape, x_test.shape))

logistic_regression = LogisticRegression()
logistic_regression.fit(x_train,y_train)

test['TARGET'] = logistic_regression.predict_proba(x_test)[:,1]
# Out:
# 0:	total: 115ms	remaining: 22.9s
# 1:	total: 156ms	remaining: 15.5s
# 2:	total: 195ms	remaining: 12.8s
# 3:	total: 234ms	remaining: 11.5s
# 4:	total: 274ms	remaining: 10.7s
# 5:	total: 313ms	remaining: 10.1s
# 6:	total: 376ms	remaining: 10.4s
# 7:	total: 412ms	remaining: 9.88s
# 8:	total: 451ms	remaining: 9.56s
# 9:	total: 490ms	remaining: 9.31s
# 10:	total: 527ms	remaining: 9.06s
# 11:	total: 570ms	remaining: 8.93s
# 12:	total: 629ms	remaining: 9.05s
# 13:	total: 670ms	remaining: 8.89s
# 14:	total: 710ms	remaining: 8.75s
# 15:	total: 750ms	remaining: 8.63s
# 16:	total: 783ms	remaining: 8.43s
# 17:	total: 820ms	remaining: 8.3s
# 18:	total: 872ms	remaining: 8.31s
# 19:	total: 909ms	remaining: 8.18s
# 20:	total: 946ms	remaining: 8.06s
# 21:	total: 985ms	remaining: 7.97s
# 22:	total: 1.02s	remaining: 7.89s
# 23:	total: 1.07s	remaining: 7.83s
# 24:	total: 1.12s	remaining: 7.84s
# 25:	total: 1.16s	remaining: 7.76s
# 26:	total: 1.2s	remaining: 7.67s
# 27:	total: 1.24s	remaining: 7.59s
# 28:	total: 1.27s	remaining: 7.5s
# 29:	total: 1.31s	remaining: 7.43s
# 30:	total: 1.36s	remaining: 7.41s
# 31:	total: 1.4s	remaining: 7.34s
# 32:	total: 1.43s	remaining: 7.25s
# 33:	total: 1.47s	remaining: 7.18s
# 34:	total: 1.5s	remaining: 7.08s
# 35:	total: 1.54s	remaining: 7.01s
# 36:	total: 1.59s	remaining: 7.02s
# 37:	total: 1.64s	remaining: 7s
# 38:	total: 1.69s	remaining: 6.96s
# 39:	total: 1.73s	remaining: 6.9s
# 40:	total: 1.76s	remaining: 6.84s
# 41:	total: 1.8s	remaining: 6.79s
# 42:	total: 1.86s	remaining: 6.8s
# 43:	total: 1.9s	remaining: 6.74s
# 44:	total: 1.94s	remaining: 6.68s
# 45:	total: 1.98s	remaining: 6.63s
# 46:	total: 2.03s	remaining: 6.6s
# 47:	total: 2.07s	remaining: 6.56s
# 48:	total: 2.11s	remaining: 6.5s
# 49:	total: 2.15s	remaining: 6.45s
# 50:	total: 2.19s	remaining: 6.39s
# 51:	total: 2.23s	remaining: 6.34s
# 52:	total: 2.28s	remaining: 6.33s
# 53:	total: 2.32s	remaining: 6.27s
# 54:	total: 2.36s	remaining: 6.22s
# 55:	total: 2.4s	remaining: 6.18s
# 56:	total: 2.44s	remaining: 6.12s
# 57:	total: 2.48s	remaining: 6.07s
# 58:	total: 2.55s	remaining: 6.09s
# 59:	total: 2.59s	remaining: 6.05s
# 60:	total: 2.63s	remaining: 6s
# 61:	total: 2.67s	remaining: 5.95s
# 62:	total: 2.71s	remaining: 5.91s
# 63:	total: 2.76s	remaining: 5.86s
# 64:	total: 2.8s	remaining: 5.83s
# 65:	total: 2.85s	remaining: 5.78s
# 66:	total: 2.88s	remaining: 5.73s
# 67:	total: 2.93s	remaining: 5.68s
# 68:	total: 2.96s	remaining: 5.63s
# 69:	total: 3s	remaining: 5.58s
# 70:	total: 3.06s	remaining: 5.56s
# 71:	total: 3.1s	remaining: 5.51s
# 72:	total: 3.14s	remaining: 5.46s
# 73:	total: 3.17s	remaining: 5.4s
# 74:	total: 3.21s	remaining: 5.36s
# 75:	total: 3.25s	remaining: 5.31s
# 76:	total: 3.31s	remaining: 5.28s
# 77:	total: 3.35s	remaining: 5.24s
# 78:	total: 3.39s	remaining: 5.19s
# 79:	total: 3.42s	remaining: 5.14s
# 80:	total: 3.46s	remaining: 5.09s
# 81:	total: 3.5s	remaining: 5.04s
# 82:	total: 3.56s	remaining: 5.03s
# 83:	total: 3.61s	remaining: 4.98s
# 84:	total: 3.65s	remaining: 4.93s
# 85:	total: 3.69s	remaining: 4.89s
# 86:	total: 3.73s	remaining: 4.84s
# 87:	total: 3.77s	remaining: 4.79s
# 88:	total: 3.82s	remaining: 4.76s
# 89:	total: 3.86s	remaining: 4.72s
# 90:	total: 3.9s	remaining: 4.67s
# 91:	total: 3.95s	remaining: 4.64s
# 92:	total: 3.99s	remaining: 4.59s
# 93:	total: 4.03s	remaining: 4.54s
# 94:	total: 4.08s	remaining: 4.51s
# 95:	total: 4.12s	remaining: 4.46s
# 96:	total: 4.16s	remaining: 4.42s
# 97:	total: 4.2s	remaining: 4.37s
# 98:	total: 4.24s	remaining: 4.33s
# 99:	total: 4.3s	remaining: 4.3s
# 100:	total: 4.33s	remaining: 4.25s
# 101:	total: 4.38s	remaining: 4.2s
# 102:	total: 4.42s	remaining: 4.16s
# 103:	total: 4.47s	remaining: 4.13s
# 104:	total: 4.51s	remaining: 4.08s
# 105:	total: 4.54s	remaining: 4.03s
# 106:	total: 4.58s	remaining: 3.98s
# 107:	total: 4.62s	remaining: 3.93s
# 108:	total: 4.66s	remaining: 3.89s
# 109:	total: 4.72s	remaining: 3.87s
# 110:	total: 4.77s	remaining: 3.83s
# 111:	total: 4.81s	remaining: 3.78s
# 112:	total: 4.85s	remaining: 3.73s
# 113:	total: 4.89s	remaining: 3.69s
# 114:	total: 4.93s	remaining: 3.64s
# 115:	total: 4.98s	remaining: 3.61s
# 116:	total: 5.02s	remaining: 3.56s
# 117:	total: 5.06s	remaining: 3.52s
# 118:	total: 5.1s	remaining: 3.47s
# 119:	total: 5.14s	remaining: 3.43s
# 120:	total: 5.19s	remaining: 3.39s
# 121:	total: 5.23s	remaining: 3.34s
# 122:	total: 5.27s	remaining: 3.3s
# 123:	total: 5.31s	remaining: 3.26s
# 124:	total: 5.35s	remaining: 3.21s
# 125:	total: 5.4s	remaining: 3.17s
# 126:	total: 5.45s	remaining: 3.13s
# 127:	total: 5.49s	remaining: 3.09s
# 128:	total: 5.53s	remaining: 3.04s
# 129:	total: 5.57s	remaining: 3s
# 130:	total: 5.62s	remaining: 2.96s
# 131:	total: 5.65s	remaining: 2.91s
# 132:	total: 5.7s	remaining: 2.87s
# 133:	total: 5.74s	remaining: 2.82s
# 134:	total: 5.78s	remaining: 2.78s
# 135:	total: 5.83s	remaining: 2.74s
# 136:	total: 5.87s	remaining: 2.7s
# 137:	total: 5.91s	remaining: 2.65s
# 138:	total: 5.95s	remaining: 2.61s
# 139:	total: 6s	remaining: 2.57s
# 140:	total: 6.05s	remaining: 2.53s
# 141:	total: 6.1s	remaining: 2.49s
# 142:	total: 6.14s	remaining: 2.45s
# 143:	total: 6.18s	remaining: 2.4s
# 144:	total: 6.22s	remaining: 2.36s
# 145:	total: 6.27s	remaining: 2.32s
# 146:	total: 6.31s	remaining: 2.27s
# 147:	total: 6.35s	remaining: 2.23s
# 148:	total: 6.39s	remaining: 2.19s
# 149:	total: 6.43s	remaining: 2.14s
# 150:	total: 6.47s	remaining: 2.1s
# 151:	total: 6.52s	remaining: 2.06s
# 152:	total: 6.56s	remaining: 2.01s
# 153:	total: 6.6s	remaining: 1.97s
# 154:	total: 6.64s	remaining: 1.93s
# 155:	total: 6.69s	remaining: 1.89s
# 156:	total: 6.73s	remaining: 1.84s
# 157:	total: 6.77s	remaining: 1.8s
# 158:	total: 6.82s	remaining: 1.76s
# 159:	total: 6.87s	remaining: 1.72s
# 160:	total: 6.91s	remaining: 1.67s
# 161:	total: 6.95s	remaining: 1.63s
# 162:	total: 6.99s	remaining: 1.59s
# 163:	total: 7.03s	remaining: 1.54s
# 164:	total: 7.07s	remaining: 1.5s
# 165:	total: 7.12s	remaining: 1.46s
# 166:	total: 7.15s	remaining: 1.41s
# 167:	total: 7.19s	remaining: 1.37s
# 168:	total: 7.23s	remaining: 1.32s
# 169:	total: 7.26s	remaining: 1.28s
# 170:	total: 7.3s	remaining: 1.24s
# 171:	total: 7.35s	remaining: 1.2s
# 172:	total: 7.39s	remaining: 1.15s
# 173:	total: 7.43s	remaining: 1.11s
# 174:	total: 7.47s	remaining: 1.07s
# 175:	total: 7.51s	remaining: 1.02s
# 176:	total: 7.55s	remaining: 982ms
# 177:	total: 7.62s	remaining: 941ms
# 178:	total: 7.67s	remaining: 900ms
# 179:	total: 7.71s	remaining: 857ms
# 180:	total: 7.75s	remaining: 814ms
# 181:	total: 7.79s	remaining: 771ms
# 182:	total: 7.84s	remaining: 729ms
# 183:	total: 7.88s	remaining: 685ms
# 184:	total: 7.92s	remaining: 642ms
# 185:	total: 7.96s	remaining: 599ms
# 186:	total: 8s	remaining: 556ms
# 187:	total: 8.04s	remaining: 513ms
# 188:	total: 8.09s	remaining: 471ms
# 189:	total: 8.13s	remaining: 428ms
# 190:	total: 8.16s	remaining: 385ms
# 191:	total: 8.21s	remaining: 342ms
# 192:	total: 8.24s	remaining: 299ms
# 193:	total: 8.28s	remaining: 256ms
# 194:	total: 8.34s	remaining: 214ms
# 195:	total: 8.38s	remaining: 171ms
# 196:	total: 8.42s	remaining: 128ms
# 197:	total: 8.46s	remaining: 85.5ms
# 198:	total: 8.5s	remaining: 42.7ms
# 199:	total: 8.54s	remaining: 0us
# 0:	total: 45.9ms	remaining: 9.12s
# 1:	total: 84.8ms	remaining: 8.4s
# 2:	total: 123ms	remaining: 8.1s
# 3:	total: 163ms	remaining: 8s
# 4:	total: 202ms	remaining: 7.9s
# 5:	total: 243ms	remaining: 7.87s
# 6:	total: 299ms	remaining: 8.25s
# 7:	total: 342ms	remaining: 8.22s
# 8:	total: 374ms	remaining: 7.94s
# 9:	total: 425ms	remaining: 8.08s
# 10:	total: 466ms	remaining: 8.01s
# 11:	total: 516ms	remaining: 8.09s
# 12:	total: 566ms	remaining: 8.14s
# 13:	total: 608ms	remaining: 8.08s
# 14:	total: 644ms	remaining: 7.95s
# 15:	total: 683ms	remaining: 7.85s
# 16:	total: 730ms	remaining: 7.86s
# 17:	total: 771ms	remaining: 7.8s
# 18:	total: 814ms	remaining: 7.75s
# 19:	total: 854ms	remaining: 7.69s
# 20:	total: 895ms	remaining: 7.63s
# 21:	total: 933ms	remaining: 7.55s
# 22:	total: 987ms	remaining: 7.59s
# 23:	total: 1.03s	remaining: 7.55s
# 24:	total: 1.07s	remaining: 7.46s
# 25:	total: 1.1s	remaining: 7.38s
# 26:	total: 1.15s	remaining: 7.38s
# 27:	total: 1.19s	remaining: 7.33s
# 28:	total: 1.23s	remaining: 7.25s
# 29:	total: 1.27s	remaining: 7.2s
# 30:	total: 1.31s	remaining: 7.13s
# 31:	total: 1.34s	remaining: 7.04s
# 32:	total: 1.39s	remaining: 7.02s
# 33:	total: 1.43s	remaining: 7s
# 34:	total: 1.47s	remaining: 6.92s
# 35:	total: 1.51s	remaining: 6.88s
# 36:	total: 1.55s	remaining: 6.83s
# 37:	total: 1.59s	remaining: 6.77s
# 38:	total: 1.64s	remaining: 6.77s
# 39:	total: 1.68s	remaining: 6.71s
# 40:	total: 1.72s	remaining: 6.66s
# 41:	total: 1.76s	remaining: 6.62s
# 42:	total: 1.81s	remaining: 6.62s
# 43:	total: 1.85s	remaining: 6.57s
# 44:	total: 1.89s	remaining: 6.51s
# 45:	total: 1.93s	remaining: 6.46s
# 46:	total: 1.97s	remaining: 6.42s
# 47:	total: 2.02s	remaining: 6.39s
# 48:	total: 2.06s	remaining: 6.36s
# 49:	total: 2.1s	remaining: 6.31s
# 50:	total: 2.14s	remaining: 6.26s
# 51:	total: 2.18s	remaining: 6.2s
# 52:	total: 2.22s	remaining: 6.15s
# 53:	total: 2.26s	remaining: 6.12s
# 54:	total: 2.31s	remaining: 6.08s
# 55:	total: 2.34s	remaining: 6.03s
# 56:	total: 2.38s	remaining: 5.97s
# 57:	total: 2.42s	remaining: 5.94s
# 58:	total: 2.47s	remaining: 5.9s
# 59:	total: 2.51s	remaining: 5.87s
# 60:	total: 2.56s	remaining: 5.82s
# 61:	total: 2.59s	remaining: 5.77s
# 62:	total: 2.63s	remaining: 5.71s
# 63:	total: 2.66s	remaining: 5.66s
# 64:	total: 2.71s	remaining: 5.62s
# 65:	total: 2.75s	remaining: 5.57s
# 66:	total: 2.79s	remaining: 5.54s
# 67:	total: 2.83s	remaining: 5.49s
# 68:	total: 2.86s	remaining: 5.44s
# 69:	total: 2.91s	remaining: 5.4s
# 70:	total: 2.96s	remaining: 5.38s
# 71:	total: 2.99s	remaining: 5.32s
# 72:	total: 3.04s	remaining: 5.28s
# 73:	total: 3.08s	remaining: 5.24s
# 74:	total: 3.12s	remaining: 5.2s
# 75:	total: 3.15s	remaining: 5.15s
# 76:	total: 3.21s	remaining: 5.12s
# 77:	total: 3.25s	remaining: 5.08s
# 78:	total: 3.28s	remaining: 5.03s
# 79:	total: 3.32s	remaining: 4.98s
# 80:	total: 3.36s	remaining: 4.93s
# 81:	total: 3.4s	remaining: 4.89s
# 82:	total: 3.44s	remaining: 4.85s
# 83:	total: 3.48s	remaining: 4.81s
# 84:	total: 3.52s	remaining: 4.76s
# 85:	total: 3.56s	remaining: 4.71s
# 86:	total: 3.6s	remaining: 4.67s
# 87:	total: 3.64s	remaining: 4.63s
# 88:	total: 3.69s	remaining: 4.6s
# 89:	total: 3.73s	remaining: 4.56s
# 90:	total: 3.76s	remaining: 4.51s
# 91:	total: 3.81s	remaining: 4.47s
# 92:	total: 3.85s	remaining: 4.43s
# 93:	total: 3.89s	remaining: 4.39s
# 94:	total: 3.94s	remaining: 4.35s
# 95:	total: 3.97s	remaining: 4.3s
# 96:	total: 4.02s	remaining: 4.27s
# 97:	total: 4.06s	remaining: 4.22s
# 98:	total: 4.1s	remaining: 4.18s
# 99:	total: 4.14s	remaining: 4.14s
# 100:	total: 4.18s	remaining: 4.1s
# 101:	total: 4.23s	remaining: 4.06s
# 102:	total: 4.27s	remaining: 4.03s
# 103:	total: 4.31s	remaining: 3.98s
# 104:	total: 4.36s	remaining: 3.94s
# 105:	total: 4.4s	remaining: 3.9s
# 106:	total: 4.44s	remaining: 3.86s
# 107:	total: 4.48s	remaining: 3.81s
# 108:	total: 4.52s	remaining: 3.77s
# 109:	total: 4.56s	remaining: 3.73s
# 110:	total: 4.6s	remaining: 3.69s
# 111:	total: 4.65s	remaining: 3.65s
# 112:	total: 4.69s	remaining: 3.61s
# 113:	total: 4.72s	remaining: 3.56s
# 114:	total: 4.77s	remaining: 3.52s
# 115:	total: 4.81s	remaining: 3.48s
# 116:	total: 4.85s	remaining: 3.44s
# 117:	total: 4.91s	remaining: 3.41s
# 118:	total: 4.94s	remaining: 3.37s
# 119:	total: 4.98s	remaining: 3.32s
# 120:	total: 5.02s	remaining: 3.28s
# 121:	total: 5.06s	remaining: 3.23s
# 122:	total: 5.1s	remaining: 3.19s
# 123:	total: 5.15s	remaining: 3.16s
# 124:	total: 5.19s	remaining: 3.11s
# 125:	total: 5.22s	remaining: 3.07s
# 126:	total: 5.26s	remaining: 3.03s
# 127:	total: 5.3s	remaining: 2.98s
# 128:	total: 5.34s	remaining: 2.94s
# 129:	total: 5.39s	remaining: 2.9s
# 130:	total: 5.43s	remaining: 2.86s
# 131:	total: 5.47s	remaining: 2.82s
# 132:	total: 5.51s	remaining: 2.77s
# 133:	total: 5.55s	remaining: 2.73s
# 134:	total: 5.59s	remaining: 2.69s
# 135:	total: 5.64s	remaining: 2.66s
# 136:	total: 5.68s	remaining: 2.61s
# 137:	total: 5.72s	remaining: 2.57s
# 138:	total: 5.76s	remaining: 2.53s
# 139:	total: 5.8s	remaining: 2.48s
# 140:	total: 5.83s	remaining: 2.44s
# 141:	total: 5.89s	remaining: 2.4s
# 142:	total: 5.93s	remaining: 2.36s
# 143:	total: 5.96s	remaining: 2.32s
# 144:	total: 6.01s	remaining: 2.28s
# 145:	total: 6.04s	remaining: 2.23s
# 146:	total: 6.08s	remaining: 2.19s
# 147:	total: 6.13s	remaining: 2.15s
# 148:	total: 6.17s	remaining: 2.11s
# 149:	total: 6.21s	remaining: 2.07s
# 150:	total: 6.25s	remaining: 2.03s
# 151:	total: 6.29s	remaining: 1.99s
# 152:	total: 6.33s	remaining: 1.94s
# 153:	total: 6.37s	remaining: 1.9s
# 154:	total: 6.42s	remaining: 1.86s
# 155:	total: 6.45s	remaining: 1.82s
# 156:	total: 6.49s	remaining: 1.78s
# 157:	total: 6.53s	remaining: 1.74s
# 158:	total: 6.57s	remaining: 1.7s
# 159:	total: 6.62s	remaining: 1.66s
# 160:	total: 6.66s	remaining: 1.61s
# 161:	total: 6.7s	remaining: 1.57s
# 162:	total: 6.75s	remaining: 1.53s
# 163:	total: 6.78s	remaining: 1.49s
# 164:	total: 6.82s	remaining: 1.45s
# 165:	total: 6.87s	remaining: 1.41s
# 166:	total: 6.91s	remaining: 1.36s
# 167:	total: 6.95s	remaining: 1.32s
# 168:	total: 6.99s	remaining: 1.28s
# 169:	total: 7.04s	remaining: 1.24s
# 170:	total: 7.08s	remaining: 1.2s
# 171:	total: 7.13s	remaining: 1.16s
# 172:	total: 7.17s	remaining: 1.12s
# 173:	total: 7.21s	remaining: 1.08s
# 174:	total: 7.25s	remaining: 1.03s
# 175:	total: 7.3s	remaining: 996ms
# 176:	total: 7.34s	remaining: 954ms
# 177:	total: 7.38s	remaining: 913ms
# 178:	total: 7.42s	remaining: 871ms
# 179:	total: 7.46s	remaining: 829ms
# 180:	total: 7.5s	remaining: 787ms
# 181:	total: 7.55s	remaining: 747ms
# 182:	total: 7.59s	remaining: 705ms
# 183:	total: 7.63s	remaining: 663ms
# 184:	total: 7.67s	remaining: 622ms
# 185:	total: 7.71s	remaining: 580ms
# 186:	total: 7.74s	remaining: 538ms
# 187:	total: 7.79s	remaining: 498ms
# 188:	total: 7.83s	remaining: 456ms
# 189:	total: 7.87s	remaining: 414ms
# 190:	total: 7.92s	remaining: 373ms
# 191:	total: 7.95s	remaining: 331ms
# 192:	total: 7.99s	remaining: 290ms
# 193:	total: 8.05s	remaining: 249ms
# 194:	total: 8.09s	remaining: 208ms
# 195:	total: 8.13s	remaining: 166ms
# 196:	total: 8.17s	remaining: 124ms
# 197:	total: 8.21s	remaining: 83ms
# 198:	total: 8.25s	remaining: 41.5ms
# 199:	total: 8.3s	remaining: 0us
# 0:	total: 48.2ms	remaining: 9.6s
# 1:	total: 89.7ms	remaining: 8.88s
# 2:	total: 130ms	remaining: 8.51s
# 3:	total: 171ms	remaining: 8.35s
# 4:	total: 210ms	remaining: 8.2s
# 5:	total: 250ms	remaining: 8.07s
# 6:	total: 295ms	remaining: 8.14s
# 7:	total: 334ms	remaining: 8.03s
# 8:	total: 380ms	remaining: 8.07s
# 9:	total: 420ms	remaining: 7.97s
# 10:	total: 457ms	remaining: 7.85s
# 11:	total: 495ms	remaining: 7.75s
# 12:	total: 543ms	remaining: 7.81s
# 13:	total: 586ms	remaining: 7.78s
# 14:	total: 625ms	remaining: 7.71s
# 15:	total: 667ms	remaining: 7.67s
# 16:	total: 702ms	remaining: 7.56s
# 17:	total: 760ms	remaining: 7.68s
# 18:	total: 799ms	remaining: 7.61s
# 19:	total: 835ms	remaining: 7.51s
# 20:	total: 873ms	remaining: 7.44s
# 21:	total: 910ms	remaining: 7.36s
# 22:	total: 946ms	remaining: 7.28s
# 23:	total: 991ms	remaining: 7.27s
# 24:	total: 1.03s	remaining: 7.21s
# 25:	total: 1.07s	remaining: 7.17s
# 26:	total: 1.11s	remaining: 7.13s
# 27:	total: 1.15s	remaining: 7.08s
# 28:	total: 1.21s	remaining: 7.13s
# 29:	total: 1.25s	remaining: 7.09s
# 30:	total: 1.29s	remaining: 7.03s
# 31:	total: 1.33s	remaining: 6.97s
# 32:	total: 1.38s	remaining: 6.96s
# 33:	total: 1.42s	remaining: 6.95s
# 34:	total: 1.47s	remaining: 6.91s
# 35:	total: 1.5s	remaining: 6.86s
# 36:	total: 1.54s	remaining: 6.8s
# 37:	total: 1.58s	remaining: 6.75s
# 38:	total: 1.62s	remaining: 6.69s
# 39:	total: 1.67s	remaining: 6.68s
# 40:	total: 1.71s	remaining: 6.63s
# 41:	total: 1.75s	remaining: 6.59s
# 42:	total: 1.79s	remaining: 6.54s
# 43:	total: 1.83s	remaining: 6.49s
# 44:	total: 1.87s	remaining: 6.44s
# 45:	total: 1.92s	remaining: 6.44s
# 46:	total: 1.96s	remaining: 6.39s
# 47:	total: 2s	remaining: 6.34s
# 48:	total: 2.04s	remaining: 6.29s
# 49:	total: 2.08s	remaining: 6.23s
# 50:	total: 2.12s	remaining: 6.19s
# 51:	total: 2.17s	remaining: 6.17s
# 52:	total: 2.21s	remaining: 6.13s
# 53:	total: 2.25s	remaining: 6.08s
# 54:	total: 2.29s	remaining: 6.04s
# 55:	total: 2.33s	remaining: 6s
# 56:	total: 2.37s	remaining: 5.96s
# 57:	total: 2.42s	remaining: 5.93s
# 58:	total: 2.47s	remaining: 5.91s
# 59:	total: 2.51s	remaining: 5.86s
# 60:	total: 2.55s	remaining: 5.81s
# 61:	total: 2.6s	remaining: 5.79s
# 62:	total: 2.64s	remaining: 5.74s
# 63:	total: 2.68s	remaining: 5.7s
# 64:	total: 2.72s	remaining: 5.64s
# 65:	total: 2.76s	remaining: 5.6s
# 66:	total: 2.8s	remaining: 5.55s
# 67:	total: 2.85s	remaining: 5.53s
# 68:	total: 2.89s	remaining: 5.49s
# 69:	total: 2.93s	remaining: 5.44s
# 70:	total: 2.98s	remaining: 5.41s
# 71:	total: 3.01s	remaining: 5.35s
# 72:	total: 3.05s	remaining: 5.31s
# 73:	total: 3.1s	remaining: 5.28s
# 74:	total: 3.14s	remaining: 5.24s
# 75:	total: 3.19s	remaining: 5.2s
# 76:	total: 3.23s	remaining: 5.16s
# 77:	total: 3.28s	remaining: 5.13s
# 78:	total: 3.32s	remaining: 5.08s
# 79:	total: 3.36s	remaining: 5.04s
# 80:	total: 3.4s	remaining: 5s
# 81:	total: 3.44s	remaining: 4.95s
# 82:	total: 3.48s	remaining: 4.91s
# 83:	total: 3.53s	remaining: 4.87s
# 84:	total: 3.57s	remaining: 4.83s
# 85:	total: 3.6s	remaining: 4.78s
# 86:	total: 3.64s	remaining: 4.73s
# 87:	total: 3.68s	remaining: 4.69s
# 88:	total: 3.72s	remaining: 4.63s
# 89:	total: 3.77s	remaining: 4.61s
# 90:	total: 3.83s	remaining: 4.59s
# 91:	total: 3.88s	remaining: 4.55s
# 92:	total: 3.91s	remaining: 4.5s
# 93:	total: 3.96s	remaining: 4.46s
# 94:	total: 4s	remaining: 4.42s
# 95:	total: 4.04s	remaining: 4.38s
# 96:	total: 4.08s	remaining: 4.33s
# 97:	total: 4.12s	remaining: 4.29s
# 98:	total: 4.16s	remaining: 4.24s
# 99:	total: 4.2s	remaining: 4.2s
# 100:	total: 4.25s	remaining: 4.16s
# 101:	total: 4.29s	remaining: 4.12s
# 102:	total: 4.33s	remaining: 4.08s
# 103:	total: 4.37s	remaining: 4.03s
# 104:	total: 4.41s	remaining: 3.99s
# 105:	total: 4.44s	remaining: 3.94s
# 106:	total: 4.49s	remaining: 3.9s
# 107:	total: 4.53s	remaining: 3.86s
# 108:	total: 4.57s	remaining: 3.81s
# 109:	total: 4.61s	remaining: 3.77s
# 110:	total: 4.64s	remaining: 3.72s
# 111:	total: 4.68s	remaining: 3.68s
# 112:	total: 4.74s	remaining: 3.65s
# 113:	total: 4.78s	remaining: 3.6s
# 114:	total: 4.81s	remaining: 3.56s
# 115:	total: 4.85s	remaining: 3.51s
# 116:	total: 4.89s	remaining: 3.47s
# 117:	total: 4.93s	remaining: 3.43s
# 118:	total: 4.99s	remaining: 3.39s
# 119:	total: 5.03s	remaining: 3.35s
# 120:	total: 5.07s	remaining: 3.31s
# 121:	total: 5.12s	remaining: 3.27s
# 122:	total: 5.16s	remaining: 3.23s
# 123:	total: 5.2s	remaining: 3.18s
# 124:	total: 5.25s	remaining: 3.15s
# 125:	total: 5.29s	remaining: 3.11s
# 126:	total: 5.33s	remaining: 3.06s
# 127:	total: 5.38s	remaining: 3.02s
# 128:	total: 5.42s	remaining: 2.98s
# 129:	total: 5.46s	remaining: 2.94s
# 130:	total: 5.5s	remaining: 2.9s
# 131:	total: 5.54s	remaining: 2.85s
# 132:	total: 5.58s	remaining: 2.81s
# 133:	total: 5.62s	remaining: 2.77s
# 134:	total: 5.67s	remaining: 2.73s
# 135:	total: 5.71s	remaining: 2.69s
# 136:	total: 5.75s	remaining: 2.64s
# 137:	total: 5.79s	remaining: 2.6s
# 138:	total: 5.83s	remaining: 2.56s
# 139:	total: 5.86s	remaining: 2.51s
# 140:	total: 5.91s	remaining: 2.47s
# 141:	total: 5.94s	remaining: 2.43s
# 142:	total: 5.98s	remaining: 2.38s
# 143:	total: 6.02s	remaining: 2.34s
# 144:	total: 6.06s	remaining: 2.3s
# 145:	total: 6.09s	remaining: 2.25s
# 146:	total: 6.14s	remaining: 2.21s
# 147:	total: 6.18s	remaining: 2.17s
# 148:	total: 6.22s	remaining: 2.13s
# 149:	total: 6.26s	remaining: 2.09s
# 150:	total: 6.31s	remaining: 2.05s
# 151:	total: 6.35s	remaining: 2s
# 152:	total: 6.39s	remaining: 1.96s
# 153:	total: 6.43s	remaining: 1.92s
# 154:	total: 6.47s	remaining: 1.88s
# 155:	total: 6.51s	remaining: 1.84s
# 156:	total: 6.55s	remaining: 1.79s
# 157:	total: 6.59s	remaining: 1.75s
# 158:	total: 6.64s	remaining: 1.71s
# 159:	total: 6.68s	remaining: 1.67s
# 160:	total: 6.72s	remaining: 1.63s
# 161:	total: 6.76s	remaining: 1.59s
# 162:	total: 6.8s	remaining: 1.54s
# 163:	total: 6.85s	remaining: 1.5s
# 164:	total: 6.89s	remaining: 1.46s
# 165:	total: 6.93s	remaining: 1.42s
# 166:	total: 6.97s	remaining: 1.38s
# 167:	total: 7.01s	remaining: 1.34s
# 168:	total: 7.06s	remaining: 1.29s
# 169:	total: 7.11s	remaining: 1.25s
# 170:	total: 7.15s	remaining: 1.21s
# 171:	total: 7.2s	remaining: 1.17s
# 172:	total: 7.24s	remaining: 1.13s
# 173:	total: 7.28s	remaining: 1.09s
# 174:	total: 7.32s	remaining: 1.05s
# 175:	total: 7.36s	remaining: 1s
# 176:	total: 7.41s	remaining: 963ms
# 177:	total: 7.45s	remaining: 921ms
# 178:	total: 7.49s	remaining: 879ms
# 179:	total: 7.54s	remaining: 837ms
# 180:	total: 7.58s	remaining: 796ms
# 181:	total: 7.62s	remaining: 754ms
# 182:	total: 7.67s	remaining: 713ms
# 183:	total: 7.72s	remaining: 671ms
# 184:	total: 7.75s	remaining: 629ms
# 185:	total: 7.8s	remaining: 587ms
# 186:	total: 7.83s	remaining: 545ms
# 187:	total: 7.87s	remaining: 502ms
# 188:	total: 7.91s	remaining: 460ms
# 189:	total: 7.96s	remaining: 419ms
# 190:	total: 8s	remaining: 377ms
# 191:	total: 8.03s	remaining: 335ms
# 192:	total: 8.07s	remaining: 293ms
# 193:	total: 8.12s	remaining: 251ms
# 194:	total: 8.16s	remaining: 209ms
# 195:	total: 8.21s	remaining: 167ms
# 196:	total: 8.24s	remaining: 126ms
# 197:	total: 8.28s	remaining: 83.7ms
# 198:	total: 8.32s	remaining: 41.8ms
# 199:	total: 8.37s	remaining: 0us
# XG-CV: 0.2597074114623466
# ET-CV: 0.26296502347137407
# RF-CV: 0.2629856213006646
# RF-CV: 0.331013744619807
# (307511, 4),(48744, 4)

# %%
test[['SK_ID_CURR', 'TARGET']]
# Out:
#        SK_ID_CURR    TARGET
# 0          100001  0.047240
# 1          100005  0.110492
# 2          100013  0.026113
# 3          100028  0.038719
# 4          100038  0.148671
# ...           ...       ...
# 48739      456221  0.042605
# 48740      456222  0.075681
# 48741      456223  0.027298
# 48742      456224  0.064708
# 48743      456250  0.221590
#
# [48744 rows x 2 columns]

# %%
test[['SK_ID_CURR', 'TARGET']].to_csv('first_submission.csv', index=False, float_format='%.8f')
